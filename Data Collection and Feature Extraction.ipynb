# %%
# Installing billboard library
# !pip install billboard.py
# Out:
# Requirement already satisfied: billboard.py in c:\users\basan\anaconda3\lib\site-packages (7.0.1)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\basan\anaconda3\lib\site-packages (from billboard.py) (4.12.2)
# Requirement already satisfied: requests>=2.2.1 in c:\users\basan\anaconda3\lib\site-packages (from billboard.py) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\basan\anaconda3\lib\site-packages (from beautifulsoup4>=4.4.1->billboard.py) (2.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\basan\anaconda3\lib\site-packages (from requests>=2.2.1->billboard.py) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\basan\anaconda3\lib\site-packages (from requests>=2.2.1->billboard.py) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\basan\anaconda3\lib\site-packages (from requests>=2.2.1->billboard.py) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\basan\anaconda3\lib\site-packages (from requests>=2.2.1->billboard.py) (2023.7.22)

# %%
# Importing libraries
import numpy as np
import pandas as pd
import billboard

# %%
# Installing required libraries
from billboard import ChartData
from datetime import date

def get_hot100_info_for_years(years):
    all_years_info = {}

    for year in years:
        year_info = {}
        hot100_chart = ChartData('hot-100', date=f"{year}-01-01")

        songs_info = []

        for song in hot100_chart:
            song_info = {
                'song': song.title,
                'artist': song.artist
            }
            songs_info.append(song_info)

        year_info['songs'] = songs_info
        all_years_info[year] = year_info

    return all_years_info

# Getting data for the current year and previous 9 years
current_year = date.today().year
years = list(range(current_year, current_year - 10, -1))
hot100_info_for_years = get_hot100_info_for_years(years)

# Creating a DataFrame to store the information
df_list = []

for year, year_info in hot100_info_for_years.items():
    for song_info in year_info['songs']:
        df_list.append({'Song': song_info['song'], 'Artist': song_info['artist'], 'Label': 1})

# Converting list of dictionaries to DataFrame
hot100_df = pd.DataFrame(df_list)

# %%
hot100_df.count()
# Out:
# Song      1000
# Artist    1000
# Label     1000
# dtype: int64

# %%
hot100_df.head(10)
# Out:
#                                        Song          Artist  Label
# 0         Rockin' Around The Christmas Tree      Brenda Lee      1
# 1           All I Want For Christmas Is You    Mariah Carey      1
# 2                          Jingle Bell Rock     Bobby Helms      1
# 3                            Last Christmas           Wham!      1
# 4                   A Holly Jolly Christmas       Burl Ives      1
# 5  It's The Most Wonderful Time Of The Year   Andy Williams      1
# 6    Let It Snow, Let It Snow, Let It Snow!     Dean Martin      1
# 7                             Feliz Navidad  Jose Feliciano      1
# 8                               Lovin On Me     Jack Harlow      1
# 9                               Sleigh Ride    The Ronettes      1

# %%
# Dealing with duplicated values
hot100_df.duplicated().sum()
# Out:
# 161

# %%
hot100_df = hot100_df.drop_duplicates()

# %%
# Checking for duplicated rows
hot100_df.duplicated().sum()
# Out:
# 0

# %%
hot100_df.count()
# Out:
# Song      839
# Artist    839
# Label     839
# dtype: int64

# %%
all_global200_data = []

# Collecting data for the current year
current_year = 2024
chart_data_current_year = billboard.ChartData('billboard-global-200', year=current_year)
for song in chart_data_current_year:
    all_global200_data.append({'artist': song.artist, 'title': song.title, 'label': 0})

# Collecting data for the previous nine years
for year in range(current_year - 1, current_year - 10, -1):
    chart_data = billboard.ChartData('billboard-global-200', year=year)
    for song in chart_data:
        all_global200_data.append({'artist': song.artist, 'title': song.title, 'label': 0})

# Printing the collected data
for entry in all_global200_data:
    print(entry)
# Out:
# C:\Users\Basan\anaconda3\Lib\site-packages\billboard.py:423: UnsupportedYearWarning:
#             2024 is not a supported year-end chart from Billboard.
#             Results may be incomplete, inconsistent, or missing entirely.
#             The min and max supported years for the 'billboard-global-200' chart are 2021 and 2023, respectively.
#
#   warnings.warn(UnsupportedYearWarning(msg))
# C:\Users\Basan\anaconda3\Lib\site-packages\billboard.py:423: UnsupportedYearWarning:
#             2020 is not a supported year-end chart from Billboard.
#             Results may be incomplete, inconsistent, or missing entirely.
#             The min and max supported years for the 'billboard-global-200' chart are 2021 and 2023, respectively.
#
#   warnings.warn(UnsupportedYearWarning(msg))
# C:\Users\Basan\anaconda3\Lib\site-packages\billboard.py:423: UnsupportedYearWarning:
#             2019 is not a supported year-end chart from Billboard.
#             Results may be incomplete, inconsistent, or missing entirely.
#             The min and max supported years for the 'billboard-global-200' chart are 2021 and 2023, respectively.
#
#   warnings.warn(UnsupportedYearWarning(msg))
# C:\Users\Basan\anaconda3\Lib\site-packages\billboard.py:423: UnsupportedYearWarning:
#             2018 is not a supported year-end chart from Billboard.
#             Results may be incomplete, inconsistent, or missing entirely.
#             The min and max supported years for the 'billboard-global-200' chart are 2021 and 2023, respectively.
#
#   warnings.warn(UnsupportedYearWarning(msg))
# C:\Users\Basan\anaconda3\Lib\site-packages\billboard.py:423: UnsupportedYearWarning:
#             2017 is not a supported year-end chart from Billboard.
#             Results may be incomplete, inconsistent, or missing entirely.
#             The min and max supported years for the 'billboard-global-200' chart are 2021 and 2023, respectively.
#
#   warnings.warn(UnsupportedYearWarning(msg))
# C:\Users\Basan\anaconda3\Lib\site-packages\billboard.py:423: UnsupportedYearWarning:
#             2016 is not a supported year-end chart from Billboard.
#             Results may be incomplete, inconsistent, or missing entirely.
#             The min and max supported years for the 'billboard-global-200' chart are 2021 and 2023, respectively.
#
#   warnings.warn(UnsupportedYearWarning(msg))
# {'artist': 'Miley Cyrus', 'title': 'Flowers', 'label': 0}
# {'artist': 'Rema & Selena Gomez', 'title': 'Calm Down', 'label': 0}
# {'artist': 'SZA', 'title': 'Kill Bill', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Anti-Hero', 'label': 0}
# {'artist': 'The Weeknd & Ariana Grande', 'title': 'Die For You', 'label': 0}
# {'artist': 'Harry Styles', 'title': 'As It Was', 'label': 0}
# {'artist': 'Sam Smith & Kim Petras', 'title': 'Unholy', 'label': 0}
# {'artist': 'David Guetta & Bebe Rexha', 'title': "I'm Good (Blue)", 'label': 0}
# {'artist': 'Metro Boomin, The Weeknd & 21 Savage', 'title': "Creepin'", 'label': 0}
# {'artist': 'Morgan Wallen', 'title': 'Last Night', 'label': 0}
# {'artist': 'Yng Lvcas x Peso Pluma', 'title': 'La Bebe', 'label': 0}
# {'artist': 'Eslabon Armado X Peso Pluma', 'title': 'Ella Baila Sola', 'label': 0}
# {'artist': 'Stephen Sanchez', 'title': 'Until I Found You', 'label': 0}
# {'artist': 'OneRepublic', 'title': "I Ain't Worried", 'label': 0}
# {'artist': 'The Weeknd & Ariana Grande', 'title': 'Save Your Tears', 'label': 0}
# {'artist': 'Tom Odell', 'title': 'Another Love', 'label': 0}
# {'artist': 'Jung Kook Featuring Latto', 'title': 'Seven', 'label': 0}
# {'artist': 'Karol G x Shakira', 'title': 'TQG', 'label': 0}
# {'artist': 'Manuel Turizo', 'title': 'La Bachata', 'label': 0}
# {'artist': 'Fifty Fifty', 'title': 'Cupid', 'label': 0}
# {'artist': 'JVKE', 'title': 'Golden Hour', 'label': 0}
# {'artist': 'Bizarrap & Shakira', 'title': 'Bzrp Music Sessions, Vol. 53', 'label': 0}
# {'artist': 'RAYE Featuring 070 Shake', 'title': 'Escapism', 'label': 0}
# {'artist': 'Chris Brown', 'title': 'Under The Influence', 'label': 0}
# {'artist': 'Grupo Frontera X Bad Bunny', 'title': 'Un x100to', 'label': 0}
# {'artist': 'PinkPantheress & Ice Spice', 'title': "Boy's A Liar, Pt. 2", 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Cruel Summer', 'label': 0}
# {'artist': 'Zach Bryan', 'title': 'Something In The Orange', 'label': 0}
# {'artist': 'The Weeknd', 'title': 'Blinding Lights', 'label': 0}
# {'artist': 'Glass Animals', 'title': 'Heat Waves', 'label': 0}
# {'artist': 'SZA', 'title': 'Snooze', 'label': 0}
# {'artist': 'Bad Bunny & Chencho Corleone', 'title': 'Me Porto Bonito', 'label': 0}
# {'artist': 'Miguel', 'title': 'Sure Thing', 'label': 0}
# {'artist': 'Drake & 21 Savage', 'title': 'Rich Flex', 'label': 0}
# {'artist': 'Dua Lipa', 'title': 'Levitating', 'label': 0}
# {'artist': 'The Weeknd Featuring Daft Punk', 'title': 'Starboy', 'label': 0}
# {'artist': 'The Kid LAROI & Justin Bieber', 'title': 'Stay', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Perfect', 'label': 0}
# {'artist': 'Elton John & Dua Lipa', 'title': 'Cold Heart (PNAU Remix)', 'label': 0}
# {'artist': 'Bizarrap & Quevedo', 'title': 'Bzrp Music Sessions, Vol. 52', 'label': 0}
# {'artist': 'NewJeans', 'title': 'OMG', 'label': 0}
# {'artist': 'YOASOBI', 'title': 'Idol', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Shivers', 'label': 0}
# {'artist': 'Beyonce', 'title': 'Cuff It', 'label': 0}
# {'artist': 'The Neighbourhood', 'title': 'Sweater Weather', 'label': 0}
# {'artist': 'David Kushner', 'title': 'Daylight', 'label': 0}
# {'artist': 'Post Malone & Swae Lee', 'title': 'Sunflower (Spider-Man: Into The Spider-Verse)', 'label': 0}
# {'artist': 'Eminem', 'title': 'Mockingbird', 'label': 0}
# {'artist': 'Lewis Capaldi', 'title': 'Someone You Loved', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Titi Me Pregunto', 'label': 0}
# {'artist': 'Libianca', 'title': 'People', 'label': 0}
# {'artist': 'NewJeans', 'title': 'Ditto', 'label': 0}
# {'artist': 'Yandel & Feid', 'title': 'Yandel 150', 'label': 0}
# {'artist': 'Ozuna Featuring Feid', 'title': 'Hey Mor', 'label': 0}
# {'artist': 'Imagine Dragons', 'title': 'Bones', 'label': 0}
# {'artist': 'Arctic Monkeys', 'title': 'I Wanna Be Yours', 'label': 0}
# {'artist': 'Meghan Trainor', 'title': 'Made You Look', 'label': 0}
# {'artist': 'Luke Combs', 'title': 'Fast Car', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Bad Habits', 'label': 0}
# {'artist': 'Imagine Dragons', 'title': 'Believer', 'label': 0}
# {'artist': 'Jimin', 'title': 'Like Crazy', 'label': 0}
# {'artist': 'Bad Bunny & Bomba Estereo', 'title': 'Ojitos Lindos', 'label': 0}
# {'artist': 'Dua Lipa', 'title': 'Dance The Night', 'label': 0}
# {'artist': 'Coldplay', 'title': 'Viva La Vida', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Shape Of You', 'label': 0}
# {'artist': 'Olivia Rodrigo', 'title': 'Vampire', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Blank Space', 'label': 0}
# {'artist': 'Feid x Young Miko', 'title': 'Classy 101', 'label': 0}
# {'artist': 'Sia', 'title': 'Unstoppable', 'label': 0}
# {'artist': 'Coldplay', 'title': 'Yellow', 'label': 0}
# {'artist': 'Morgan Wallen', 'title': 'You Proof', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Lavender Haze', 'label': 0}
# {'artist': 'Rosa Linn', 'title': 'Snap', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Where She Goes', 'label': 0}
# {'artist': 'Drake Featuring 21 Savage', 'title': 'Jimmy Cooks', 'label': 0}
# {'artist': 'Myke Towers', 'title': 'LaLa', 'label': 0}
# {'artist': 'Lana Del Rey vs. Cedric Gervais', 'title': 'Summertime Sadness', 'label': 0}
# {'artist': 'Carin Leon X Grupo Frontera', 'title': 'Que Vuelvas', 'label': 0}
# {'artist': 'Lil Uzi Vert', 'title': 'Just Wanna Rock', 'label': 0}
# {'artist': 'Metro Boomin, Future & Chris Brown', 'title': 'Superhero (Heroes & Villains)', 'label': 0}
# {'artist': 'Steve Lacy', 'title': 'Bad Habit', 'label': 0}
# {'artist': 'Doja Cat', 'title': 'Paint The Town Red', 'label': 0}
# {'artist': 'Eminem', 'title': 'Without Me', 'label': 0}
# {'artist': 'Gunna', 'title': 'Fukumean', 'label': 0}
# {'artist': 'Billie Eilish & Khalid', 'title': 'Lovely', 'label': 0}
# {'artist': 'Arcangel & Bad Bunny', 'title': 'La Jumpa', 'label': 0}
# {'artist': 'Hotel Ugly', 'title': 'Shut Up My Moms Calling', 'label': 0}
# {'artist': 'Taylor Swift Featuring Ice Spice', 'title': 'Karma', 'label': 0}
# {'artist': 'Pinkfong', 'title': 'Baby Shark', 'label': 0}
# {'artist': 'Peso Pluma', 'title': 'Por Las Noches', 'label': 0}
# {'artist': 'J. Cole', 'title': 'No Role Modelz', 'label': 0}
# {'artist': 'Rosalia & Rauw Alejandro', 'title': 'Beso', 'label': 0}
# {'artist': 'Peso Pluma X Natanael Cano', 'title': 'PRC', 'label': 0}
# {'artist': 'Tears For Fears', 'title': 'Everybody Wants To Rule The World', 'label': 0}
# {'artist': 'Mariah Carey', 'title': 'All I Want For Christmas Is You', 'label': 0}
# {'artist': 'OneRepublic', 'title': 'Counting Stars', 'label': 0}
# {'artist': 'Oliver Tree & Robin Schulz', 'title': 'Miss You', 'label': 0}
# {'artist': 'Dave & Central Cee', 'title': 'Sprinter', 'label': 0}
# {'artist': 'Junior H x Peso Pluma', 'title': 'El Azul', 'label': 0}
# {'artist': 'd4vd', 'title': 'Here With Me', 'label': 0}
# {'artist': 'Vance Joy', 'title': 'Riptide', 'label': 0}
# {'artist': 'Fuerza Regida X Grupo Frontera', 'title': 'Bebe Dame', 'label': 0}
# {'artist': 'Gabito Ballesteros, Peso Pluma & Natanael Cano', 'title': 'AMG', 'label': 0}
# {'artist': 'Hozier', 'title': 'Take Me To Church', 'label': 0}
# {'artist': 'Post Malone', 'title': 'Circles', 'label': 0}
# {'artist': 'Morgan Wallen', 'title': "Thinkin' Bout Me", 'label': 0}
# {'artist': 'Adele', 'title': 'Easy On Me', 'label': 0}
# {'artist': 'Coi Leray', 'title': 'Players', 'label': 0}
# {'artist': 'a-ha', 'title': 'Take On Me', 'label': 0}
# {'artist': 'Lil Durk Featuring J. Cole', 'title': 'All My Life', 'label': 0}
# {'artist': 'Billie Eilish', 'title': 'What Was I Made For?', 'label': 0}
# {'artist': 'Rosalia', 'title': 'Despecha', 'label': 0}
# {'artist': 'Harry Styles', 'title': 'Watermelon Sugar', 'label': 0}
# {'artist': 'Feid', 'title': 'Feliz Cumpleanos Ferxxo', 'label': 0}
# {'artist': 'Post Malone', 'title': 'Chemical', 'label': 0}
# {'artist': 'Nicky Youre & dazy', 'title': 'Sunroof', 'label': 0}
# {'artist': 'NewJeans', 'title': 'Super Shy', 'label': 0}
# {'artist': 'Coolio Featuring L.V.', 'title': "Gangsta's Paradise", 'label': 0}
# {'artist': "Guns N' Roses", 'title': "Sweet Child O' Mine", 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Style', 'label': 0}
# {'artist': 'Karol G', 'title': 'Provenza', 'label': 0}
# {'artist': 'Bruno Mars', 'title': 'When I Was Your Man', 'label': 0}
# {'artist': 'Nicki Minaj & Ice Spice With Aqua', 'title': 'Barbie World', 'label': 0}
# {'artist': 'Morgan Wallen', 'title': 'Wasted On You', 'label': 0}
# {'artist': 'David Guetta, Anne-Marie & Coi Leray', 'title': "Baby Don't Hurt Me", 'label': 0}
# {'artist': 'Lady Gaga & Bradley Cooper', 'title': 'Shallow', 'label': 0}
# {'artist': 'Toosii', 'title': 'Favorite Song', 'label': 0}
# {'artist': 'Rihanna', 'title': 'Lift Me Up', 'label': 0}
# {'artist': 'Wham!', 'title': 'Last Christmas', 'label': 0}
# {'artist': 'Adele', 'title': 'Set Fire To The Rain', 'label': 0}
# {'artist': 'Kali Uchis', 'title': 'Moonlight', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Eyes Closed', 'label': 0}
# {'artist': 'Tyler, The Creator Featuring Kali Uchis', 'title': 'See You Again', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Efecto', 'label': 0}
# {'artist': 'Calvin Harris & Ellie Goulding', 'title': 'Miracle', 'label': 0}
# {'artist': 'Ruth B.', 'title': 'Dandelions', 'label': 0}
# {'artist': 'Peso Pluma, Gabito Ballesteros & Junior H', 'title': 'Lady Gaga', 'label': 0}
# {'artist': 'Macklemore & Ryan Lewis Featuring Ray Dalton', 'title': "Can't Hold Us", 'label': 0}
# {'artist': 'Metro Boomin Featuring Don Toliver & Future', 'title': 'Too Many Nights', 'label': 0}
# {'artist': 'Tiesto Featuring Tate McRae', 'title': '10:35', 'label': 0}
# {'artist': 'Grupo Frontera', 'title': 'No Se Va', 'label': 0}
# {'artist': 'Fuerza Regida', 'title': 'TQM', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Shake It Off', 'label': 0}
# {'artist': 'Future Featuring Drake & Tems', 'title': 'Wait For U', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Cardigan', 'label': 0}
# {'artist': 'Brenda Lee', 'title': "Rockin' Around The Christmas Tree", 'label': 0}
# {'artist': 'NewJeans', 'title': 'Hype Boy', 'label': 0}
# {'artist': 'Drake', 'title': 'Search & Rescue', 'label': 0}
# {'artist': 'Kenshi Yonezu', 'title': 'Kick Back', 'label': 0}
# {'artist': 'Yahritza y Su Esencia x Grupo Frontera', 'title': 'Fragil', 'label': 0}
# {'artist': 'Bizarrap & Peso Pluma', 'title': 'Bzrp Music Sessions, Vol. 55', 'label': 0}
# {'artist': 'IVE', 'title': 'I Am', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Lover', 'label': 0}
# {'artist': 'Bailey Zimmerman', 'title': 'Rock And A Hard Place', 'label': 0}
# {'artist': 'The Police', 'title': 'Every Breath You Take', 'label': 0}
# {'artist': 'The Weeknd, Playboi Carti & Madonna', 'title': 'Popular', 'label': 0}
# {'artist': 'Fleetwood Mac', 'title': 'Dreams', 'label': 0}
# {'artist': 'The Chainsmokers & Coldplay', 'title': 'Something Just Like This', 'label': 0}
# {'artist': 'Quevedo', 'title': 'Columbia', 'label': 0}
# {'artist': 'Jisoo', 'title': 'Flower', 'label': 0}
# {'artist': 'Taylor Swift', 'title': "Don't Blame Me", 'label': 0}
# {'artist': 'Junior H X Oscar Maydon', 'title': 'Fin de Semana', 'label': 0}
# {'artist': 'd4vd', 'title': 'Romantic Homicide', 'label': 0}
# {'artist': 'Imagine Dragons X JID', 'title': 'Enemy', 'label': 0}
# {'artist': 'Bobby Helms', 'title': 'Jingle Bell Rock', 'label': 0}
# {'artist': 'Kendrick Lamar Featuring Jay Rock', 'title': 'Money Trees', 'label': 0}
# {'artist': 'Lady Gaga', 'title': 'Bloody Mary', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Moscow Mule', 'label': 0}
# {'artist': 'Nirvana', 'title': 'Smells Like Teen Spirit', 'label': 0}
# {'artist': 'Marshmello & Manuel Turizo', 'title': 'El Merengue', 'label': 0}
# {'artist': '(G)I-DLE', 'title': 'Queencard', 'label': 0}
# {'artist': 'Karol G', 'title': 'Amargura', 'label': 0}
# {'artist': 'Imagine Dragons', 'title': 'Thunder', 'label': 0}
# {'artist': 'Chino Pacas', 'title': 'El Gordo Trae El Mando', 'label': 0}
# {'artist': 'Karol G & Peso Pluma', 'title': 'Qlona', 'label': 0}
# {'artist': 'Radiohead', 'title': 'Creep', 'label': 0}
# {'artist': 'Fuerza Regida', 'title': 'Sabor Fresa', 'label': 0}
# {'artist': 'Loreen', 'title': 'Tattoo', 'label': 0}
# {'artist': 'Fuerza Regida X Natanael Cano', 'title': 'Ch y La Pizza', 'label': 0}
# {'artist': 'Sabrina Carpenter', 'title': 'Nonsense', 'label': 0}
# {'artist': 'SZA', 'title': 'Shirt', 'label': 0}
# {'artist': 'LE SSERAFIM', 'title': 'Antifragile', 'label': 0}
# {'artist': 'Metro Boomin, Travis Scott & Young Thug', 'title': 'Trance', 'label': 0}
# {'artist': 'Eladio Carrion & Bad Bunny', 'title': 'Coco Chanel', 'label': 0}
# {'artist': 'Peggy Gou', 'title': '(It Goes Like) Nanana', 'label': 0}
# {'artist': 'Peso Pluma & Grupo Frontera', 'title': 'Tulum', 'label': 0}
# {'artist': 'Harry Styles', 'title': 'Late Night Talking', 'label': 0}
# {'artist': 'BLACKPINK', 'title': 'Shut Down', 'label': 0}
# {'artist': 'Carin Leon', 'title': 'Primera Cita', 'label': 0}
# {'artist': 'Billie Eilish', 'title': 'Happier Than Ever', 'label': 0}
# {'artist': 'Feid', 'title': 'Chorrito Pa Las Animas', 'label': 0}
# {'artist': 'Joji', 'title': 'Glimpse Of Us', 'label': 0}
# {'artist': 'Doechii Featuring Kodak Black', 'title': 'What It Is (Block Boy)', 'label': 0}
# {'artist': 'Ariana Grande', 'title': 'Santa Tell Me', 'label': 0}
# {'artist': 'Official HIGE DANdism', 'title': 'Subtitle', 'label': 0}
# {'artist': 'Lizzo', 'title': 'About Damn Time', 'label': 0}
# {'artist': 'NewJeans', 'title': 'ETA', 'label': 0}
# {'artist': 'DENNIS E MC Kevin O Chris, Maluma & Karol G', 'title': 'Ta OK', 'label': 0}
# {'artist': 'Shakira + Ozuna', 'title': 'Monotonia', 'label': 0}
# {'artist': 'Karol G x Romeo Santos', 'title': 'X Si Volvemos', 'label': 0}
# {'artist': 'Miley Cyrus', 'title': 'Flowers', 'label': 0}
# {'artist': 'Rema & Selena Gomez', 'title': 'Calm Down', 'label': 0}
# {'artist': 'SZA', 'title': 'Kill Bill', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Anti-Hero', 'label': 0}
# {'artist': 'The Weeknd & Ariana Grande', 'title': 'Die For You', 'label': 0}
# {'artist': 'Harry Styles', 'title': 'As It Was', 'label': 0}
# {'artist': 'Sam Smith & Kim Petras', 'title': 'Unholy', 'label': 0}
# {'artist': 'David Guetta & Bebe Rexha', 'title': "I'm Good (Blue)", 'label': 0}
# {'artist': 'Metro Boomin, The Weeknd & 21 Savage', 'title': "Creepin'", 'label': 0}
# {'artist': 'Morgan Wallen', 'title': 'Last Night', 'label': 0}
# {'artist': 'Yng Lvcas x Peso Pluma', 'title': 'La Bebe', 'label': 0}
# {'artist': 'Eslabon Armado X Peso Pluma', 'title': 'Ella Baila Sola', 'label': 0}
# {'artist': 'Stephen Sanchez', 'title': 'Until I Found You', 'label': 0}
# {'artist': 'OneRepublic', 'title': "I Ain't Worried", 'label': 0}
# {'artist': 'The Weeknd & Ariana Grande', 'title': 'Save Your Tears', 'label': 0}
# {'artist': 'Tom Odell', 'title': 'Another Love', 'label': 0}
# {'artist': 'Jung Kook Featuring Latto', 'title': 'Seven', 'label': 0}
# {'artist': 'Karol G x Shakira', 'title': 'TQG', 'label': 0}
# {'artist': 'Manuel Turizo', 'title': 'La Bachata', 'label': 0}
# {'artist': 'Fifty Fifty', 'title': 'Cupid', 'label': 0}
# {'artist': 'JVKE', 'title': 'Golden Hour', 'label': 0}
# {'artist': 'Bizarrap & Shakira', 'title': 'Bzrp Music Sessions, Vol. 53', 'label': 0}
# {'artist': 'RAYE Featuring 070 Shake', 'title': 'Escapism', 'label': 0}
# {'artist': 'Chris Brown', 'title': 'Under The Influence', 'label': 0}
# {'artist': 'Grupo Frontera X Bad Bunny', 'title': 'Un x100to', 'label': 0}
# {'artist': 'PinkPantheress & Ice Spice', 'title': "Boy's A Liar, Pt. 2", 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Cruel Summer', 'label': 0}
# {'artist': 'Zach Bryan', 'title': 'Something In The Orange', 'label': 0}
# {'artist': 'The Weeknd', 'title': 'Blinding Lights', 'label': 0}
# {'artist': 'Glass Animals', 'title': 'Heat Waves', 'label': 0}
# {'artist': 'SZA', 'title': 'Snooze', 'label': 0}
# {'artist': 'Bad Bunny & Chencho Corleone', 'title': 'Me Porto Bonito', 'label': 0}
# {'artist': 'Miguel', 'title': 'Sure Thing', 'label': 0}
# {'artist': 'Drake & 21 Savage', 'title': 'Rich Flex', 'label': 0}
# {'artist': 'Dua Lipa', 'title': 'Levitating', 'label': 0}
# {'artist': 'The Weeknd Featuring Daft Punk', 'title': 'Starboy', 'label': 0}
# {'artist': 'The Kid LAROI & Justin Bieber', 'title': 'Stay', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Perfect', 'label': 0}
# {'artist': 'Elton John & Dua Lipa', 'title': 'Cold Heart (PNAU Remix)', 'label': 0}
# {'artist': 'Bizarrap & Quevedo', 'title': 'Bzrp Music Sessions, Vol. 52', 'label': 0}
# {'artist': 'NewJeans', 'title': 'OMG', 'label': 0}
# {'artist': 'YOASOBI', 'title': 'Idol', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Shivers', 'label': 0}
# {'artist': 'Beyonce', 'title': 'Cuff It', 'label': 0}
# {'artist': 'The Neighbourhood', 'title': 'Sweater Weather', 'label': 0}
# {'artist': 'David Kushner', 'title': 'Daylight', 'label': 0}
# {'artist': 'Post Malone & Swae Lee', 'title': 'Sunflower (Spider-Man: Into The Spider-Verse)', 'label': 0}
# {'artist': 'Eminem', 'title': 'Mockingbird', 'label': 0}
# {'artist': 'Lewis Capaldi', 'title': 'Someone You Loved', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Titi Me Pregunto', 'label': 0}
# {'artist': 'Libianca', 'title': 'People', 'label': 0}
# {'artist': 'NewJeans', 'title': 'Ditto', 'label': 0}
# {'artist': 'Yandel & Feid', 'title': 'Yandel 150', 'label': 0}
# {'artist': 'Ozuna Featuring Feid', 'title': 'Hey Mor', 'label': 0}
# {'artist': 'Imagine Dragons', 'title': 'Bones', 'label': 0}
# {'artist': 'Arctic Monkeys', 'title': 'I Wanna Be Yours', 'label': 0}
# {'artist': 'Meghan Trainor', 'title': 'Made You Look', 'label': 0}
# {'artist': 'Luke Combs', 'title': 'Fast Car', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Bad Habits', 'label': 0}
# {'artist': 'Imagine Dragons', 'title': 'Believer', 'label': 0}
# {'artist': 'Jimin', 'title': 'Like Crazy', 'label': 0}
# {'artist': 'Bad Bunny & Bomba Estereo', 'title': 'Ojitos Lindos', 'label': 0}
# {'artist': 'Dua Lipa', 'title': 'Dance The Night', 'label': 0}
# {'artist': 'Coldplay', 'title': 'Viva La Vida', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Shape Of You', 'label': 0}
# {'artist': 'Olivia Rodrigo', 'title': 'Vampire', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Blank Space', 'label': 0}
# {'artist': 'Feid x Young Miko', 'title': 'Classy 101', 'label': 0}
# {'artist': 'Sia', 'title': 'Unstoppable', 'label': 0}
# {'artist': 'Coldplay', 'title': 'Yellow', 'label': 0}
# {'artist': 'Morgan Wallen', 'title': 'You Proof', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Lavender Haze', 'label': 0}
# {'artist': 'Rosa Linn', 'title': 'Snap', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Where She Goes', 'label': 0}
# {'artist': 'Drake Featuring 21 Savage', 'title': 'Jimmy Cooks', 'label': 0}
# {'artist': 'Myke Towers', 'title': 'LaLa', 'label': 0}
# {'artist': 'Lana Del Rey vs. Cedric Gervais', 'title': 'Summertime Sadness', 'label': 0}
# {'artist': 'Carin Leon X Grupo Frontera', 'title': 'Que Vuelvas', 'label': 0}
# {'artist': 'Lil Uzi Vert', 'title': 'Just Wanna Rock', 'label': 0}
# {'artist': 'Metro Boomin, Future & Chris Brown', 'title': 'Superhero (Heroes & Villains)', 'label': 0}
# {'artist': 'Steve Lacy', 'title': 'Bad Habit', 'label': 0}
# {'artist': 'Doja Cat', 'title': 'Paint The Town Red', 'label': 0}
# {'artist': 'Eminem', 'title': 'Without Me', 'label': 0}
# {'artist': 'Gunna', 'title': 'Fukumean', 'label': 0}
# {'artist': 'Billie Eilish & Khalid', 'title': 'Lovely', 'label': 0}
# {'artist': 'Arcangel & Bad Bunny', 'title': 'La Jumpa', 'label': 0}
# {'artist': 'Hotel Ugly', 'title': 'Shut Up My Moms Calling', 'label': 0}
# {'artist': 'Taylor Swift Featuring Ice Spice', 'title': 'Karma', 'label': 0}
# {'artist': 'Pinkfong', 'title': 'Baby Shark', 'label': 0}
# {'artist': 'Peso Pluma', 'title': 'Por Las Noches', 'label': 0}
# {'artist': 'J. Cole', 'title': 'No Role Modelz', 'label': 0}
# {'artist': 'Rosalia & Rauw Alejandro', 'title': 'Beso', 'label': 0}
# {'artist': 'Peso Pluma X Natanael Cano', 'title': 'PRC', 'label': 0}
# {'artist': 'Tears For Fears', 'title': 'Everybody Wants To Rule The World', 'label': 0}
# {'artist': 'Mariah Carey', 'title': 'All I Want For Christmas Is You', 'label': 0}
# {'artist': 'OneRepublic', 'title': 'Counting Stars', 'label': 0}
# {'artist': 'Oliver Tree & Robin Schulz', 'title': 'Miss You', 'label': 0}
# {'artist': 'Dave & Central Cee', 'title': 'Sprinter', 'label': 0}
# {'artist': 'Junior H x Peso Pluma', 'title': 'El Azul', 'label': 0}
# {'artist': 'd4vd', 'title': 'Here With Me', 'label': 0}
# {'artist': 'Vance Joy', 'title': 'Riptide', 'label': 0}
# {'artist': 'Fuerza Regida X Grupo Frontera', 'title': 'Bebe Dame', 'label': 0}
# {'artist': 'Gabito Ballesteros, Peso Pluma & Natanael Cano', 'title': 'AMG', 'label': 0}
# {'artist': 'Hozier', 'title': 'Take Me To Church', 'label': 0}
# {'artist': 'Post Malone', 'title': 'Circles', 'label': 0}
# {'artist': 'Morgan Wallen', 'title': "Thinkin' Bout Me", 'label': 0}
# {'artist': 'Adele', 'title': 'Easy On Me', 'label': 0}
# {'artist': 'Coi Leray', 'title': 'Players', 'label': 0}
# {'artist': 'a-ha', 'title': 'Take On Me', 'label': 0}
# {'artist': 'Lil Durk Featuring J. Cole', 'title': 'All My Life', 'label': 0}
# {'artist': 'Billie Eilish', 'title': 'What Was I Made For?', 'label': 0}
# {'artist': 'Rosalia', 'title': 'Despecha', 'label': 0}
# {'artist': 'Harry Styles', 'title': 'Watermelon Sugar', 'label': 0}
# {'artist': 'Feid', 'title': 'Feliz Cumpleanos Ferxxo', 'label': 0}
# {'artist': 'Post Malone', 'title': 'Chemical', 'label': 0}
# {'artist': 'Nicky Youre & dazy', 'title': 'Sunroof', 'label': 0}
# {'artist': 'NewJeans', 'title': 'Super Shy', 'label': 0}
# {'artist': 'Coolio Featuring L.V.', 'title': "Gangsta's Paradise", 'label': 0}
# {'artist': "Guns N' Roses", 'title': "Sweet Child O' Mine", 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Style', 'label': 0}
# {'artist': 'Karol G', 'title': 'Provenza', 'label': 0}
# {'artist': 'Bruno Mars', 'title': 'When I Was Your Man', 'label': 0}
# {'artist': 'Nicki Minaj & Ice Spice With Aqua', 'title': 'Barbie World', 'label': 0}
# {'artist': 'Morgan Wallen', 'title': 'Wasted On You', 'label': 0}
# {'artist': 'David Guetta, Anne-Marie & Coi Leray', 'title': "Baby Don't Hurt Me", 'label': 0}
# {'artist': 'Lady Gaga & Bradley Cooper', 'title': 'Shallow', 'label': 0}
# {'artist': 'Toosii', 'title': 'Favorite Song', 'label': 0}
# {'artist': 'Rihanna', 'title': 'Lift Me Up', 'label': 0}
# {'artist': 'Wham!', 'title': 'Last Christmas', 'label': 0}
# {'artist': 'Adele', 'title': 'Set Fire To The Rain', 'label': 0}
# {'artist': 'Kali Uchis', 'title': 'Moonlight', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Eyes Closed', 'label': 0}
# {'artist': 'Tyler, The Creator Featuring Kali Uchis', 'title': 'See You Again', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Efecto', 'label': 0}
# {'artist': 'Calvin Harris & Ellie Goulding', 'title': 'Miracle', 'label': 0}
# {'artist': 'Ruth B.', 'title': 'Dandelions', 'label': 0}
# {'artist': 'Peso Pluma, Gabito Ballesteros & Junior H', 'title': 'Lady Gaga', 'label': 0}
# {'artist': 'Macklemore & Ryan Lewis Featuring Ray Dalton', 'title': "Can't Hold Us", 'label': 0}
# {'artist': 'Metro Boomin Featuring Don Toliver & Future', 'title': 'Too Many Nights', 'label': 0}
# {'artist': 'Tiesto Featuring Tate McRae', 'title': '10:35', 'label': 0}
# {'artist': 'Grupo Frontera', 'title': 'No Se Va', 'label': 0}
# {'artist': 'Fuerza Regida', 'title': 'TQM', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Shake It Off', 'label': 0}
# {'artist': 'Future Featuring Drake & Tems', 'title': 'Wait For U', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Cardigan', 'label': 0}
# {'artist': 'Brenda Lee', 'title': "Rockin' Around The Christmas Tree", 'label': 0}
# {'artist': 'NewJeans', 'title': 'Hype Boy', 'label': 0}
# {'artist': 'Drake', 'title': 'Search & Rescue', 'label': 0}
# {'artist': 'Kenshi Yonezu', 'title': 'Kick Back', 'label': 0}
# {'artist': 'Yahritza y Su Esencia x Grupo Frontera', 'title': 'Fragil', 'label': 0}
# {'artist': 'Bizarrap & Peso Pluma', 'title': 'Bzrp Music Sessions, Vol. 55', 'label': 0}
# {'artist': 'IVE', 'title': 'I Am', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Lover', 'label': 0}
# {'artist': 'Bailey Zimmerman', 'title': 'Rock And A Hard Place', 'label': 0}
# {'artist': 'The Police', 'title': 'Every Breath You Take', 'label': 0}
# {'artist': 'The Weeknd, Playboi Carti & Madonna', 'title': 'Popular', 'label': 0}
# {'artist': 'Fleetwood Mac', 'title': 'Dreams', 'label': 0}
# {'artist': 'The Chainsmokers & Coldplay', 'title': 'Something Just Like This', 'label': 0}
# {'artist': 'Quevedo', 'title': 'Columbia', 'label': 0}
# {'artist': 'Jisoo', 'title': 'Flower', 'label': 0}
# {'artist': 'Taylor Swift', 'title': "Don't Blame Me", 'label': 0}
# {'artist': 'Junior H X Oscar Maydon', 'title': 'Fin de Semana', 'label': 0}
# {'artist': 'd4vd', 'title': 'Romantic Homicide', 'label': 0}
# {'artist': 'Imagine Dragons X JID', 'title': 'Enemy', 'label': 0}
# {'artist': 'Bobby Helms', 'title': 'Jingle Bell Rock', 'label': 0}
# {'artist': 'Kendrick Lamar Featuring Jay Rock', 'title': 'Money Trees', 'label': 0}
# {'artist': 'Lady Gaga', 'title': 'Bloody Mary', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Moscow Mule', 'label': 0}
# {'artist': 'Nirvana', 'title': 'Smells Like Teen Spirit', 'label': 0}
# {'artist': 'Marshmello & Manuel Turizo', 'title': 'El Merengue', 'label': 0}
# {'artist': '(G)I-DLE', 'title': 'Queencard', 'label': 0}
# {'artist': 'Karol G', 'title': 'Amargura', 'label': 0}
# {'artist': 'Imagine Dragons', 'title': 'Thunder', 'label': 0}
# {'artist': 'Chino Pacas', 'title': 'El Gordo Trae El Mando', 'label': 0}
# {'artist': 'Karol G & Peso Pluma', 'title': 'Qlona', 'label': 0}
# {'artist': 'Radiohead', 'title': 'Creep', 'label': 0}
# {'artist': 'Fuerza Regida', 'title': 'Sabor Fresa', 'label': 0}
# {'artist': 'Loreen', 'title': 'Tattoo', 'label': 0}
# {'artist': 'Fuerza Regida X Natanael Cano', 'title': 'Ch y La Pizza', 'label': 0}
# {'artist': 'Sabrina Carpenter', 'title': 'Nonsense', 'label': 0}
# {'artist': 'SZA', 'title': 'Shirt', 'label': 0}
# {'artist': 'LE SSERAFIM', 'title': 'Antifragile', 'label': 0}
# {'artist': 'Metro Boomin, Travis Scott & Young Thug', 'title': 'Trance', 'label': 0}
# {'artist': 'Eladio Carrion & Bad Bunny', 'title': 'Coco Chanel', 'label': 0}
# {'artist': 'Peggy Gou', 'title': '(It Goes Like) Nanana', 'label': 0}
# {'artist': 'Peso Pluma & Grupo Frontera', 'title': 'Tulum', 'label': 0}
# {'artist': 'Harry Styles', 'title': 'Late Night Talking', 'label': 0}
# {'artist': 'BLACKPINK', 'title': 'Shut Down', 'label': 0}
# {'artist': 'Carin Leon', 'title': 'Primera Cita', 'label': 0}
# {'artist': 'Billie Eilish', 'title': 'Happier Than Ever', 'label': 0}
# {'artist': 'Feid', 'title': 'Chorrito Pa Las Animas', 'label': 0}
# {'artist': 'Joji', 'title': 'Glimpse Of Us', 'label': 0}
# {'artist': 'Doechii Featuring Kodak Black', 'title': 'What It Is (Block Boy)', 'label': 0}
# {'artist': 'Ariana Grande', 'title': 'Santa Tell Me', 'label': 0}
# {'artist': 'Official HIGE DANdism', 'title': 'Subtitle', 'label': 0}
# {'artist': 'Lizzo', 'title': 'About Damn Time', 'label': 0}
# {'artist': 'NewJeans', 'title': 'ETA', 'label': 0}
# {'artist': 'DENNIS E MC Kevin O Chris, Maluma & Karol G', 'title': 'Ta OK', 'label': 0}
# {'artist': 'Shakira + Ozuna', 'title': 'Monotonia', 'label': 0}
# {'artist': 'Karol G x Romeo Santos', 'title': 'X Si Volvemos', 'label': 0}
# {'artist': 'Harry Styles', 'title': 'As It Was', 'label': 0}
# {'artist': 'Glass Animals', 'title': 'Heat Waves', 'label': 0}
# {'artist': 'The Kid LAROI & Justin Bieber', 'title': 'Stay', 'label': 0}
# {'artist': 'Elton John & Dua Lipa', 'title': 'Cold Heart (PNAU Remix)', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Shivers', 'label': 0}
# {'artist': 'Adele', 'title': 'Easy On Me', 'label': 0}
# {'artist': 'GAYLE', 'title': 'abcdefu', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Bad Habits', 'label': 0}
# {'artist': 'Imagine Dragons X JID', 'title': 'Enemy', 'label': 0}
# {'artist': 'The Weeknd & Ariana Grande', 'title': 'Save Your Tears', 'label': 0}
# {'artist': 'Bad Bunny & Chencho Corleone', 'title': 'Me Porto Bonito', 'label': 0}
# {'artist': 'Lil Nas X & Jack Harlow', 'title': 'Industry Baby', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Titi Me Pregunto', 'label': 0}
# {'artist': 'Dua Lipa', 'title': 'Levitating', 'label': 0}
# {'artist': 'Farruko', 'title': 'Pepas', 'label': 0}
# {'artist': 'The Weeknd', 'title': 'Blinding Lights', 'label': 0}
# {'artist': 'CKay', 'title': 'Love Nwantiti (Ah Ah Ah)', 'label': 0}
# {'artist': 'Kate Bush', 'title': 'Running Up That Hill (A Deal With God)', 'label': 0}
# {'artist': 'Justin Bieber', 'title': 'Ghost', 'label': 0}
# {'artist': 'Jack Harlow', 'title': 'First Class', 'label': 0}
# {'artist': 'Billie Eilish', 'title': 'Happier Than Ever', 'label': 0}
# {'artist': 'Doja Cat', 'title': 'Woman', 'label': 0}
# {'artist': 'Bad Bunny & Bomba Estereo', 'title': 'Ojitos Lindos', 'label': 0}
# {'artist': 'Lost Frequencies & Calum Scott', 'title': 'Where Are You Now', 'label': 0}
# {'artist': 'Coldplay x BTS', 'title': 'My Universe', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Moscow Mule', 'label': 0}
# {'artist': 'Olivia Rodrigo', 'title': 'Good 4 U', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Efecto', 'label': 0}
# {'artist': 'Camila Cabello Featuring Ed Sheeran', 'title': 'Bam Bam', 'label': 0}
# {'artist': 'Lizzo', 'title': 'About Damn Time', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Perfect', 'label': 0}
# {'artist': 'Karol G', 'title': 'Provenza', 'label': 0}
# {'artist': 'Tom Odell', 'title': 'Another Love', 'label': 0}
# {'artist': 'The Neighbourhood', 'title': 'Sweater Weather', 'label': 0}
# {'artist': 'Bizarrap & Quevedo', 'title': 'Bzrp Music Sessions, Vol. 52', 'label': 0}
# {'artist': 'Becky G X Karol G', 'title': 'MAMIII', 'label': 0}
# {'artist': 'Tiesto & Ava Max', 'title': 'The Motto', 'label': 0}
# {'artist': 'BTS', 'title': 'Butter', 'label': 0}
# {'artist': 'Doja Cat Featuring SZA', 'title': 'Kiss Me More', 'label': 0}
# {'artist': 'BTS', 'title': 'Dynamite', 'label': 0}
# {'artist': 'Rauw Alejandro & Chencho Corleone', 'title': 'Desesperados', 'label': 0}
# {'artist': 'Carolina Gaitan, Mauro Castillo, Adassa, Rhenzy Feliz, Diane Guerrero, Stephanie Beatriz & Encanto Cast', 'title': "We Don't Talk About Bruno", 'label': 0}
# {'artist': 'OneRepublic', 'title': "I Ain't Worried", 'label': 0}
# {'artist': 'Future Featuring Drake & Tems', 'title': 'Wait For U', 'label': 0}
# {'artist': 'Imagine Dragons', 'title': 'Believer', 'label': 0}
# {'artist': 'Harry Styles', 'title': 'Watermelon Sugar', 'label': 0}
# {'artist': 'Post Malone & Swae Lee', 'title': 'Sunflower (Spider-Man: Into The Spider-Verse)', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Shape Of You', 'label': 0}
# {'artist': 'Lil Nas X', 'title': 'Thats What I Want', 'label': 0}
# {'artist': 'Joji', 'title': 'Glimpse Of Us', 'label': 0}
# {'artist': 'Acraze Featuring Cherish', 'title': 'Do It To It', 'label': 0}
# {'artist': 'Pinkfong', 'title': 'Baby Shark', 'label': 0}
# {'artist': 'Tones And I', 'title': 'Dance Monkey', 'label': 0}
# {'artist': 'Lewis Capaldi', 'title': 'Someone You Loved', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Yonaguni', 'label': 0}
# {'artist': 'Elley Duhe', 'title': 'Middle Of The Night', 'label': 0}
# {'artist': 'Taylor Swift', 'title': "All Too Well (Taylor's Version)", 'label': 0}
# {'artist': 'Olivia Rodrigo', 'title': 'Traitor', 'label': 0}
# {'artist': 'Bad Bunny & Rauw Alejandro', 'title': 'Party', 'label': 0}
# {'artist': 'Olivia Rodrigo', 'title': 'Drivers License', 'label': 0}
# {'artist': 'Bad Bunny & Jhay Cortez', 'title': 'Dakiti', 'label': 0}
# {'artist': 'Harry Styles', 'title': 'Late Night Talking', 'label': 0}
# {'artist': 'Eminem', 'title': 'Without Me', 'label': 0}
# {'artist': 'Doja Cat', 'title': 'Need To Know', 'label': 0}
# {'artist': 'Justin Bieber Featuring Daniel Caesar & Giveon', 'title': 'Peaches', 'label': 0}
# {'artist': 'Dua Lipa', 'title': "Don't Start Now", 'label': 0}
# {'artist': 'Lady Gaga & Bradley Cooper', 'title': 'Shallow', 'label': 0}
# {'artist': 'Anitta', 'title': 'Envolver', 'label': 0}
# {'artist': 'Ruth B.', 'title': 'Dandelions', 'label': 0}
# {'artist': 'Maneskin', 'title': "Beggin'", 'label': 0}
# {'artist': 'Bad Bunny & Jhay Cortez', 'title': 'Tarot', 'label': 0}
# {'artist': 'Post Malone', 'title': 'Circles', 'label': 0}
# {'artist': 'Billie Eilish & Khalid', 'title': 'Lovely', 'label': 0}
# {'artist': 'Coldplay', 'title': 'Yellow', 'label': 0}
# {'artist': 'Queen', 'title': 'Bohemian Rhapsody', 'label': 0}
# {'artist': 'Imagine Dragons', 'title': 'Bones', 'label': 0}
# {'artist': 'Kodak Black', 'title': 'Super Gremlin', 'label': 0}
# {'artist': 'Tainy, Bad Bunny & Julieta Venegas', 'title': 'Lo Siento BB:/', 'label': 0}
# {'artist': 'Coolio Featuring L.V.', 'title': "Gangsta's Paradise", 'label': 0}
# {'artist': 'Steve Lacy', 'title': 'Bad Habit', 'label': 0}
# {'artist': 'Drake Featuring 21 Savage', 'title': 'Jimmy Cooks', 'label': 0}
# {'artist': 'Shakira & Rauw Alejandro', 'title': 'Te Felicito', 'label': 0}
# {'artist': 'Shouse', 'title': 'Love Tonight', 'label': 0}
# {'artist': 'Jaymes Young', 'title': 'Infinity', 'label': 0}
# {'artist': 'Lil Nas X', 'title': 'Montero (Call Me By Your Name)', 'label': 0}
# {'artist': 'Nirvana', 'title': 'Smells Like Teen Spirit', 'label': 0}
# {'artist': 'Post Malone Featuring Doja Cat', 'title': 'I Like You (A Happier Song)', 'label': 0}
# {'artist': 'Mariah Carey', 'title': 'All I Want For Christmas Is You', 'label': 0}
# {'artist': 'OneRepublic', 'title': 'Counting Stars', 'label': 0}
# {'artist': 'Manuel Turizo', 'title': 'La Bachata', 'label': 0}
# {'artist': 'Post Malone & The Weeknd', 'title': 'One Right Now', 'label': 0}
# {'artist': 'The Chainsmokers & Coldplay', 'title': 'Something Just Like This', 'label': 0}
# {'artist': 'David Guetta & Bebe Rexha', 'title': "I'm Good (Blue)", 'label': 0}
# {'artist': 'BLACKPINK', 'title': 'Pink Venom', 'label': 0}
# {'artist': 'Chris Brown', 'title': 'Under The Influence', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Neverita', 'label': 0}
# {'artist': 'J. Cole', 'title': 'No Role Modelz', 'label': 0}
# {'artist': 'Sam Smith & Kim Petras', 'title': 'Unholy', 'label': 0}
# {'artist': 'Beyonce', 'title': 'Break My Soul', 'label': 0}
# {'artist': 'The Weeknd Featuring Daft Punk', 'title': 'Starboy', 'label': 0}
# {'artist': 'Fleetwood Mac', 'title': 'Dreams', 'label': 0}
# {'artist': 'Fireboy DML & Ed Sheeran', 'title': 'Peru', 'label': 0}
# {'artist': 'The Weeknd & Ariana Grande', 'title': 'Die For You', 'label': 0}
# {'artist': 'Rosalia', 'title': 'Despecha', 'label': 0}
# {'artist': 'Billie Eilish', 'title': 'Bad Guy', 'label': 0}
# {'artist': 'Charlie Puth Featuring Jung Kook', 'title': 'Left And Right', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Despues de La Playa', 'label': 0}
# {'artist': 'Nicky Youre & dazy', 'title': 'Sunroof', 'label': 0}
# {'artist': 'Silk Sonic (Bruno Mars & Anderson .Paak)', 'title': 'Leave The Door Open', 'label': 0}
# {'artist': 'Adele', 'title': 'Oh My God', 'label': 0}
# {'artist': 'Charlie Puth', 'title': 'Light Switch', 'label': 0}
# {'artist': 'Olivia Rodrigo', 'title': 'Deja Vu', 'label': 0}
# {'artist': 'Hozier', 'title': 'Take Me To Church', 'label': 0}
# {'artist': "Guns N' Roses", 'title': "Sweet Child O' Mine", 'label': 0}
# {'artist': 'Sia', 'title': 'Unstoppable', 'label': 0}
# {'artist': 'Vance Joy', 'title': 'Riptide', 'label': 0}
# {'artist': 'Eminem', 'title': 'The Real Slim Shady', 'label': 0}
# {'artist': 'The Killers', 'title': 'Mr. Brightside', 'label': 0}
# {'artist': 'Latto', 'title': 'Big Energy', 'label': 0}
# {'artist': 'Eminem', 'title': 'Lose Yourself', 'label': 0}
# {'artist': 'Bad Bunny & Tony Dize', 'title': 'La Corriente', 'label': 0}
# {'artist': 'Stephen Sanchez', 'title': 'Until I Found You', 'label': 0}
# {'artist': 'Cris Mj', 'title': 'Una Noche En Medellin', 'label': 0}
# {'artist': 'Rema & Selena Gomez', 'title': 'Calm Down', 'label': 0}
# {'artist': 'Jessica Darrow', 'title': 'Surface Pressure', 'label': 0}
# {'artist': 'Nicki Minaj', 'title': 'Super Freaky Girl', 'label': 0}
# {'artist': 'Masked Wolf', 'title': 'Astronaut In The Ocean', 'label': 0}
# {'artist': 'Doja Cat', 'title': 'Vegas', 'label': 0}
# {'artist': 'Polima WestCoast Featuring Pailita', 'title': 'Ultra Solo', 'label': 0}
# {'artist': 'Zach Bryan', 'title': 'Something In The Orange', 'label': 0}
# {'artist': '50 Cent', 'title': 'In Da Club', 'label': 0}
# {'artist': 'Eagles', 'title': 'Hotel California', 'label': 0}
# {'artist': 'Rosa Linn', 'title': 'Snap', 'label': 0}
# {'artist': 'Arctic Monkeys', 'title': '505', 'label': 0}
# {'artist': 'Morgan Wallen', 'title': 'You Proof', 'label': 0}
# {'artist': 'Drake Featuring 21 Savage & Project Pat', 'title': 'Knife Talk', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Un Ratito', 'label': 0}
# {'artist': 'Wham!', 'title': 'Last Christmas', 'label': 0}
# {'artist': 'a-ha', 'title': 'Take On Me', 'label': 0}
# {'artist': 'Doja Cat & The Weeknd', 'title': 'You Right', 'label': 0}
# {'artist': 'THE ANXIETY: WILLOW & Tyler Cole', 'title': 'Meet Me At Our Spot', 'label': 0}
# {'artist': 'Swedish House Mafia & The Weeknd', 'title': 'Moth To A Flame', 'label': 0}
# {'artist': 'Journey', 'title': "Don't Stop Believin'", 'label': 0}
# {'artist': 'Tate McRae', 'title': "She's All I Wanna Be", 'label': 0}
# {'artist': 'Dove Cameron', 'title': 'Boyfriend', 'label': 0}
# {'artist': 'Gunna & Future Featuring Young Thug', 'title': 'Pushin P', 'label': 0}
# {'artist': 'The Walters', 'title': 'I Love You So', 'label': 0}
# {'artist': 'AC/DC', 'title': 'Thunderstruck', 'label': 0}
# {'artist': '24kGoldn Featuring iann dior', 'title': 'Mood', 'label': 0}
# {'artist': 'Silk Sonic (Bruno Mars & Anderson .Paak)', 'title': 'Smokin Out The Window', 'label': 0}
# {'artist': 'Ed Sheeran Featuring Lil Baby', 'title': '2step', 'label': 0}
# {'artist': 'Calvin Harris & Dua Lipa', 'title': 'One Kiss', 'label': 0}
# {'artist': 'Luis Fonsi & Daddy Yankee Featuring Justin Bieber', 'title': 'Despacito', 'label': 0}
# {'artist': 'The Chainsmokers Featuring Halsey', 'title': 'Closer', 'label': 0}
# {'artist': 'Brenda Lee', 'title': "Rockin' Around The Christmas Tree", 'label': 0}
# {'artist': 'Burna Boy', 'title': 'Last Last', 'label': 0}
# {'artist': 'Lisa', 'title': 'Money', 'label': 0}
# {'artist': 'James Hype & Miggy Dela Rosa', 'title': 'Ferrari', 'label': 0}
# {'artist': 'Rauw Alejandro', 'title': 'Todo de Ti', 'label': 0}
# {'artist': 'IVE', 'title': 'Love Dive', 'label': 0}
# {'artist': 'Shawn Mendes', 'title': "There's Nothing Holdin' Me Back", 'label': 0}
# {'artist': 'Morgan Wallen', 'title': 'Wasted On You', 'label': 0}
# {'artist': 'Luke Combs', 'title': 'The Kind Of Love We Make', 'label': 0}
# {'artist': 'Beyonce', 'title': 'Cuff It', 'label': 0}
# {'artist': 'Lauren Spencer Smith', 'title': 'Fingers Crossed', 'label': 0}
# {'artist': 'BoyWithUke', 'title': 'Toxic', 'label': 0}
# {'artist': 'Bobby Helms', 'title': 'Jingle Bell Rock', 'label': 0}
# {'artist': 'Paloma Faith', 'title': 'Only Love Can Hurt Like This', 'label': 0}
# {'artist': 'SZA', 'title': 'I Hate U', 'label': 0}
# {'artist': 'The Police', 'title': 'Every Breath You Take', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Un Coco', 'label': 0}
# {'artist': 'Walker Hayes', 'title': 'Fancy Like', 'label': 0}
# {'artist': 'Bad Bunny & Buscabulla', 'title': 'Andrea', 'label': 0}
# {'artist': 'J Balvin & Bad Bunny', 'title': 'La Cancion', 'label': 0}
# {'artist': 'BTS', 'title': 'Permission To Dance', 'label': 0}
# {'artist': 'The Weeknd', 'title': 'The Hills', 'label': 0}
# {'artist': 'Central Cee', 'title': 'Doja', 'label': 0}
# {'artist': 'Lady Gaga', 'title': 'Hold My Hand', 'label': 0}
# {'artist': 'Aventura x Bad Bunny', 'title': 'Volvi', 'label': 0}
# {'artist': 'BLACKPINK', 'title': 'Shut Down', 'label': 0}
# {'artist': 'The Weeknd', 'title': 'Take My Breath', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Dos Mil 16', 'label': 0}
# {'artist': 'Sebastian Yatra', 'title': 'Tacones Rojos', 'label': 0}
# {'artist': 'NEIKED X Mae Muller X Polo G', 'title': 'Better Days', 'label': 0}
# {'artist': 'Marshmello & Khalid', 'title': 'Numb', 'label': 0}
# {'artist': 'Megan Thee Stallion & Dua Lipa', 'title': 'Sweetest Pie', 'label': 0}
# {'artist': 'zzoilo', 'title': 'Mon Amour', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Yo No Soy Celoso', 'label': 0}
# {'artist': 'Bailey Zimmerman', 'title': 'Rock And A Hard Place', 'label': 0}
# {'artist': 'The Weeknd', 'title': 'Sacrifice', 'label': 0}
# {'artist': 'Blessd, Justin Quiles & Lenny Tavarez', 'title': 'Medallo', 'label': 0}
# {'artist': 'Sebastian Yatra', 'title': 'Dos Oruguitas', 'label': 0}
# {'artist': 'Ariana Grande', 'title': 'Santa Tell Me', 'label': 0}
# {'artist': 'Aimer', 'title': 'Zankyosanka', 'label': 0}
# {'artist': 'Willow Smith', 'title': 'Wait A Minute!', 'label': 0}
# {'artist': 'Imagine Dragons', 'title': 'Thunder', 'label': 0}
# {'artist': 'Michael Jackson', 'title': 'Billie Jean', 'label': 0}
# {'artist': 'Stephanie Beatriz, Olga Merediz & Encanto Cast', 'title': 'The Family Madrigal', 'label': 0}
# {'artist': 'Michael Buble', 'title': "It's Beginning To Look A Lot Like Christmas", 'label': 0}
# {'artist': 'Doja Cat', 'title': 'Get Into It (Yuh)', 'label': 0}
# {'artist': 'Dua Lipa', 'title': 'Levitating', 'label': 0}
# {'artist': 'The Weeknd & Ariana Grande', 'title': 'Save Your Tears', 'label': 0}
# {'artist': 'The Weeknd', 'title': 'Blinding Lights', 'label': 0}
# {'artist': 'Olivia Rodrigo', 'title': 'Drivers License', 'label': 0}
# {'artist': 'BTS', 'title': 'Dynamite', 'label': 0}
# {'artist': 'Bad Bunny & Jhay Cortez', 'title': 'Dakiti', 'label': 0}
# {'artist': 'Lil Nas X', 'title': 'Montero (Call Me By Your Name)', 'label': 0}
# {'artist': 'The Kid LAROI & Justin Bieber', 'title': 'Stay', 'label': 0}
# {'artist': 'Olivia Rodrigo', 'title': 'Good 4 U', 'label': 0}
# {'artist': '24kGoldn Featuring iann dior', 'title': 'Mood', 'label': 0}
# {'artist': 'Justin Bieber Featuring Daniel Caesar & Giveon', 'title': 'Peaches', 'label': 0}
# {'artist': 'BTS', 'title': 'Butter', 'label': 0}
# {'artist': 'Doja Cat Featuring SZA', 'title': 'Kiss Me More', 'label': 0}
# {'artist': 'Masked Wolf', 'title': 'Astronaut In The Ocean', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Bad Habits', 'label': 0}
# {'artist': 'Silk Sonic (Bruno Mars & Anderson .Paak)', 'title': 'Leave The Door Open', 'label': 0}
# {'artist': 'Glass Animals', 'title': 'Heat Waves', 'label': 0}
# {'artist': 'The Kid LAROI', 'title': 'Without You', 'label': 0}
# {'artist': 'Ariana Grande', 'title': 'Positions', 'label': 0}
# {'artist': 'Tiesto', 'title': 'The Business', 'label': 0}
# {'artist': 'Ariana Grande', 'title': '34+35', 'label': 0}
# {'artist': 'Tones And I', 'title': 'Dance Monkey', 'label': 0}
# {'artist': 'Harry Styles', 'title': 'Watermelon Sugar', 'label': 0}
# {'artist': 'Maluma', 'title': 'Hawai', 'label': 0}
# {'artist': 'Maneskin', 'title': "Beggin'", 'label': 0}
# {'artist': 'Lil Nas X & Jack Harlow', 'title': 'Industry Baby', 'label': 0}
# {'artist': 'Olivia Rodrigo', 'title': 'Deja Vu', 'label': 0}
# {'artist': 'Lewis Capaldi', 'title': 'Someone You Loved', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Perfect', 'label': 0}
# {'artist': 'Dua Lipa', 'title': "Don't Start Now", 'label': 0}
# {'artist': 'Internet Money & Gunna Featuring Don Toliver & NAV', 'title': 'Lemonade', 'label': 0}
# {'artist': 'Travis Scott & HVME', 'title': 'Goosebumps', 'label': 0}
# {'artist': 'Rauw Alejandro', 'title': 'Todo de Ti', 'label': 0}
# {'artist': 'Tate McRae', 'title': 'You Broke Me First.', 'label': 0}
# {'artist': 'SAINt JHN', 'title': 'Roses', 'label': 0}
# {'artist': 'Doja Cat', 'title': 'Streets', 'label': 0}
# {'artist': 'Jawsh 685 x Jason Derulo', 'title': 'Savage Love (Laxed - Siren Beat)', 'label': 0}
# {'artist': 'Joel Corry X MNEK', 'title': 'Head & Heart', 'label': 0}
# {'artist': 'Giveon', 'title': 'Heartbreak Anniversary', 'label': 0}
# {'artist': 'Pop Smoke Featuring Lil Baby & DaBaby', 'title': 'For The Night', 'label': 0}
# {'artist': 'Post Malone & Swae Lee', 'title': 'Sunflower (Spider-Man: Into The Spider-Verse)', 'label': 0}
# {'artist': 'Cardi B Featuring Megan Thee Stallion', 'title': 'WAP', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Yonaguni', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Shape Of You', 'label': 0}
# {'artist': 'Bad Bunny & Rosalia', 'title': 'La Noche de Anoche', 'label': 0}
# {'artist': 'DaBaby Featuring Roddy Ricch', 'title': 'Rockstar', 'label': 0}
# {'artist': 'Polo G', 'title': 'Rapstar', 'label': 0}
# {'artist': 'Pinkfong', 'title': 'Baby Shark', 'label': 0}
# {'artist': 'Riton X Nightcrawlers Featuring Mufasa & Hypeman', 'title': 'Friday', 'label': 0}
# {'artist': 'Los Legendarios, Wisin & Jhay Cortez', 'title': 'Fiel', 'label': 0}
# {'artist': 'Pop Smoke', 'title': 'What You Know Bout Love', 'label': 0}
# {'artist': 'CJ', 'title': 'Whoopty', 'label': 0}
# {'artist': 'Imagine Dragons', 'title': 'Believer', 'label': 0}
# {'artist': 'Cardi B', 'title': 'Up', 'label': 0}
# {'artist': 'YOASOBI', 'title': 'Yoru Ni Kakeru', 'label': 0}
# {'artist': 'Billie Eilish', 'title': 'Therefore I Am', 'label': 0}
# {'artist': 'Nio Garcia X J Balvin X Bad Bunny', 'title': 'AM', 'label': 0}
# {'artist': 'Billie Eilish', 'title': 'Bad Guy', 'label': 0}
# {'artist': 'Olivia Rodrigo', 'title': 'Traitor', 'label': 0}
# {'artist': 'Lewis Capaldi', 'title': 'Before You Go', 'label': 0}
# {'artist': 'Post Malone', 'title': 'Circles', 'label': 0}
# {'artist': 'Karol G', 'title': 'Bichota', 'label': 0}
# {'artist': 'Lady Gaga & Bradley Cooper', 'title': 'Shallow', 'label': 0}
# {'artist': 'Fleetwood Mac', 'title': 'Dreams', 'label': 0}
# {'artist': 'The Neighbourhood', 'title': 'Sweater Weather', 'label': 0}
# {'artist': 'Nathan Evans', 'title': 'Wellerman', 'label': 0}
# {'artist': 'Jack Harlow Featuring DaBaby, Tory Lanez & Lil Wayne', 'title': 'Whats Poppin', 'label': 0}
# {'artist': 'Doja Cat', 'title': 'Need To Know', 'label': 0}
# {'artist': 'Billie Eilish & Khalid', 'title': 'Lovely', 'label': 0}
# {'artist': 'Farruko', 'title': 'Pepas', 'label': 0}
# {'artist': 'BTS', 'title': 'Permission To Dance', 'label': 0}
# {'artist': 'Maroon 5 Featuring Megan Thee Stallion', 'title': 'Beautiful Mistakes', 'label': 0}
# {'artist': 'Myke Towers & Juhn', 'title': 'Bandido', 'label': 0}
# ...
# {'artist': 'Nirvana', 'title': 'Smells Like Teen Spirit', 'label': 0}
# {'artist': 'Marshmello & Manuel Turizo', 'title': 'El Merengue', 'label': 0}
# {'artist': '(G)I-DLE', 'title': 'Queencard', 'label': 0}
# {'artist': 'Karol G', 'title': 'Amargura', 'label': 0}
# {'artist': 'Imagine Dragons', 'title': 'Thunder', 'label': 0}
# {'artist': 'Chino Pacas', 'title': 'El Gordo Trae El Mando', 'label': 0}
# {'artist': 'Karol G & Peso Pluma', 'title': 'Qlona', 'label': 0}
# {'artist': 'Radiohead', 'title': 'Creep', 'label': 0}
# {'artist': 'Fuerza Regida', 'title': 'Sabor Fresa', 'label': 0}
# {'artist': 'Loreen', 'title': 'Tattoo', 'label': 0}
# {'artist': 'Fuerza Regida X Natanael Cano', 'title': 'Ch y La Pizza', 'label': 0}
# {'artist': 'Sabrina Carpenter', 'title': 'Nonsense', 'label': 0}
# {'artist': 'SZA', 'title': 'Shirt', 'label': 0}
# {'artist': 'LE SSERAFIM', 'title': 'Antifragile', 'label': 0}
# {'artist': 'Metro Boomin, Travis Scott & Young Thug', 'title': 'Trance', 'label': 0}
# {'artist': 'Eladio Carrion & Bad Bunny', 'title': 'Coco Chanel', 'label': 0}
# {'artist': 'Peggy Gou', 'title': '(It Goes Like) Nanana', 'label': 0}
# {'artist': 'Peso Pluma & Grupo Frontera', 'title': 'Tulum', 'label': 0}
# {'artist': 'Harry Styles', 'title': 'Late Night Talking', 'label': 0}
# {'artist': 'BLACKPINK', 'title': 'Shut Down', 'label': 0}
# {'artist': 'Carin Leon', 'title': 'Primera Cita', 'label': 0}
# {'artist': 'Billie Eilish', 'title': 'Happier Than Ever', 'label': 0}
# {'artist': 'Feid', 'title': 'Chorrito Pa Las Animas', 'label': 0}
# {'artist': 'Joji', 'title': 'Glimpse Of Us', 'label': 0}
# {'artist': 'Doechii Featuring Kodak Black', 'title': 'What It Is (Block Boy)', 'label': 0}
# {'artist': 'Ariana Grande', 'title': 'Santa Tell Me', 'label': 0}
# {'artist': 'Official HIGE DANdism', 'title': 'Subtitle', 'label': 0}
# {'artist': 'Lizzo', 'title': 'About Damn Time', 'label': 0}
# {'artist': 'NewJeans', 'title': 'ETA', 'label': 0}
# {'artist': 'DENNIS E MC Kevin O Chris, Maluma & Karol G', 'title': 'Ta OK', 'label': 0}
# {'artist': 'Shakira + Ozuna', 'title': 'Monotonia', 'label': 0}
# {'artist': 'Karol G x Romeo Santos', 'title': 'X Si Volvemos', 'label': 0}
# {'artist': 'Miley Cyrus', 'title': 'Flowers', 'label': 0}
# {'artist': 'Rema & Selena Gomez', 'title': 'Calm Down', 'label': 0}
# {'artist': 'SZA', 'title': 'Kill Bill', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Anti-Hero', 'label': 0}
# {'artist': 'The Weeknd & Ariana Grande', 'title': 'Die For You', 'label': 0}
# {'artist': 'Harry Styles', 'title': 'As It Was', 'label': 0}
# {'artist': 'Sam Smith & Kim Petras', 'title': 'Unholy', 'label': 0}
# {'artist': 'David Guetta & Bebe Rexha', 'title': "I'm Good (Blue)", 'label': 0}
# {'artist': 'Metro Boomin, The Weeknd & 21 Savage', 'title': "Creepin'", 'label': 0}
# {'artist': 'Morgan Wallen', 'title': 'Last Night', 'label': 0}
# {'artist': 'Yng Lvcas x Peso Pluma', 'title': 'La Bebe', 'label': 0}
# {'artist': 'Eslabon Armado X Peso Pluma', 'title': 'Ella Baila Sola', 'label': 0}
# {'artist': 'Stephen Sanchez', 'title': 'Until I Found You', 'label': 0}
# {'artist': 'OneRepublic', 'title': "I Ain't Worried", 'label': 0}
# {'artist': 'The Weeknd & Ariana Grande', 'title': 'Save Your Tears', 'label': 0}
# {'artist': 'Tom Odell', 'title': 'Another Love', 'label': 0}
# {'artist': 'Jung Kook Featuring Latto', 'title': 'Seven', 'label': 0}
# {'artist': 'Karol G x Shakira', 'title': 'TQG', 'label': 0}
# {'artist': 'Manuel Turizo', 'title': 'La Bachata', 'label': 0}
# {'artist': 'Fifty Fifty', 'title': 'Cupid', 'label': 0}
# {'artist': 'JVKE', 'title': 'Golden Hour', 'label': 0}
# {'artist': 'Bizarrap & Shakira', 'title': 'Bzrp Music Sessions, Vol. 53', 'label': 0}
# {'artist': 'RAYE Featuring 070 Shake', 'title': 'Escapism', 'label': 0}
# {'artist': 'Chris Brown', 'title': 'Under The Influence', 'label': 0}
# {'artist': 'Grupo Frontera X Bad Bunny', 'title': 'Un x100to', 'label': 0}
# {'artist': 'PinkPantheress & Ice Spice', 'title': "Boy's A Liar, Pt. 2", 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Cruel Summer', 'label': 0}
# {'artist': 'Zach Bryan', 'title': 'Something In The Orange', 'label': 0}
# {'artist': 'The Weeknd', 'title': 'Blinding Lights', 'label': 0}
# {'artist': 'Glass Animals', 'title': 'Heat Waves', 'label': 0}
# {'artist': 'SZA', 'title': 'Snooze', 'label': 0}
# {'artist': 'Bad Bunny & Chencho Corleone', 'title': 'Me Porto Bonito', 'label': 0}
# {'artist': 'Miguel', 'title': 'Sure Thing', 'label': 0}
# {'artist': 'Drake & 21 Savage', 'title': 'Rich Flex', 'label': 0}
# {'artist': 'Dua Lipa', 'title': 'Levitating', 'label': 0}
# {'artist': 'The Weeknd Featuring Daft Punk', 'title': 'Starboy', 'label': 0}
# {'artist': 'The Kid LAROI & Justin Bieber', 'title': 'Stay', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Perfect', 'label': 0}
# {'artist': 'Elton John & Dua Lipa', 'title': 'Cold Heart (PNAU Remix)', 'label': 0}
# {'artist': 'Bizarrap & Quevedo', 'title': 'Bzrp Music Sessions, Vol. 52', 'label': 0}
# {'artist': 'NewJeans', 'title': 'OMG', 'label': 0}
# {'artist': 'YOASOBI', 'title': 'Idol', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Shivers', 'label': 0}
# {'artist': 'Beyonce', 'title': 'Cuff It', 'label': 0}
# {'artist': 'The Neighbourhood', 'title': 'Sweater Weather', 'label': 0}
# {'artist': 'David Kushner', 'title': 'Daylight', 'label': 0}
# {'artist': 'Post Malone & Swae Lee', 'title': 'Sunflower (Spider-Man: Into The Spider-Verse)', 'label': 0}
# {'artist': 'Eminem', 'title': 'Mockingbird', 'label': 0}
# {'artist': 'Lewis Capaldi', 'title': 'Someone You Loved', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Titi Me Pregunto', 'label': 0}
# {'artist': 'Libianca', 'title': 'People', 'label': 0}
# {'artist': 'NewJeans', 'title': 'Ditto', 'label': 0}
# {'artist': 'Yandel & Feid', 'title': 'Yandel 150', 'label': 0}
# {'artist': 'Ozuna Featuring Feid', 'title': 'Hey Mor', 'label': 0}
# {'artist': 'Imagine Dragons', 'title': 'Bones', 'label': 0}
# {'artist': 'Arctic Monkeys', 'title': 'I Wanna Be Yours', 'label': 0}
# {'artist': 'Meghan Trainor', 'title': 'Made You Look', 'label': 0}
# {'artist': 'Luke Combs', 'title': 'Fast Car', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Bad Habits', 'label': 0}
# {'artist': 'Imagine Dragons', 'title': 'Believer', 'label': 0}
# {'artist': 'Jimin', 'title': 'Like Crazy', 'label': 0}
# {'artist': 'Bad Bunny & Bomba Estereo', 'title': 'Ojitos Lindos', 'label': 0}
# {'artist': 'Dua Lipa', 'title': 'Dance The Night', 'label': 0}
# {'artist': 'Coldplay', 'title': 'Viva La Vida', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Shape Of You', 'label': 0}
# {'artist': 'Olivia Rodrigo', 'title': 'Vampire', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Blank Space', 'label': 0}
# {'artist': 'Feid x Young Miko', 'title': 'Classy 101', 'label': 0}
# {'artist': 'Sia', 'title': 'Unstoppable', 'label': 0}
# {'artist': 'Coldplay', 'title': 'Yellow', 'label': 0}
# {'artist': 'Morgan Wallen', 'title': 'You Proof', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Lavender Haze', 'label': 0}
# {'artist': 'Rosa Linn', 'title': 'Snap', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Where She Goes', 'label': 0}
# {'artist': 'Drake Featuring 21 Savage', 'title': 'Jimmy Cooks', 'label': 0}
# {'artist': 'Myke Towers', 'title': 'LaLa', 'label': 0}
# {'artist': 'Lana Del Rey vs. Cedric Gervais', 'title': 'Summertime Sadness', 'label': 0}
# {'artist': 'Carin Leon X Grupo Frontera', 'title': 'Que Vuelvas', 'label': 0}
# {'artist': 'Lil Uzi Vert', 'title': 'Just Wanna Rock', 'label': 0}
# {'artist': 'Metro Boomin, Future & Chris Brown', 'title': 'Superhero (Heroes & Villains)', 'label': 0}
# {'artist': 'Steve Lacy', 'title': 'Bad Habit', 'label': 0}
# {'artist': 'Doja Cat', 'title': 'Paint The Town Red', 'label': 0}
# {'artist': 'Eminem', 'title': 'Without Me', 'label': 0}
# {'artist': 'Gunna', 'title': 'Fukumean', 'label': 0}
# {'artist': 'Billie Eilish & Khalid', 'title': 'Lovely', 'label': 0}
# {'artist': 'Arcangel & Bad Bunny', 'title': 'La Jumpa', 'label': 0}
# {'artist': 'Hotel Ugly', 'title': 'Shut Up My Moms Calling', 'label': 0}
# {'artist': 'Taylor Swift Featuring Ice Spice', 'title': 'Karma', 'label': 0}
# {'artist': 'Pinkfong', 'title': 'Baby Shark', 'label': 0}
# {'artist': 'Peso Pluma', 'title': 'Por Las Noches', 'label': 0}
# {'artist': 'J. Cole', 'title': 'No Role Modelz', 'label': 0}
# {'artist': 'Rosalia & Rauw Alejandro', 'title': 'Beso', 'label': 0}
# {'artist': 'Peso Pluma X Natanael Cano', 'title': 'PRC', 'label': 0}
# {'artist': 'Tears For Fears', 'title': 'Everybody Wants To Rule The World', 'label': 0}
# {'artist': 'Mariah Carey', 'title': 'All I Want For Christmas Is You', 'label': 0}
# {'artist': 'OneRepublic', 'title': 'Counting Stars', 'label': 0}
# {'artist': 'Oliver Tree & Robin Schulz', 'title': 'Miss You', 'label': 0}
# {'artist': 'Dave & Central Cee', 'title': 'Sprinter', 'label': 0}
# {'artist': 'Junior H x Peso Pluma', 'title': 'El Azul', 'label': 0}
# {'artist': 'd4vd', 'title': 'Here With Me', 'label': 0}
# {'artist': 'Vance Joy', 'title': 'Riptide', 'label': 0}
# {'artist': 'Fuerza Regida X Grupo Frontera', 'title': 'Bebe Dame', 'label': 0}
# {'artist': 'Gabito Ballesteros, Peso Pluma & Natanael Cano', 'title': 'AMG', 'label': 0}
# {'artist': 'Hozier', 'title': 'Take Me To Church', 'label': 0}
# {'artist': 'Post Malone', 'title': 'Circles', 'label': 0}
# {'artist': 'Morgan Wallen', 'title': "Thinkin' Bout Me", 'label': 0}
# {'artist': 'Adele', 'title': 'Easy On Me', 'label': 0}
# {'artist': 'Coi Leray', 'title': 'Players', 'label': 0}
# {'artist': 'a-ha', 'title': 'Take On Me', 'label': 0}
# {'artist': 'Lil Durk Featuring J. Cole', 'title': 'All My Life', 'label': 0}
# {'artist': 'Billie Eilish', 'title': 'What Was I Made For?', 'label': 0}
# {'artist': 'Rosalia', 'title': 'Despecha', 'label': 0}
# {'artist': 'Harry Styles', 'title': 'Watermelon Sugar', 'label': 0}
# {'artist': 'Feid', 'title': 'Feliz Cumpleanos Ferxxo', 'label': 0}
# {'artist': 'Post Malone', 'title': 'Chemical', 'label': 0}
# {'artist': 'Nicky Youre & dazy', 'title': 'Sunroof', 'label': 0}
# {'artist': 'NewJeans', 'title': 'Super Shy', 'label': 0}
# {'artist': 'Coolio Featuring L.V.', 'title': "Gangsta's Paradise", 'label': 0}
# {'artist': "Guns N' Roses", 'title': "Sweet Child O' Mine", 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Style', 'label': 0}
# {'artist': 'Karol G', 'title': 'Provenza', 'label': 0}
# {'artist': 'Bruno Mars', 'title': 'When I Was Your Man', 'label': 0}
# {'artist': 'Nicki Minaj & Ice Spice With Aqua', 'title': 'Barbie World', 'label': 0}
# {'artist': 'Morgan Wallen', 'title': 'Wasted On You', 'label': 0}
# {'artist': 'David Guetta, Anne-Marie & Coi Leray', 'title': "Baby Don't Hurt Me", 'label': 0}
# {'artist': 'Lady Gaga & Bradley Cooper', 'title': 'Shallow', 'label': 0}
# {'artist': 'Toosii', 'title': 'Favorite Song', 'label': 0}
# {'artist': 'Rihanna', 'title': 'Lift Me Up', 'label': 0}
# {'artist': 'Wham!', 'title': 'Last Christmas', 'label': 0}
# {'artist': 'Adele', 'title': 'Set Fire To The Rain', 'label': 0}
# {'artist': 'Kali Uchis', 'title': 'Moonlight', 'label': 0}
# {'artist': 'Ed Sheeran', 'title': 'Eyes Closed', 'label': 0}
# {'artist': 'Tyler, The Creator Featuring Kali Uchis', 'title': 'See You Again', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Efecto', 'label': 0}
# {'artist': 'Calvin Harris & Ellie Goulding', 'title': 'Miracle', 'label': 0}
# {'artist': 'Ruth B.', 'title': 'Dandelions', 'label': 0}
# {'artist': 'Peso Pluma, Gabito Ballesteros & Junior H', 'title': 'Lady Gaga', 'label': 0}
# {'artist': 'Macklemore & Ryan Lewis Featuring Ray Dalton', 'title': "Can't Hold Us", 'label': 0}
# {'artist': 'Metro Boomin Featuring Don Toliver & Future', 'title': 'Too Many Nights', 'label': 0}
# {'artist': 'Tiesto Featuring Tate McRae', 'title': '10:35', 'label': 0}
# {'artist': 'Grupo Frontera', 'title': 'No Se Va', 'label': 0}
# {'artist': 'Fuerza Regida', 'title': 'TQM', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Shake It Off', 'label': 0}
# {'artist': 'Future Featuring Drake & Tems', 'title': 'Wait For U', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Cardigan', 'label': 0}
# {'artist': 'Brenda Lee', 'title': "Rockin' Around The Christmas Tree", 'label': 0}
# {'artist': 'NewJeans', 'title': 'Hype Boy', 'label': 0}
# {'artist': 'Drake', 'title': 'Search & Rescue', 'label': 0}
# {'artist': 'Kenshi Yonezu', 'title': 'Kick Back', 'label': 0}
# {'artist': 'Yahritza y Su Esencia x Grupo Frontera', 'title': 'Fragil', 'label': 0}
# {'artist': 'Bizarrap & Peso Pluma', 'title': 'Bzrp Music Sessions, Vol. 55', 'label': 0}
# {'artist': 'IVE', 'title': 'I Am', 'label': 0}
# {'artist': 'Taylor Swift', 'title': 'Lover', 'label': 0}
# {'artist': 'Bailey Zimmerman', 'title': 'Rock And A Hard Place', 'label': 0}
# {'artist': 'The Police', 'title': 'Every Breath You Take', 'label': 0}
# {'artist': 'The Weeknd, Playboi Carti & Madonna', 'title': 'Popular', 'label': 0}
# {'artist': 'Fleetwood Mac', 'title': 'Dreams', 'label': 0}
# {'artist': 'The Chainsmokers & Coldplay', 'title': 'Something Just Like This', 'label': 0}
# {'artist': 'Quevedo', 'title': 'Columbia', 'label': 0}
# {'artist': 'Jisoo', 'title': 'Flower', 'label': 0}
# {'artist': 'Taylor Swift', 'title': "Don't Blame Me", 'label': 0}
# {'artist': 'Junior H X Oscar Maydon', 'title': 'Fin de Semana', 'label': 0}
# {'artist': 'd4vd', 'title': 'Romantic Homicide', 'label': 0}
# {'artist': 'Imagine Dragons X JID', 'title': 'Enemy', 'label': 0}
# {'artist': 'Bobby Helms', 'title': 'Jingle Bell Rock', 'label': 0}
# {'artist': 'Kendrick Lamar Featuring Jay Rock', 'title': 'Money Trees', 'label': 0}
# {'artist': 'Lady Gaga', 'title': 'Bloody Mary', 'label': 0}
# {'artist': 'Bad Bunny', 'title': 'Moscow Mule', 'label': 0}
# {'artist': 'Nirvana', 'title': 'Smells Like Teen Spirit', 'label': 0}
# {'artist': 'Marshmello & Manuel Turizo', 'title': 'El Merengue', 'label': 0}
# {'artist': '(G)I-DLE', 'title': 'Queencard', 'label': 0}
# {'artist': 'Karol G', 'title': 'Amargura', 'label': 0}
# {'artist': 'Imagine Dragons', 'title': 'Thunder', 'label': 0}
# {'artist': 'Chino Pacas', 'title': 'El Gordo Trae El Mando', 'label': 0}
# {'artist': 'Karol G & Peso Pluma', 'title': 'Qlona', 'label': 0}
# {'artist': 'Radiohead', 'title': 'Creep', 'label': 0}
# {'artist': 'Fuerza Regida', 'title': 'Sabor Fresa', 'label': 0}
# {'artist': 'Loreen', 'title': 'Tattoo', 'label': 0}
# {'artist': 'Fuerza Regida X Natanael Cano', 'title': 'Ch y La Pizza', 'label': 0}
# {'artist': 'Sabrina Carpenter', 'title': 'Nonsense', 'label': 0}
# {'artist': 'SZA', 'title': 'Shirt', 'label': 0}
# {'artist': 'LE SSERAFIM', 'title': 'Antifragile', 'label': 0}
# {'artist': 'Metro Boomin, Travis Scott & Young Thug', 'title': 'Trance', 'label': 0}
# {'artist': 'Eladio Carrion & Bad Bunny', 'title': 'Coco Chanel', 'label': 0}
# {'artist': 'Peggy Gou', 'title': '(It Goes Like) Nanana', 'label': 0}
# {'artist': 'Peso Pluma & Grupo Frontera', 'title': 'Tulum', 'label': 0}
# {'artist': 'Harry Styles', 'title': 'Late Night Talking', 'label': 0}
# {'artist': 'BLACKPINK', 'title': 'Shut Down', 'label': 0}
# {'artist': 'Carin Leon', 'title': 'Primera Cita', 'label': 0}
# {'artist': 'Billie Eilish', 'title': 'Happier Than Ever', 'label': 0}
# {'artist': 'Feid', 'title': 'Chorrito Pa Las Animas', 'label': 0}
# {'artist': 'Joji', 'title': 'Glimpse Of Us', 'label': 0}
# {'artist': 'Doechii Featuring Kodak Black', 'title': 'What It Is (Block Boy)', 'label': 0}
# {'artist': 'Ariana Grande', 'title': 'Santa Tell Me', 'label': 0}
# {'artist': 'Official HIGE DANdism', 'title': 'Subtitle', 'label': 0}
# {'artist': 'Lizzo', 'title': 'About Damn Time', 'label': 0}
# {'artist': 'NewJeans', 'title': 'ETA', 'label': 0}
# {'artist': 'DENNIS E MC Kevin O Chris, Maluma & Karol G', 'title': 'Ta OK', 'label': 0}
# {'artist': 'Shakira + Ozuna', 'title': 'Monotonia', 'label': 0}
# {'artist': 'Karol G x Romeo Santos', 'title': 'X Si Volvemos', 'label': 0}
# C:\Users\Basan\anaconda3\Lib\site-packages\billboard.py:423: UnsupportedYearWarning:
#             2015 is not a supported year-end chart from Billboard.
#             Results may be incomplete, inconsistent, or missing entirely.
#             The min and max supported years for the 'billboard-global-200' chart are 2021 and 2023, respectively.
#
#   warnings.warn(UnsupportedYearWarning(msg))

# %%
global200_df =pd.DataFrame(all_global200_data)
global200_df.head()
# Out:
#                        artist        title  label
# 0                 Miley Cyrus      Flowers      0
# 1         Rema & Selena Gomez    Calm Down      0
# 2                         SZA    Kill Bill      0
# 3                Taylor Swift    Anti-Hero      0
# 4  The Weeknd & Ariana Grande  Die For You      0

# %%
# Dealing with duplicated values
global200_df.duplicated().sum()
# Out:
# 1549

# %%
global200_df = global200_df.drop_duplicates()

# %%
global200_df.duplicated().sum()
# Out:
# 0

# %%
global200_df.count()
# Out:
# artist    451
# title     451
# label     451
# dtype: int64

# %%
# renaming
global200_df.rename(columns={'title': 'Song'}, inplace=True)
global200_df.rename(columns={'artist': 'Artist'}, inplace=True)
global200_df.rename(columns={'label': 'Label'}, inplace=True)

# %%
global200_df.head()
# Out:
#                        Artist         Song  Label
# 0                 Miley Cyrus      Flowers      0
# 1         Rema & Selena Gomez    Calm Down      0
# 2                         SZA    Kill Bill      0
# 3                Taylor Swift    Anti-Hero      0
# 4  The Weeknd & Ariana Grande  Die For You      0

# %%
# Merging the dataframes based on song and artist columns
merged_df = pd.merge(hot100_df, global200_df, on=['Song', 'Artist'], how='left', suffixes=('_hot100', '_global200'))

# Filtering global200_df to include only songs and labels of artists present in hot100_df
filtered_global200_df = global200_df[global200_df['Artist'].isin(hot100_df['Artist']) & 
                                     ~global200_df['Song'].isin(hot100_df['Song'])]

# Concatenating hot100_df with filtered_global200_df
final_df = pd.concat([hot100_df, filtered_global200_df])

# Resetting index of the final dataframe
final_df.reset_index(drop=True, inplace=True)

# Sort the dataframe by the 'Artist' column
final_df = final_df.sort_values(by='Artist')

# Resetting index again after sorting
final_df.reset_index(drop=True, inplace=True)

# Displaying the final dataframe
print(final_df)
# Out:
#                        Song                          Artist  Label
# 0              Break Da Law                       21 Savage      1
# 1         Out For The Night                       21 Savage      1
# 2                       1.5                       21 Savage      1
# 3                     A Lot                       21 Savage      1
# 4    Can't Leave Without It                       21 Savage      1
# ..                      ...                             ...    ...
# 925       Romantic Homicide                            d4vd      1
# 926       I Hate U I Love U  gnash Featuring Olivia O'Brien      1
# 927            Hit The Quan                    iLoveMemphis      1
# 928            Stressed Out               twenty one pilots      1
# 929                Heathens               twenty one pilots      1
#
# [930 rows x 3 columns]

# %%
# Exporting final dataframe into a csv file

final_df.to_csv('billboard_songs_artist.csv', index=False)

# %%
final_df.head()
# Out:
#                      Song     Artist  Label
# 0            Break Da Law  21 Savage      1
# 1       Out For The Night  21 Savage      1
# 2                     1.5  21 Savage      1
# 3                   A Lot  21 Savage      1
# 4  Can't Leave Without It  21 Savage      1

# %%
# Installing pytube library
# !pip install pytube
# Out:
# Requirement already satisfied: pytube in c:\users\basan\anaconda3\lib\site-packages (15.0.0)

# %%
# !pip install pandas youtube-search-python
# Out:
# Requirement already satisfied: pandas in c:\users\basan\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: youtube-search-python in c:\users\basan\anaconda3\lib\site-packages (1.6.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\basan\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\basan\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\basan\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\basan\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: httpx>=0.14.2 in c:\users\basan\anaconda3\lib\site-packages (from youtube-search-python) (0.27.0)
# Requirement already satisfied: anyio in c:\users\basan\anaconda3\lib\site-packages (from httpx>=0.14.2->youtube-search-python) (3.5.0)
# Requirement already satisfied: certifi in c:\users\basan\anaconda3\lib\site-packages (from httpx>=0.14.2->youtube-search-python) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in c:\users\basan\anaconda3\lib\site-packages (from httpx>=0.14.2->youtube-search-python) (1.0.4)
# Requirement already satisfied: idna in c:\users\basan\anaconda3\lib\site-packages (from httpx>=0.14.2->youtube-search-python) (3.4)
# Requirement already satisfied: sniffio in c:\users\basan\anaconda3\lib\site-packages (from httpx>=0.14.2->youtube-search-python) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\basan\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.14.2->youtube-search-python) (0.14.0)
# Requirement already satisfied: six>=1.5 in c:\users\basan\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
from youtubesearchpython import VideosSearch

def get_youtube_url(song, artist):
    # Searching for videos on YouTube using song and artist information
    search_query = f"{song} {artist} official video"
    videos_search = VideosSearch(search_query, limit=1)
    result = videos_search.result()

    # Extracting YouTube URL if found
    if result['result']:
        video_url = result['result'][0]['link']
        return video_url
    else:
        return "Not Found"

def add_youtube_urls_to_csv(csv_file):
    # Loading CSV file
    df = pd.read_csv(csv_file)

    # Creating a new column for YouTube URLs
    df['YouTube_URL'] = ""

    # Iterating through each row of the DataFrame
    for index, row in df.iterrows():
        song = row['Song']
        artist = row['Artist']
        youtube_url = get_youtube_url(song, artist)
        df.at[index, 'YouTube_URL'] = youtube_url

    # Writing the updated DataFrame back to the CSV file
    df.to_csv(csv_file, index=False)

def main():
    csv_file = 'billboard_songs_artist.csv'
    add_youtube_urls_to_csv(csv_file)
    print("YouTube URLs have been added to the CSV file.")

if __name__ == "__main__":
    main()
# Out:
# YouTube URLs have been added to the CSV file.

# %%
from pytube import YouTube
import os

def download_audio(youtube_url, output_dir, filename):
    try:
        yt = YouTube(youtube_url)
        stream = yt.streams.filter(only_audio=True).first()
        if stream:
            stream.download(output_dir, filename=filename)
            return True
        else:
            print(f"No audio stream available for {youtube_url}")
            return False
    except Exception as e:
        print(f"Error downloading audio for {youtube_url}: {e}")
        return False

def download_and_rename_songs(csv_file, output_dir):
    # Loading CSV file
    df = pd.read_csv(csv_file)

    # Creating output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Iterating through each row of the DataFrame
    for index, row in df.iterrows():
        song = row['Song']
        artist = row['Artist']
        youtube_url = row['YouTube_URL']

        # Generating filename
        filename = f"{song}.mp3"

        # Downloading audio and rename file
        if youtube_url:
            success = download_audio(youtube_url, output_dir, filename)
            if success:
                print(f"Downloaded and renamed: {filename}")
            else:
                print(f"Failed to download: {filename}")
        else:
            print(f"No YouTube URL found for {song}")

def main():
    csv_file = 'billboard_songs_artist.csv'
    output_dir = 'downloaded_songs'
    download_and_rename_songs(csv_file, output_dir)
    print("Audio files have been downloaded and renamed.")

if __name__ == "__main__":
    main()
# Out:
# Downloaded and renamed: Break Da Law.mp3
# Downloaded and renamed: Out For The Night.mp3
# Downloaded and renamed: 1.5.mp3
# Downloaded and renamed: A Lot.mp3
# Downloaded and renamed: Can't Leave Without It.mp3
# Downloaded and renamed: Gun Smoke.mp3
# Downloaded and renamed: ASMR.mp3
# Downloaded and renamed: All My Friends.mp3
# Downloaded and renamed: Bank Account.mp3
# Downloaded and renamed: Red Opps.mp3
# Downloaded and renamed: Monster.mp3
# Downloaded and renamed: No Heart.mp3
# Downloaded and renamed: Mr. Right Now.mp3
# Downloaded and renamed: X.mp3
# Downloaded and renamed: Mood.mp3
# Downloaded and renamed: Youngblood.mp3
# Downloaded and renamed: Kooda.mp3
# Downloaded and renamed: Gummo.mp3
# Downloaded and renamed: Look Back At It.mp3
# Downloaded and renamed: Swervin.mp3
# Downloaded and renamed: Demons And Angels.mp3
# Downloaded and renamed: Startender.mp3
# Downloaded and renamed: Plain Jane.mp3
# Downloaded and renamed: Bang!.mp3
# Downloaded and renamed: Do It To It.mp3
# Downloaded and renamed: Tennessee Rain.mp3
# Downloaded and renamed: Oh My God.mp3
# Downloaded and renamed: Easy On Me.mp3
# Downloaded and renamed: Water Under The Bridge.mp3
# Downloaded and renamed: When We Were Young.mp3
# Downloaded and renamed: Set Fire To The Rain.mp3
# Downloaded and renamed: Hello.mp3
# Downloaded and renamed: Scars To Your Beautiful.mp3
# Downloaded and renamed: Here.mp3
# Downloaded and renamed: How Far I'll Go.mp3
# Downloaded and renamed: Heroes (We Could Be).mp3
# Downloaded and renamed: Caroline.mp3
# Downloaded and renamed: Fresh Eyes.mp3
# Downloaded and renamed: Good To Be Alive (Hallelujah).mp3
# Error downloading audio for https://www.youtube.com/watch?v=oZ5cmrz-mrU: [Errno 2] No such file or directory: 'C:\\Users\\Basan\\OneDrive\\Desktop\\project\\downloaded_songs\\Happy Holiday / The Holiday Season.mp3'
# Failed to download: Happy Holiday / The Holiday Season.mp3
# Downloaded and renamed: It's The Most Wonderful Time Of The Year.mp3
# Downloaded and renamed: Yellow Hearts.mp3
# Downloaded and renamed: Ella Quiere Beber.mp3
# Downloaded and renamed: La Jumpa.mp3
# Downloaded and renamed: Imagine.mp3
# Downloaded and renamed: Focus.mp3
# Downloaded and renamed: Positions.mp3
# Downloaded and renamed: Santa Tell Me.mp3
# Downloaded and renamed: Thank U, Next.mp3
# Downloaded and renamed: Breathin.mp3
# Downloaded and renamed: Love Me Harder.mp3
# Downloaded and renamed: 34+35.mp3
# Downloaded and renamed: Side To Side.mp3
# Downloaded and renamed: Roxanne.mp3
# Downloaded and renamed: No Love.mp3
# Downloaded and renamed: How Far I'll Go.mp3
# Downloaded and renamed: Sweet But Psycho.mp3
# Downloaded and renamed: My Head And My Heart.mp3
# Downloaded and renamed: Kings & Queens.mp3
# Downloaded and renamed: Throat Baby (Go Baby).mp3
# Downloaded and renamed: Dynamite.mp3
# Downloaded and renamed: Permission To Dance.mp3
# Downloaded and renamed: Butter.mp3
# Downloaded and renamed: MIC Drop.mp3
# Downloaded and renamed: Family Ties.mp3
# Downloaded and renamed: Vete.mp3
# Downloaded and renamed: Yo No Soy Celoso.mp3
# Downloaded and renamed: Dos Mil 16.mp3
# Downloaded and renamed: Moscow Mule.mp3
# Downloaded and renamed: Where She Goes.mp3
# Downloaded and renamed: Monaco.mp3
# Downloaded and renamed: Neverita.mp3
# Downloaded and renamed: Efecto.mp3
# Downloaded and renamed: Un Ratito.mp3
# Downloaded and renamed: Un Coco.mp3
# Downloaded and renamed: Despues de La Playa.mp3
# Downloaded and renamed: Yonaguni.mp3
# Downloaded and renamed: Titi Me Pregunto.mp3
# Downloaded and renamed: Dakiti.mp3
# Downloaded and renamed: Tarot.mp3
# Downloaded and renamed: MIA.mp3
# Downloaded and renamed: Rock And A Hard Place.mp3
# Downloaded and renamed: Beautiful.mp3
# Downloaded and renamed: Meant To Be.mp3
# Downloaded and renamed: Mayores.mp3
# Error downloading audio for https://www.youtube.com/watch?v=k4YRWT_Aldo: [Errno 2] No such file or directory: 'C:\\Users\\Basan\\OneDrive\\Desktop\\project\\downloaded_songs\\7/11.mp3'
# Failed to download: 7/11.mp3
# Downloaded and renamed: Cuff It.mp3
# Downloaded and renamed: Break My Soul.mp3
# Error downloading audio for https://www.youtube.com/watch?v=IyuUWOnS9BY: [Errno 22] Invalid argument: 'C:\\Users\\Basan\\OneDrive\\Desktop\\project\\downloaded_songs\\***Flawless.mp3'
# Failed to download: ***Flawless.mp3
# Downloaded and renamed: Bounce Back.mp3
# Downloaded and renamed: Play No Games.mp3
# Error downloading audio for https://www.youtube.com/watch?v=ZR_X6PrASho: ZR_X6PrASho is age restricted, and can't be accessed without logging in.
# Failed to download: I Don't F**k With You.mp3
# Downloaded and renamed: Everything I Wanted.mp3
# Downloaded and renamed: Bad Guy.mp3
# Downloaded and renamed: Therefore I Am.mp3
# Downloaded and renamed: Happier Than Ever.mp3
# Downloaded and renamed: Good Days.mp3
# Downloaded and renamed: Low.mp3
# Downloaded and renamed: Blind.mp3
# Downloaded and renamed: Nobody Gets Me.mp3
# Downloaded and renamed: Used.mp3
# Downloaded and renamed: Ghost In The Machine.mp3
# Downloaded and renamed: Hit Different.mp3
# Downloaded and renamed: Feather.mp3
# Downloaded and renamed: Nonsense.mp3
# Downloaded and renamed: Kinfolks.mp3
# Downloaded and renamed: Break Up In A Small Town.mp3
# Downloaded and renamed: Too Good At Goodbyes.mp3
# Downloaded and renamed: I'm Not The Only One.mp3
# Downloaded and renamed: Diamonds.mp3
# Downloaded and renamed: Stay With Me.mp3
# Downloaded and renamed: Unholy.mp3
# Downloaded and renamed: Back To The Streets.mp3
# Downloaded and renamed: Five More Minutes.mp3
# Downloaded and renamed: This Is It.mp3
# Downloaded and renamed: Lose You To Love Me.mp3
# Downloaded and renamed: The Heart Wants What It Wants.mp3
# Downloaded and renamed: Hands To Myself.mp3
# Downloaded and renamed: Same Old Love.mp3
# Downloaded and renamed: Good For You.mp3
# Downloaded and renamed: Wolves.mp3
# Downloaded and renamed: Chantaje.mp3
# Downloaded and renamed: Treat You Better.mp3
# Downloaded and renamed: Mercy.mp3
# Downloaded and renamed: There's Nothing Holdin' Me Back.mp3
# Downloaded and renamed: Stitches.mp3
# Downloaded and renamed: I Know What You Did Last Summer.mp3
# Downloaded and renamed: Senorita.mp3
# Downloaded and renamed: Monster.mp3
# Downloaded and renamed: Lost In Japan.mp3
# Downloaded and renamed: Mo Bamba.mp3
# Downloaded and renamed: Unstoppable.mp3
# Downloaded and renamed: Chandelier.mp3
# Downloaded and renamed: The Greatest.mp3
# Downloaded and renamed: Cheap Thrills.mp3
# Downloaded and renamed: Watch Me.mp3
# Downloaded and renamed: Leave The Door Open.mp3
# Downloaded and renamed: Smokin Out The Window.mp3
# Downloaded and renamed: Where Are U Now.mp3
# Downloaded and renamed: Until I Found You.mp3
# Downloaded and renamed: Just Hold On.mp3
# Downloaded and renamed: Bad Habit.mp3
# Downloaded and renamed: Playing Games.mp3
# Downloaded and renamed: No Love.mp3
# Downloaded and renamed: About The Money.mp3
# Downloaded and renamed: Meet Me At Our Spot.mp3
# Downloaded and renamed: When We.mp3
# Downloaded and renamed: Greedy.mp3
# Downloaded and renamed: You Broke Me First..mp3
# Downloaded and renamed: Exes.mp3
# Downloaded and renamed: She's All I Wanna Be.mp3
# Downloaded and renamed: The Race.mp3
# Downloaded and renamed: Don't Blame Me.mp3
# Downloaded and renamed: Christmas Tree Farm (Old Timey Version).mp3
# Downloaded and renamed: Look What You Made Me Do.mp3
# Downloaded and renamed: Style.mp3
# Error downloading audio for https://www.youtube.com/watch?v=wIft-t-MQuE: [Errno 22] Invalid argument: 'C:\\Users\\Basan\\OneDrive\\Desktop\\project\\downloaded_songs\\...Ready For It?.mp3'
# Failed to download: ...Ready For It?.mp3
# Downloaded and renamed: Cardigan.mp3
# Error downloading audio for https://www.youtube.com/watch?v=tNxUxm3-658: [Errno 22] Invalid argument: "C:\\Users\\Basan\\OneDrive\\Desktop\\project\\downloaded_songs\\Is It Over Now? (Taylor's Version) [From The Vault].mp3"
# Failed to download: Is It Over Now? (Taylor's Version) [From The Vault].mp3
# Downloaded and renamed: Message In A Bottle (Taylor's Version) (From The Vault).mp3
# Downloaded and renamed: Wildest Dreams.mp3
# Downloaded and renamed: Anti-Hero.mp3
# Downloaded and renamed: Shake It Off.mp3
# Downloaded and renamed: You're Losing Me (From The Vault).mp3
# Downloaded and renamed: 'Tis The Damn Season.mp3
# Downloaded and renamed: Lover.mp3
# Downloaded and renamed: Cruel Summer.mp3
# Downloaded and renamed: Willow.mp3
# Downloaded and renamed: Lavender Haze.mp3
# Downloaded and renamed: Blank Space.mp3
# Downloaded and renamed: Champagne Problems.mp3
# Downloaded and renamed: All Too Well (Taylor's Version).mp3
# Downloaded and renamed: End Game.mp3
# Downloaded and renamed: No Body, No Crime.mp3
# Downloaded and renamed: Lose Control.mp3
# Downloaded and renamed: Little Saint Nick.mp3
# Downloaded and renamed: Don't Let Me Down.mp3
# Downloaded and renamed: Closer.mp3
# Downloaded and renamed: This Feeling.mp3
# Downloaded and renamed: All We Know.mp3
# Downloaded and renamed: Roses.mp3
# Downloaded and renamed: Without You.mp3
# Downloaded and renamed: Stay.mp3
# Downloaded and renamed: Sleigh Ride.mp3
# Downloaded and renamed: Can't Feel My Face.mp3
# Downloaded and renamed: Take My Breath.mp3
# Downloaded and renamed: Six Feet Under.mp3
# Downloaded and renamed: Reminder.mp3
# Downloaded and renamed: Blinding Lights.mp3
# Downloaded and renamed: Party Monster.mp3
# Downloaded and renamed: Often.mp3
# Downloaded and renamed: The Hills.mp3
# Downloaded and renamed: In The Night.mp3
# Downloaded and renamed: Sacrifice.mp3
# Downloaded and renamed: Heartless.mp3
# Downloaded and renamed: Save Your Tears.mp3
# Downloaded and renamed: Die For You.mp3
# Downloaded and renamed: I Feel It Coming.mp3
# Downloaded and renamed: Starboy.mp3
# Downloaded and renamed: Sidewalks.mp3
# Downloaded and renamed: Marry Me.mp3
# Downloaded and renamed: Star Of The Show.mp3
# Downloaded and renamed: Sixteen.mp3
# Downloaded and renamed: Remember You Young.mp3
# Downloaded and renamed: Die A Happy Man.mp3
# Downloaded and renamed: Make Me Wanna.mp3
# Downloaded and renamed: You're A Mean One, Mr. Grinch.mp3
# Downloaded and renamed: Top Of The World.mp3
# Downloaded and renamed: How I'll Always Be.mp3
# Downloaded and renamed: Shotgun Rider.mp3
# Downloaded and renamed: Dance Monkey.mp3
# Downloaded and renamed: Hollow.mp3
# Downloaded and renamed: Say It.mp3
# Downloaded and renamed: Talk To Me.mp3
# Downloaded and renamed: Habits (Stay High).mp3
# Downloaded and renamed: Play That Song.mp3
# Downloaded and renamed: Goosebumps.mp3
# Downloaded and renamed: Sicko Mode.mp3
# Downloaded and renamed: Highest In The Room.mp3
# Downloaded and renamed: HIGHEST IN THE ROOM.mp3
# Downloaded and renamed: Antidote.mp3
# Downloaded and renamed: Falling.mp3
# Downloaded and renamed: Touchin, Lovin.mp3
# Downloaded and renamed: Death.mp3
# Downloaded and renamed: Dark Knight Dummo.mp3
# Downloaded and renamed: Blase.mp3
# Downloaded and renamed: Water.mp3
# Downloaded and renamed: I Don't Mind.mp3
# Downloaded and renamed: Good Good.mp3
# Downloaded and renamed: Riptide.mp3
# Downloaded and renamed: On My Mama.mp3
# Downloaded and renamed: Christmastime Is Here.mp3
# Downloaded and renamed: Linus And Lucy (Peanuts Theme).mp3
# Downloaded and renamed: Shut Up And Dance.mp3
# Downloaded and renamed: On Chill.mp3
# Downloaded and renamed: Fancy Like.mp3
# Downloaded and renamed: You Broke Up With Me.mp3
# Downloaded and renamed: Pretty Little Poison.mp3
# Downloaded and renamed: Last Christmas.mp3
# Downloaded and renamed: See You Again.mp3
# Downloaded and renamed: Unsteady.mp3
# Downloaded and renamed: BAD!.mp3
# Error downloading audio for https://www.youtube.com/watch?v=JcWOSgImiRw: [Errno 22] Invalid argument: 'C:\\Users\\Basan\\OneDrive\\Desktop\\project\\downloaded_songs\\F**k Love.mp3'
# Failed to download: F**k Love.mp3
# Downloaded and renamed: Arms Around You.mp3
# Downloaded and renamed: La Diabla.mp3
# Downloaded and renamed: La Victima.mp3
# Downloaded and renamed: Rubbin Off The Paint.mp3
# Downloaded and renamed: 223's.mp3
# Downloaded and renamed: Suicidal.mp3
# Downloaded and renamed: Juice.mp3
# Downloaded and renamed: Down In The DM.mp3
# Downloaded and renamed: OOOUUU.mp3
# Downloaded and renamed: Best Friend.mp3
# Error downloading audio for https://www.youtube.com/watch?v=mZDinQ92OZQ: mZDinQ92OZQ is age restricted, and can't be accessed without logging in.
# Failed to download: Pick Up The Phone.mp3
# Downloaded and renamed: Hot.mp3
# Downloaded and renamed: Bubbly.mp3
# Downloaded and renamed: No Smoke.mp3
# Downloaded and renamed: You're Mines Still.mp3
# Downloaded and renamed: Same Boat.mp3
# Downloaded and renamed: Beautiful Drug.mp3
# Downloaded and renamed: Something In The Orange.mp3
# Downloaded and renamed: I Remember Everything.mp3
# Downloaded and renamed: Hey Driver.mp3
# Downloaded and renamed: Juju On That Beat (TZ Anthem).mp3
# Downloaded and renamed: I Don't Wanna Live Forever (Fifty Shades Darker).mp3
# Downloaded and renamed: Dusk Till Dawn.mp3
# Downloaded and renamed: Eastside.mp3
# Downloaded and renamed: Hot Girl Bummer.mp3
# Downloaded and renamed: Here With Me.mp3
# Downloaded and renamed: Romantic Homicide.mp3
# Downloaded and renamed: I Hate U I Love U.mp3
# Downloaded and renamed: Hit The Quan.mp3
# Downloaded and renamed: Stressed Out.mp3
# Downloaded and renamed: Heathens.mp3
# Audio files have been downloaded and renamed.

# %%
# Installing pychorus
# !pip install pychorus
# Out:
# Requirement already satisfied: pychorus in c:\users\basan\anaconda3\lib\site-packages (0.1)
# Requirement already satisfied: librosa in c:\users\basan\anaconda3\lib\site-packages (from pychorus) (0.10.1)
# Requirement already satisfied: numpy in c:\users\basan\anaconda3\lib\site-packages (from pychorus) (1.24.3)
# Requirement already satisfied: scipy in c:\users\basan\anaconda3\lib\site-packages (from pychorus) (1.11.1)
# Requirement already satisfied: soundfile in c:\users\basan\anaconda3\lib\site-packages (from pychorus) (0.12.1)
# Requirement already satisfied: matplotlib in c:\users\basan\anaconda3\lib\site-packages (from pychorus) (3.7.2)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\basan\anaconda3\lib\site-packages (from librosa->pychorus) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\basan\anaconda3\lib\site-packages (from librosa->pychorus) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in c:\users\basan\anaconda3\lib\site-packages (from librosa->pychorus) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\basan\anaconda3\lib\site-packages (from librosa->pychorus) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\basan\anaconda3\lib\site-packages (from librosa->pychorus) (0.57.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\basan\anaconda3\lib\site-packages (from librosa->pychorus) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\basan\anaconda3\lib\site-packages (from librosa->pychorus) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\basan\anaconda3\lib\site-packages (from librosa->pychorus) (4.7.1)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\basan\anaconda3\lib\site-packages (from librosa->pychorus) (0.2)
# Requirement already satisfied: msgpack>=1.0 in c:\users\basan\anaconda3\lib\site-packages (from librosa->pychorus) (1.0.3)
# Requirement already satisfied: cffi>=1.0 in c:\users\basan\anaconda3\lib\site-packages (from soundfile->pychorus) (1.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\basan\anaconda3\lib\site-packages (from matplotlib->pychorus) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\basan\anaconda3\lib\site-packages (from matplotlib->pychorus) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\basan\anaconda3\lib\site-packages (from matplotlib->pychorus) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\basan\anaconda3\lib\site-packages (from matplotlib->pychorus) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\basan\anaconda3\lib\site-packages (from matplotlib->pychorus) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\basan\anaconda3\lib\site-packages (from matplotlib->pychorus) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\basan\anaconda3\lib\site-packages (from matplotlib->pychorus) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\basan\anaconda3\lib\site-packages (from matplotlib->pychorus) (2.8.2)
# Requirement already satisfied: pycparser in c:\users\basan\anaconda3\lib\site-packages (from cffi>=1.0->soundfile->pychorus) (2.21)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\basan\anaconda3\lib\site-packages (from numba>=0.51.0->librosa->pychorus) (0.40.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\basan\anaconda3\lib\site-packages (from pooch>=1.0->librosa->pychorus) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\basan\anaconda3\lib\site-packages (from pooch>=1.0->librosa->pychorus) (2.31.0)
# Requirement already satisfied: six>=1.5 in c:\users\basan\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->pychorus) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\basan\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa->pychorus) (2.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\basan\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->pychorus) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\basan\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->pychorus) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\basan\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->pychorus) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\basan\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->pychorus) (2023.7.22)

# %%
# !pip install ffmpeg-python
# Out:
# Requirement already satisfied: ffmpeg-python in c:\users\basan\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: future in c:\users\basan\anaconda3\lib\site-packages (from ffmpeg-python) (0.18.3)

# %%
# Installing pydub
# !pip install pydub
# Out:
# Requirement already satisfied: pydub in c:\users\basan\anaconda3\lib\site-packages (0.25.1)

# %%
import os
from pydub import AudioSegment

def extract_chorus(audio_file, output_dir):
    try:
        song = AudioSegment.from_file(audio_file)

        # Assuming the chorus starts at 30 seconds and lasts for 20 seconds
        start_time = 30 * 1000  # Converting to milliseconds
        end_time = start_time + 20 * 1000  # 20 seconds after start time

        chorus = song[start_time:end_time]

        # Saving the chorus
        chorus.export(output_dir, format="mp3")
        return True
    except Exception as e:
        print(f"Error extracting chorus for {audio_file}: {e}")
        return False

def extract_choruses_from_downloaded_songs(input_dir, output_dir):
    # Creating output directory for choruses if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Iterating through each audio file in the input directory
    for audio_file in os.listdir(input_dir):
        if audio_file.endswith(".mp3"):
            try:
                audio_file_path = os.path.join(input_dir, audio_file)

                # Generating filename for the chorus
                chorus_output_file = os.path.join(output_dir, audio_file)

                # Extracting chorus
                chorus_extracted = extract_chorus(audio_file_path, chorus_output_file)
                if chorus_extracted:
                    print(f"Chorus extracted for {audio_file}")
                else:
                    print(f"Failed to extract chorus for {audio_file}")
            except Exception as e:
                print(f"Error processing {audio_file}: {e}")

def main():
    input_dir = 'downloaded_songs'
    output_dir = 'chorus'
    extract_choruses_from_downloaded_songs(input_dir, output_dir)
    print("Choruses have been extracted and saved.")

if __name__ == "__main__":
    main()
# Out:
# Chorus extracted for $ave Dat Money.mp3
# Chorus extracted for 'Til You Can't.mp3
# Chorus extracted for 'Tis The Damn Season.mp3
# Chorus extracted for (There's No Place Like) Home For The Holidays (1954).mp3
# Chorus extracted for (There's No Place Like) Home For The Holidays (1959).mp3
# Chorus extracted for 1 Night.mp3
# Chorus extracted for 1-800-273-8255.mp3
# Chorus extracted for 1.5.mp3
# Chorus extracted for 10,000 Hours.mp3
# Chorus extracted for 223's.mp3
# Chorus extracted for 24K Magic.mp3
# Chorus extracted for 25 Million.mp3
# Chorus extracted for 34+35.mp3
# Chorus extracted for 500lbs.mp3
# Chorus extracted for 679.mp3
# Chorus extracted for 7 Summers.mp3
# Chorus extracted for A Guy With A Girl.mp3
# Chorus extracted for A Holly Jolly Christmas.mp3
# Chorus extracted for A Lot.mp3
# Chorus extracted for abcdefu.mp3
# Chorus extracted for About Damn Time.mp3
# Chorus extracted for About The Money.mp3
# Chorus extracted for Adderall (Corvette Corvette).mp3
# Chorus extracted for Adore You.mp3
# Chorus extracted for Adventure Of A Lifetime.mp3
# Chorus extracted for Afterglow.mp3
# Chorus extracted for Again.mp3
# Chorus extracted for Agora Hills.mp3
# Chorus extracted for Ain't Shit.mp3
# Chorus extracted for All About That Bass.mp3
# Chorus extracted for All I Want For Christmas Is You.mp3
# Chorus extracted for All My Friends.mp3
# Chorus extracted for All Of Me.mp3
# Chorus extracted for All On Me.mp3
# Chorus extracted for All Time Low.mp3
# Chorus extracted for All Too Well (Taylor's Version).mp3
# Chorus extracted for All We Know.mp3
# Chorus extracted for Alone.mp3
# Chorus extracted for Already Dead.mp3
# Chorus extracted for Amargura.mp3
# Chorus extracted for Anaconda.mp3
# Chorus extracted for Animals.mp3
# Chorus extracted for Anti-Hero.mp3
# Chorus extracted for Antidote.mp3
# Chorus extracted for Anyone.mp3
# Chorus extracted for Apparently.mp3
# Chorus extracted for Armed And Dangerous.mp3
# Chorus extracted for Arms Around You.mp3
# Chorus extracted for As It Was.mp3
# Chorus extracted for ASMR.mp3
# Chorus extracted for Attention.mp3
# Chorus extracted for Wow..mp3
# Chorus extracted for Written In The Sand.mp3
# Chorus extracted for WTF (Where They From).mp3
# Chorus extracted for X.mp3
# Chorus extracted for Yellow Flicker Beat.mp3
# Chorus extracted for Yellow Hearts.mp3
# Chorus extracted for Yellow.mp3
# Chorus extracted for Yo No Soy Celoso.mp3
# Chorus extracted for Yonaguni.mp3
# Chorus extracted for You Broke Me First..mp3
# Chorus extracted for You Broke My Heart.mp3
# Chorus extracted for You Broke Up With Me.mp3
# Chorus extracted for You Proof.mp3
# Chorus extracted for You Say.mp3
# Chorus extracted for You Should Be Here.mp3
# Chorus extracted for You Should Probably Leave.mp3
# Chorus extracted for You Was Right.mp3
# Chorus extracted for You're A Mean One, Mr. Grinch.mp3
# Chorus extracted for You're Losing Me (From The Vault).mp3
# Chorus extracted for You're Mines Still.mp3
# Chorus extracted for You're Welcome.mp3
# Chorus extracted for You.mp3
# Chorus extracted for Young Dumb & Broke.mp3
# Chorus extracted for Youngblood.mp3
# Chorus extracted for Yours.mp3
# Chorus extracted for ZEZE.mp3
# Choruses have been extracted and saved.

# %%
# Installing librosa library for extracting audio features
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\basan\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\basan\anaconda3\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\basan\anaconda3\lib\site-packages (from librosa) (1.24.3)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\basan\anaconda3\lib\site-packages (from librosa) (1.11.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\basan\anaconda3\lib\site-packages (from librosa) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in c:\users\basan\anaconda3\lib\site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\basan\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\basan\anaconda3\lib\site-packages (from librosa) (0.57.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\basan\anaconda3\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\basan\anaconda3\lib\site-packages (from librosa) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\basan\anaconda3\lib\site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\basan\anaconda3\lib\site-packages (from librosa) (4.7.1)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\basan\anaconda3\lib\site-packages (from librosa) (0.2)
# Requirement already satisfied: msgpack>=1.0 in c:\users\basan\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\basan\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.40.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\basan\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\basan\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (23.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\basan\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\basan\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\basan\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\basan\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\basan\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\basan\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\basan\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\basan\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.7.22)

# %%
# !pip install --upgrade numpy
# Out:
# Requirement already satisfied: numpy in c:\users\basan\anaconda3\lib\site-packages (1.24.0)
# Collecting numpy
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/3f/6b/5610004206cf7f8e7ad91c5a85a8c71b2f2f8051a0c0c4d5916b76d6cbb2/numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.0
#     Uninstalling numpy-1.24.0:
#       Successfully uninstalled numpy-1.24.0
# Successfully installed numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# tables 3.8.0 requires cython>=0.29.21, which is not installed.
# numba 0.57.1 requires llvmlite<0.41,>=0.40.0dev0, but you have llvmlite 0.42.0 which is incompatible.
# numba 0.57.1 requires numpy<1.25,>=1.21, but you have numpy 1.26.4 which is incompatible.

# %%
pip install --upgrade numba
# Out:
# Requirement already satisfied: numba in c:\users\basan\anaconda3\lib\site-packages (0.57.1)
# Collecting numba
#   Obtaining dependency information for numba from https://files.pythonhosted.org/packages/38/f0/ad848815b0adafcf5f238e728933950034355a8d59969772be1cd57606d8/numba-0.59.1-cp311-cp311-win_amd64.whl.metadata
#   Using cached numba-0.59.1-cp311-cp311-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\basan\anaconda3\lib\site-packages (from numba) (0.42.0)
# Requirement already satisfied: numpy<1.27,>=1.22 in c:\users\basan\anaconda3\lib\site-packages (from numba) (1.26.4)
# Using cached numba-0.59.1-cp311-cp311-win_amd64.whl (2.6 MB)
# Installing collected packages: numba
#   Attempting uninstall: numba
#     Found existing installation: numba 0.57.1
#     Uninstalling numba-0.57.1:
#       Successfully uninstalled numba-0.57.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Basan\\anaconda3\\Lib\\site-packages\\~umba\\core\\runtime\\_nrt_python.cp311-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import os
import librosa

# Creating function to extract audio features using Librosa
def extract_audio_features(file_path):
    # Loading the audio file
    y, sr = librosa.load(file_path)

    # Extracting audio features
    tempo, beats = librosa.beat.beat_track(y=y, sr=sr)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    rmse = librosa.feature.rms(y=y)
    spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    spectral_rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zero_crossing_rate = librosa.feature.zero_crossing_rate(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr)

    # Concatenating and return extracted audio features
    return {
        "file_name": os.path.basename(file_path),
        "tempo": tempo,
        "beats": beats,
        "chroma_stft": chroma_stft.mean(axis=1),
        "rmse": rmse.mean(),
        "spectral_centroid": spectral_centroid.mean(),
        "spectral_bandwidth": spectral_bandwidth.mean(),
        "spectral_rolloff": spectral_rolloff.mean(),
        "zero_crossing_rate": zero_crossing_rate.mean(),
        "mfcc": mfcc.mean(axis=1)
    }

# Creating directory where chorus audio files are stored
audio_folder = "chorus"

# Creating list to store extracted features for all audio files
all_features = []

# Iterating over all chorus audio files in the directory
for file_name in os.listdir(audio_folder):
    if file_name.endswith(".mp3"):
        file_path = os.path.join(audio_folder, file_name)
        print(f"Extracting audio features for: {file_name}")
        features = extract_audio_features(file_path)
        all_features.append(features)

# Converting the collected features into a pandas DataFrame
df = pd.DataFrame(all_features)

# Splitting arrays into separate columns
df = pd.concat([df.drop(['chroma_stft', 'mfcc'], axis=1), df['chroma_stft'].apply(pd.Series).add_prefix('chroma_stft_'),
                df['mfcc'].apply(pd.Series).add_prefix('mfcc_')], axis=1)

# Saving the DataFrame to a CSV file
output_csv = "audio_features.csv"
df.to_csv(output_csv, index=False)

print(f"Audio features saved to: {output_csv}")
# Out:
# Extracting audio features for: $ave Dat Money.mp3
# Extracting audio features for: 'Til You Can't.mp3
# Extracting audio features for: 'Tis The Damn Season.mp3
# Extracting audio features for: (There's No Place Like) Home For The Holidays (1954).mp3
# Extracting audio features for: (There's No Place Like) Home For The Holidays (1959).mp3
# Extracting audio features for: 1 Night.mp3
# Extracting audio features for: 1-800-273-8255.mp3
# Extracting audio features for: 1.5.mp3
# Extracting audio features for: 10,000 Hours.mp3
# Extracting audio features for: 223's.mp3
# Extracting audio features for: 24K Magic.mp3
# Extracting audio features for: 25 Million.mp3
# Extracting audio features for: 34+35.mp3
# Extracting audio features for: 500lbs.mp3
# Extracting audio features for: 679.mp3
# Extracting audio features for: 7 Summers.mp3
# Extracting audio features for: A Guy With A Girl.mp3
# Extracting audio features for: A Holly Jolly Christmas.mp3
# Extracting audio features for: A Lot.mp3
# Extracting audio features for: abcdefu.mp3
# Extracting audio features for: About Damn Time.mp3
# Extracting audio features for: About The Money.mp3
# Extracting audio features for: Adderall (Corvette Corvette).mp3
# Extracting audio features for: Adore You.mp3
# Extracting audio features for: Adventure Of A Lifetime.mp3
# Extracting audio features for: Afterglow.mp3
# Extracting audio features for: Again.mp3
# Extracting audio features for: Agora Hills.mp3
# Extracting audio features for: Ain't Shit.mp3
# Extracting audio features for: All About That Bass.mp3
# Extracting audio features for: All I Want For Christmas Is You.mp3
# Extracting audio features for: All My Friends.mp3
# Extracting audio features for: All Of Me.mp3
# Extracting audio features for: All On Me.mp3
# Extracting audio features for: All Time Low.mp3
# Extracting audio features for: All Too Well (Taylor's Version).mp3
# Extracting audio features for: All We Know.mp3
# Extracting audio features for: Alone.mp3
# Extracting audio features for: Already Dead.mp3
# Extracting audio features for: Amargura.mp3
# Extracting audio features for: Anaconda.mp3
# Extracting audio features for: Animals.mp3
# Extracting audio features for: Anti-Hero.mp3
# Extracting audio features for: Antidote.mp3
# Extracting audio features for: Anyone.mp3
# Extracting audio features for: Apparently.mp3
# Extracting audio features for: Armed And Dangerous.mp3
# Extracting audio features for: Arms Around You.mp3
# Extracting audio features for: As It Was.mp3
# Extracting audio features for: ASMR.mp3
# Extracting audio features for: Attention.mp3
# Extracting audio features for: Baby It's Cold Outside.mp3
# Extracting audio features for: Baby Sitter.mp3
# Extracting audio features for: Back To Back.mp3
# Extracting audio features for: Back To Sleep.mp3
# Extracting audio features for: Back To The Streets.mp3
# Extracting audio features for: Back Up.mp3
# Extracting audio features for: Backdoor.mp3
# Extracting audio features for: Backin' It Up.mp3
# Extracting audio features for: Backroad Song.mp3
# Extracting audio features for: Bad And Boujee.mp3
# Extracting audio features for: Bad At Love.mp3
# Extracting audio features for: Bad Guy.mp3
# Extracting audio features for: Bad Habit.mp3
# Extracting audio features for: Bad Habits.mp3
# Extracting audio features for: Bad Things.mp3
# Extracting audio features for: BAD!.mp3
# Extracting audio features for: Ballin'.mp3
# Extracting audio features for: Bandit.mp3
# Extracting audio features for: Bang Bang.mp3
# Extracting audio features for: Bang!.mp3
# Extracting audio features for: Bank Account.mp3
# Extracting audio features for: Be Alright.mp3
# Extracting audio features for: Beautiful Crazy.mp3
# Extracting audio features for: Beautiful Drug.mp3
# Extracting audio features for: Beautiful.mp3
# Extracting audio features for: Bebe Dame.mp3
# Extracting audio features for: Bed Of Lies.mp3
# Extracting audio features for: Before You Go.mp3
# Extracting audio features for: Beg For It.mp3
# Extracting audio features for: Believe.mp3
# Extracting audio features for: Believer.mp3
# Extracting audio features for: Bellakeo.mp3
# Extracting audio features for: Best Friend.mp3
# Extracting audio features for: BEST ON EARTH.mp3
# Extracting audio features for: Best Shot.mp3
# Extracting audio features for: Betrayed.mp3
# Extracting audio features for: Better Days.mp3
# Extracting audio features for: Better Man.mp3
# Extracting audio features for: Better Now.mp3
# Extracting audio features for: Better Together.mp3
# Extracting audio features for: Better.mp3
# Extracting audio features for: Bichota.mp3
# Extracting audio features for: Big Energy.mp3
# Extracting audio features for: Big Rings.mp3
# Extracting audio features for: Big, Big Plans.mp3
# Extracting audio features for: Black Beatles.mp3
# Extracting audio features for: Black Widow.mp3
# Extracting audio features for: Blame.mp3
# Extracting audio features for: Blank Space.mp3
# Extracting audio features for: Blase.mp3
# Extracting audio features for: Blind.mp3
# Extracting audio features for: Blinding Lights.mp3
# Extracting audio features for: Bloody Mary.mp3
# Extracting audio features for: Blue Ain't Your Color.mp3
# Extracting audio features for: Blue Christmas.mp3
# Extracting audio features for: Bodak Yellow (Money Moves).mp3
# Extracting audio features for: Body Language.mp3
# Extracting audio features for: Body.mp3
# Extracting audio features for: Bones.mp3
# Extracting audio features for: BOP.mp3
# Extracting audio features for: Both.mp3
# Extracting audio features for: Bounce Back.mp3
# Extracting audio features for: Break Da Law.mp3
# Extracting audio features for: Break My Heart.mp3
# Extracting audio features for: Break My Soul.mp3
# Extracting audio features for: Break The Rules.mp3
# Extracting audio features for: Break Up In A Small Town.mp3
# Extracting audio features for: Breathin.mp3
# Extracting audio features for: Broadway Girls.mp3
# Extracting audio features for: Broccoli.mp3
# Extracting audio features for: Brutal.mp3
# Extracting audio features for: Bubbly.mp3
# Extracting audio features for: Burn It Down.mp3
# Extracting audio features for: Burn.mp3
# Extracting audio features for: Burning House.mp3
# Extracting audio features for: Burning Man.mp3
# Extracting audio features for: Butter.mp3
# Extracting audio features for: Buy Dirt.mp3
# Extracting audio features for: By Your Side.mp3
# Extracting audio features for: Cake By The Ocean.mp3
# Extracting audio features for: Calling My Spirit.mp3
# Extracting audio features for: Calm Down.mp3
# Extracting audio features for: Camelot.mp3
# Extracting audio features for: Can't Catch Me Now.mp3
# Extracting audio features for: Can't Feel My Face.mp3
# Extracting audio features for: Can't Leave Without It.mp3
# Extracting audio features for: Can't Stop The Feeling!.mp3
# Extracting audio features for: Candy Paint.mp3
# Extracting audio features for: Candy.mp3
# Extracting audio features for: Cardigan.mp3
# Extracting audio features for: Caroline.mp3
# Extracting audio features for: Centuries.mp3
# Extracting audio features for: Champagne Night.mp3
# Extracting audio features for: Champagne Problems.mp3
# Extracting audio features for: Chandelier.mp3
# Extracting audio features for: Change.mp3
# Extracting audio features for: Chantaje.mp3
# Extracting audio features for: Cheap Thrills.mp3
# Extracting audio features for: Cheerleader.mp3
# Extracting audio features for: Chemical.mp3
# Extracting audio features for: Chill Bill.mp3
# Extracting audio features for: Chosen.mp3
# Extracting audio features for: Christmas (Baby Please Come Home).mp3
# Extracting audio features for: Christmas Isn't Canceled (Just You).mp3
# Extracting audio features for: Christmas Tree Farm (Old Timey Version).mp3
# Extracting audio features for: Christmastime Is Here.mp3
# Extracting audio features for: Circles.mp3
# Extracting audio features for: Circo Loco.mp3
# Extracting audio features for: Climb Every Mountain.mp3
# Extracting audio features for: Close To Me.mp3
# Extracting audio features for: Close Your Eyes.mp3
# Extracting audio features for: Closer.mp3
# Extracting audio features for: CoCo.mp3
# Extracting audio features for: Codeine Dreaming.mp3
# Extracting audio features for: Cold Heart (PNAU Remix).mp3
# Extracting audio features for: Cold Water.mp3
# Extracting audio features for: Come Get Her.mp3
# Extracting audio features for: Confident.mp3
# Extracting audio features for: Consequences.mp3
# Extracting audio features for: Counting Stars.mp3
# Extracting audio features for: Cozy Little Christmas.mp3
# Extracting audio features for: Creepin'.mp3
# Extracting audio features for: Cruel Summer.mp3
# Extracting audio features for: Cry Baby.mp3
# Extracting audio features for: Cuff It.mp3
# Extracting audio features for: Dakiti.mp3
# Extracting audio features for: Damage.mp3
# Extracting audio features for: Dance Monkey.mp3
# Extracting audio features for: Dance The Night.mp3
# Extracting audio features for: Dangerous.mp3
# Extracting audio features for: Dark Knight Dummo.mp3
# Extracting audio features for: Death.mp3
# Extracting audio features for: Deck The Halls.mp3
# Extracting audio features for: Deja Vu.mp3
# Extracting audio features for: Demons And Angels.mp3
# Extracting audio features for: Despacito.mp3
# Extracting audio features for: Despues de La Playa.mp3
# Extracting audio features for: Dessert.mp3
# Extracting audio features for: Diamonds.mp3
# Extracting audio features for: Dibs.mp3
# Extracting audio features for: Die A Happy Man.mp3
# Extracting audio features for: Die For You.mp3
# Extracting audio features for: Dior.mp3
# Extracting audio features for: Dirt On My Boots.mp3
# Extracting audio features for: Dirty Laundry.mp3
# Extracting audio features for: DJ Play A Christmas Song.mp3
# Extracting audio features for: Do It Like Me.mp3
# Extracting audio features for: Do It To It.mp3
# Extracting audio features for: Do You Mind.mp3
# Extracting audio features for: Don't Blame Me.mp3
# Extracting audio features for: Don't Let Me Down.mp3
# Extracting audio features for: Don't Start Now.mp3
# Extracting audio features for: Don't Tell 'Em.mp3
# Extracting audio features for: Don't Wanna Know.mp3
# Extracting audio features for: Don't.mp3
# Extracting audio features for: Dos Mil 16.mp3
# Extracting audio features for: Down Home.mp3
# Extracting audio features for: Down In The DM.mp3
# Extracting audio features for: Downtown.mp3
# Extracting audio features for: Drag Me Down.mp3
# Extracting audio features for: Drinking Class.mp3
# Extracting audio features for: Drip Too Hard.mp3
# Extracting audio features for: Drivers License.mp3
# Extracting audio features for: Drunk Me.mp3
# Extracting audio features for: Dusk Till Dawn.mp3
# Extracting audio features for: Dynamite.mp3
# Extracting audio features for: Eastside.mp3
# Extracting audio features for: Easy On Me.mp3
# Extracting audio features for: Easy.mp3
# Extracting audio features for: Echame La Culpa.mp3
# Extracting audio features for: Efecto.mp3
# Extracting audio features for: El Amor de Su Vida.mp3
# Extracting audio features for: Ella Quiere Beber.mp3
# Extracting audio features for: End Game.mp3
# Extracting audio features for: Enemies.mp3
# Extracting audio features for: Enemy.mp3
# Extracting audio features for: Envy Me.mp3
# Extracting audio features for: Escapism.mp3
# Extracting audio features for: Even Though I'm Leaving.mp3
# Extracting audio features for: Everybody.mp3
# Extracting audio features for: Everything I Wanted.mp3
# Extracting audio features for: Ex's & Oh's.mp3
# Extracting audio features for: Exchange.mp3
# Extracting audio features for: Exes.mp3
# Extracting audio features for: Eyes Closed.mp3
# Extracting audio features for: Fake Love.mp3
# Extracting audio features for: Falling.mp3
# Extracting audio features for: Family Ties.mp3
# Extracting audio features for: Fancy Like.mp3
# Extracting audio features for: Fast Car.mp3
# Extracting audio features for: Favorite Crime.mp3
# Extracting audio features for: Favorite Time Of Year.mp3
# Extracting audio features for: Feather.mp3
# Extracting audio features for: Feel It Still.mp3
# Extracting audio features for: Feeling Myself.mp3
# Extracting audio features for: Feliz Navidad.mp3
# Extracting audio features for: Fine China.mp3
# Extracting audio features for: Fingers Crossed.mp3
# Extracting audio features for: Fireball.mp3
# Extracting audio features for: First Class.mp3
# Extracting audio features for: First Person Shooter.mp3
# Extracting audio features for: Five More Minutes.mp3
# Extracting audio features for: Flowers.mp3
# Extracting audio features for: Focus.mp3
# Extracting audio features for: Foldin Clothes.mp3
# Extracting audio features for: Follow You.mp3
# Extracting audio features for: For The Night.mp3
# Extracting audio features for: For Tonight.mp3
# Extracting audio features for: For Whom The Bell Tolls.mp3
# Extracting audio features for: Forever After All.mp3
# Extracting audio features for: Forget Me.mp3
# Extracting audio features for: Freedom Was A Highway.mp3
# Extracting audio features for: Fresh Eyes.mp3
# Extracting audio features for: FTCU.mp3
# Extracting audio features for: Futsal Shuffle 2020.mp3
# Extracting audio features for: G.D.F.R..mp3
# Extracting audio features for: Gato de Noche.mp3
# Extracting audio features for: Get Him Back!.mp3
# Extracting audio features for: Get Into It (Yuh).mp3
# Extracting audio features for: Get On Your Knees.mp3
# Extracting audio features for: Ghost In The Machine.mp3
# Extracting audio features for: Ghost.mp3
# Extracting audio features for: Girl In A Country Song.mp3
# Extracting audio features for: Girl Like You.mp3
# Extracting audio features for: Girls Like You.mp3
# Extracting audio features for: Girls Want Girls.mp3
# Extracting audio features for: Glimpse Of Us.mp3
# Extracting audio features for: Gnat.mp3
# Extracting audio features for: Go Crazy.mp3
# Extracting audio features for: God Made Girls.mp3
# Extracting audio features for: God Only Knows.mp3
# Extracting audio features for: Going Bad.mp3
# Extracting audio features for: Going, Going, Gone.mp3
# Extracting audio features for: Golden Hour.mp3
# Extracting audio features for: Golden.mp3
# Extracting audio features for: Gone Girl.mp3
# Extracting audio features for: Gonna Know We Were Here.mp3
# Extracting audio features for: Gonna.mp3
# Extracting audio features for: Good 4 U.mp3
# Extracting audio features for: Good As Hell.mp3
# Extracting audio features for: Good Days.mp3
# Extracting audio features for: Good For You.mp3
# Extracting audio features for: Good Girl.mp3
# Extracting audio features for: Good Good.mp3
# Extracting audio features for: Good Old Days.mp3
# Extracting audio features for: Good Time.mp3
# Extracting audio features for: Good To Be Alive (Hallelujah).mp3
# Extracting audio features for: Goosebumps.mp3
# Extracting audio features for: Graveyard.mp3
# Extracting audio features for: Great Gatsby.mp3
# Extracting audio features for: Greatest Love Story.mp3
# Extracting audio features for: Greedy.mp3
# Extracting audio features for: Gucci Gang.mp3
# Extracting audio features for: Gummo.mp3
# Extracting audio features for: Gun Smoke.mp3
# Extracting audio features for: Habits (Stay High).mp3
# Extracting audio features for: Hallelujah.mp3
# Extracting audio features for: HandClap.mp3
# Extracting audio features for: Hands To Myself.mp3
# Extracting audio features for: Happier Than Ever.mp3
# Extracting audio features for: Happier.mp3
# Extracting audio features for: Happy Xmas (War Is Over).mp3
# Extracting audio features for: Harley Quinn.mp3
# Extracting audio features for: Hate Me.mp3
# Extracting audio features for: Havana.mp3
# Extracting audio features for: Have Mercy.mp3
# Extracting audio features for: Have Yourself A Merry Little Christmas.mp3
# Extracting audio features for: Hawai.mp3
# Extracting audio features for: Heart Like A Truck.mp3
# Extracting audio features for: Heart On Fire.mp3
# Extracting audio features for: Heart On Ice.mp3
# Extracting audio features for: Heartache Medication.mp3
# Extracting audio features for: Heartbreak Anniversary.mp3
# Extracting audio features for: Heartless.mp3
# Extracting audio features for: Heat Waves.mp3
# Extracting audio features for: Heat.mp3
# Extracting audio features for: Heathens.mp3
# Extracting audio features for: Hello.mp3
# Extracting audio features for: Here Comes Santa Claus (Right Down Santa Claus Lane).mp3
# Extracting audio features for: Here With Me.mp3
# Extracting audio features for: Here.mp3
# Extracting audio features for: Heroes (We Could Be).mp3
# Extracting audio features for: Hey Driver.mp3
# Extracting audio features for: Hibachi.mp3
# Extracting audio features for: Hide Away.mp3
# Extracting audio features for: High Hopes.mp3
# Extracting audio features for: Highest In The Room.mp3
# Extracting audio features for: Him & I.mp3
# Extracting audio features for: Hit Different.mp3
# Extracting audio features for: Hit The Quan.mp3
# Extracting audio features for: Hold Me Closer.mp3
# Extracting audio features for: Hold My Hand.mp3
# Extracting audio features for: Hold On.mp3
# Extracting audio features for: Hold You Down.mp3
# Extracting audio features for: Hole In The Bottle.mp3
# Extracting audio features for: Holiday.mp3
# Extracting audio features for: Hollow.mp3
# Extracting audio features for: Holy.mp3
# Extracting audio features for: Home Alone Tonight.mp3
# Extracting audio features for: Home.mp3
# Extracting audio features for: Homegrown Honey.mp3
# Extracting audio features for: Homesick.mp3
# Extracting audio features for: Hot Boy.mp3
# Extracting audio features for: Hot Girl Bummer.mp3
# Extracting audio features for: Hot.mp3
# Extracting audio features for: Hotel California.mp3
# Extracting audio features for: Hotline Bling.mp3
# Extracting audio features for: Houdini.mp3
# Extracting audio features for: How Far I'll Go.mp3
# Extracting audio features for: How I'll Always Be.mp3
# Extracting audio features for: How Long.mp3
# Extracting audio features for: I Ain't Worried.mp3
# Extracting audio features for: I Bet My Life.mp3
# Extracting audio features for: I Could Use A Love Song.mp3
# Extracting audio features for: I Don't Mind.mp3
# Extracting audio features for: I Don't Wanna Live Forever (Fifty Shades Darker).mp3
# Extracting audio features for: I Fall Apart.mp3
# Extracting audio features for: I Feel It Coming.mp3
# Extracting audio features for: I Get The Bag.mp3
# Extracting audio features for: I Got The Boy.mp3
# Extracting audio features for: I Hate U I Love U.mp3
# Extracting audio features for: I Hate U.mp3
# Extracting audio features for: I Hope.mp3
# Extracting audio features for: I Know What You Did Last Summer.mp3
# Extracting audio features for: I Like It.mp3
# Extracting audio features for: I Lived.mp3
# Extracting audio features for: I Love This Life.mp3
# Extracting audio features for: I Pray.mp3
# Extracting audio features for: I Remember Everything.mp3
# Extracting audio features for: I Saw Mommy Kissing Santa Claus.mp3
# Extracting audio features for: I See You.mp3
# Extracting audio features for: I'll Be Home For Christmas.mp3
# Extracting audio features for: I'll Name The Dogs.mp3
# Extracting audio features for: I'll Show You.mp3
# Extracting audio features for: I'm Good (Blue).mp3
# Extracting audio features for: I'm Not The Only One.mp3
# Extracting audio features for: Ice Tray.mp3
# Extracting audio features for: IDGAF.mp3
# Extracting audio features for: Imagine.mp3
# Extracting audio features for: Immortal.mp3
# Extracting audio features for: In The Name Of Love.mp3
# Extracting audio features for: In The Night.mp3
# Extracting audio features for: In Your Arms.mp3
# Extracting audio features for: Industry Baby.mp3
# Extracting audio features for: Into The Unknown.mp3
# Extracting audio features for: Irresistible.mp3
# Extracting audio features for: It's Beginning To Look A Lot Like Christmas.mp3
# Extracting audio features for: It's The Most Wonderful Time Of The Year.mp3
# Extracting audio features for: Jealous.mp3
# Extracting audio features for: Jealousy, Jealousy.mp3
# Extracting audio features for: Jimmy Cooks.mp3
# Extracting audio features for: Jingle Bell Rock.mp3
# Extracting audio features for: Jingle Bells.mp3
# Extracting audio features for: Juice.mp3
# Extracting audio features for: Juicy.mp3
# Extracting audio features for: Juju On That Beat (TZ Anthem).mp3
# Extracting audio features for: Jumpman.mp3
# Extracting audio features for: Just Gettin' Started.mp3
# Extracting audio features for: Just Hold On.mp3
# Extracting audio features for: Just Wanna Rock.mp3
# Extracting audio features for: Kid On Christmas.mp3
# Extracting audio features for: Kill Bill.mp3
# Extracting audio features for: Kinfolks.mp3
# Extracting audio features for: Kings & Queens.mp3
# Extracting audio features for: Knife Talk.mp3
# Extracting audio features for: Knowing You.mp3
# Extracting audio features for: Kooda.mp3
# Extracting audio features for: L.A.LOVE (la la).mp3
# Extracting audio features for: La Diabla.mp3
# Extracting audio features for: La Jumpa.mp3
# Extracting audio features for: La Victima.mp3
# Extracting audio features for: Lace It.mp3
# Extracting audio features for: Last Christmas.mp3
# Extracting audio features for: Last Night.mp3
# Extracting audio features for: Last Shot.mp3
# Extracting audio features for: Late Night Talking.mp3
# Extracting audio features for: Laugh Now Cry Later.mp3
# Extracting audio features for: Lavender Haze.mp3
# Extracting audio features for: Lay It All On Me.mp3
# Extracting audio features for: Lean On.mp3
# Extracting audio features for: Leave Em Alone.mp3
# Extracting audio features for: Leave Me Alone.mp3
# Extracting audio features for: Leave The Door Open.mp3
# Extracting audio features for: Legends.mp3
# Extracting audio features for: Lemon.mp3
# Extracting audio features for: Lemonade.mp3
# Extracting audio features for: Let It Snow, Let It Snow, Let It Snow!.mp3
# Extracting audio features for: Let Me Go.mp3
# Extracting audio features for: Let Me Know (I Wonder Why Freestyle).mp3
# Extracting audio features for: Let Me Love You.mp3
# Extracting audio features for: Let You Down.mp3
# Extracting audio features for: Levitating.mp3
# Extracting audio features for: Life Goes On.mp3
# Extracting audio features for: Life Is Good.mp3
# Extracting audio features for: Lifestyle.mp3
# Extracting audio features for: Lift Me Up.mp3
# Extracting audio features for: Light It Up.mp3
# Extracting audio features for: Light Switch.mp3
# Extracting audio features for: Lights Down Low.mp3
# Extracting audio features for: Like A Cowboy.mp3
# Extracting audio features for: Like I Loved You.mp3
# Extracting audio features for: Like I'm Gonna Lose You.mp3
# Extracting audio features for: Like It's Christmas.mp3
# Extracting audio features for: Lil Boo Thang.mp3
# Extracting audio features for: Linus And Lucy (Peanuts Theme).mp3
# Extracting audio features for: Lips Are Movin.mp3
# Extracting audio features for: Little Saint Nick.mp3
# Extracting audio features for: Locked Away.mp3
# Extracting audio features for: Lonely Eyes.mp3
# Extracting audio features for: Lonely Tonight.mp3
# Extracting audio features for: Lonely.mp3
# Extracting audio features for: Look Back At It.mp3
# Extracting audio features for: Look What You Made Me Do.mp3
# Extracting audio features for: Lose Control.mp3
# Extracting audio features for: Lose You To Love Me.mp3
# Extracting audio features for: Lose Yourself.mp3
# Extracting audio features for: Losing Sleep.mp3
# Extracting audio features for: Lost In Japan.mp3
# Extracting audio features for: Lost Stars.mp3
# Extracting audio features for: Lost Without U.mp3
# Extracting audio features for: Love Again.mp3
# Extracting audio features for: Love Language.mp3
# Extracting audio features for: Love Lies.mp3
# Extracting audio features for: Love Me Harder.mp3
# Extracting audio features for: Love Me Now.mp3
# Extracting audio features for: Love Nwantiti (Ah Ah Ah).mp3
# Extracting audio features for: Love On The Brain.mp3
# Extracting audio features for: Love You Like I Used To.mp3
# Extracting audio features for: Love Yourself.mp3
# Extracting audio features for: Love..mp3
# Extracting audio features for: Lovely.mp3
# Extracting audio features for: Lover.mp3
# Extracting audio features for: Lovin On Me.mp3
# Extracting audio features for: Low.mp3
# Extracting audio features for: Lucid Dreams.mp3
# Extracting audio features for: Made You Look.mp3
# Extracting audio features for: Make Me (Cry).mp3
# Extracting audio features for: Make Me Wanna.mp3
# Extracting audio features for: Man Made A Bar.mp3
# Extracting audio features for: Marry Me.mp3
# Extracting audio features for: Mary Did You Know.mp3
# Extracting audio features for: Masterpiece.mp3
# Extracting audio features for: May We All.mp3
# Extracting audio features for: Mayores.mp3
# Extracting audio features for: Me, Myself & I.mp3
# Extracting audio features for: Mean To Me.mp3
# Extracting audio features for: Meant To Be.mp3
# Extracting audio features for: Meet Me At Our Spot.mp3
# Extracting audio features for: Mele Kalikimaka (Merry Christmas).mp3
# Extracting audio features for: Memories.mp3
# Extracting audio features for: Mercy.mp3
# Extracting audio features for: Merry Christmas.mp3
# Extracting audio features for: Message In A Bottle (Taylor's Version) (From The Vault).mp3
# Extracting audio features for: Mi Gente.mp3
# Extracting audio features for: MIA.mp3
# Extracting audio features for: MIC Drop.mp3
# Extracting audio features for: Midnight Sky.mp3
# Extracting audio features for: Million Reasons.mp3
# Extracting audio features for: Mind On You.mp3
# Extracting audio features for: Mistletoe.mp3
# Extracting audio features for: Mo Bamba.mp3
# Extracting audio features for: Mockingbird.mp3
# Extracting audio features for: Monaco.mp3
# Extracting audio features for: Money.mp3
# Extracting audio features for: Monster.mp3
# Extracting audio features for: Montero (Call Me By Your Name).mp3
# Extracting audio features for: Mood.mp3
# Extracting audio features for: Moonwalking In Calabasas.mp3
# Extracting audio features for: Moscow Mule.mp3
# Extracting audio features for: MotorSport.mp3
# Extracting audio features for: Moved To Miami.mp3
# Extracting audio features for: Mr. Right Now.mp3
# Extracting audio features for: My Baby's Got A Smile On Her Face.mp3
# Extracting audio features for: My Dawg.mp3
# Extracting audio features for: My Ex's Best Friend.mp3
# Extracting audio features for: My Head And My Heart.mp3
# Extracting audio features for: My House.mp3
# Extracting audio features for: My Love Mine All Mine.mp3
# Extracting audio features for: My Oh My.mp3
# Extracting audio features for: My Universe.mp3
# Extracting audio features for: Natural.mp3
# Extracting audio features for: Need To Know.mp3
# Extracting audio features for: Needle.mp3
# Extracting audio features for: Neighbors.mp3
# Extracting audio features for: Never Be The Same.mp3
# Extracting audio features for: Never Lose Me.mp3
# Extracting audio features for: Neverita.mp3
# Extracting audio features for: New Americana.mp3
# Extracting audio features for: New Rules.mp3
# Extracting audio features for: Nice To Meet Ya.mp3
# Extracting audio features for: Night Changes.mp3
# Extracting audio features for: No Body, No Crime.mp3
# Extracting audio features for: No Guidance.mp3
# Extracting audio features for: No Heart.mp3
# Extracting audio features for: No Idea.mp3
# Extracting audio features for: No Limit.mp3
# Extracting audio features for: No Love.mp3
# Extracting audio features for: No Role Modelz.mp3
# Extracting audio features for: No Se Va.mp3
# Extracting audio features for: No Smoke.mp3
# Extracting audio features for: No Stylist.mp3
# Extracting audio features for: No Type.mp3
# Extracting audio features for: Nobody Gets Me.mp3
# Extracting audio features for: Nonsense.mp3
# Extracting audio features for: Nothin' Like You.mp3
# Extracting audio features for: Nothing Breaks Like A Heart.mp3
# Extracting audio features for: Often.mp3
# Extracting audio features for: Oh My God.mp3
# Extracting audio features for: Old Town Road.mp3
# Extracting audio features for: On Chill.mp3
# Extracting audio features for: On Me.mp3
# Extracting audio features for: On My Mama.mp3
# Extracting audio features for: On My Mind.mp3
# Extracting audio features for: One Call Away.mp3
# Extracting audio features for: One Man Band.mp3
# Extracting audio features for: One Mississippi.mp3
# Extracting audio features for: One Right Now.mp3
# Extracting audio features for: One Thing At A Time.mp3
# Extracting audio features for: Only.mp3
# Extracting audio features for: OOOUUU.mp3
# Extracting audio features for: OTW.mp3
# Extracting audio features for: Out For The Night.mp3
# Extracting audio features for: Paint The Town Red.mp3
# Extracting audio features for: Panini.mp3
# Extracting audio features for: Party Monster.mp3
# Extracting audio features for: Party.mp3
# Extracting audio features for: Perfect Storm.mp3
# Extracting audio features for: Perfect.mp3
# Extracting audio features for: Permission To Dance.mp3
# Extracting audio features for: Pick It Up.mp3
# Extracting audio features for: Pick Me Up.mp3
# Extracting audio features for: Pick Out A Christmas Tree.mp3
# Extracting audio features for: Pills And Automobiles.mp3
# Extracting audio features for: Plain Jane.mp3
# Extracting audio features for: Play No Games.mp3
# Extracting audio features for: Play That Song.mp3
# Extracting audio features for: Playing Games.mp3
# Extracting audio features for: Please Come Home For Christmas.mp3
# Extracting audio features for: Positions.mp3
# Extracting audio features for: Prayer In C.mp3
# Extracting audio features for: Pretty Little Poison.mp3
# Extracting audio features for: Prisoner.mp3
# Extracting audio features for: Provenza.mp3
# Extracting audio features for: Purpose.mp3
# Extracting audio features for: Put Your Records On.mp3
# Extracting audio features for: Qlona.mp3
# Extracting audio features for: Que Onda.mp3
# Extracting audio features for: Que Vuelvas.mp3
# Extracting audio features for: Ran$om.mp3
# Extracting audio features for: Rather Be.mp3
# Extracting audio features for: Red Opps.mp3
# Extracting audio features for: Redbone.mp3
# Extracting audio features for: Remember You Young.mp3
# Extracting audio features for: Reminder.mp3
# Extracting audio features for: Ric Flair Drip.mp3
# Extracting audio features for: Rich Baby Daddy.mp3
# Extracting audio features for: Ridin' Roads.mp3
# Extracting audio features for: Right Hand.mp3
# Extracting audio features for: Riptide.mp3
# Extracting audio features for: RITMO (Bad Boys For Life).mp3
# Extracting audio features for: River.mp3
# Extracting audio features for: Rock And A Hard Place.mp3
# Extracting audio features for: Rockabye.mp3
# Extracting audio features for: Rockin' Around The Christmas Tree.mp3
# Extracting audio features for: Rockstar.mp3
# Extracting audio features for: Roll In Peace.mp3
# Extracting audio features for: Romantic Homicide.mp3
# Extracting audio features for: Roses.mp3
# Extracting audio features for: Round Here Buzz.mp3
# Extracting audio features for: Roxanne.mp3
# Extracting audio features for: Rubbin Off The Paint.mp3
# Extracting audio features for: Rude.mp3
# Extracting audio features for: Rudolph The Red-Nosed Reindeer.mp3
# Extracting audio features for: Run Rudolph Run.mp3
# Extracting audio features for: Run.mp3
# Extracting audio features for: Sacrifice.mp3
# Extracting audio features for: Same Boat.mp3
# Extracting audio features for: Same Old Love.mp3
# Extracting audio features for: Sand In My Boots.mp3
# Extracting audio features for: Santa Baby.mp3
# Extracting audio features for: Santa Claus Is Comin' To Town.mp3
# Extracting audio features for: Santa Tell Me.mp3
# Extracting audio features for: Santa, Can't You Hear Me.mp3
# Extracting audio features for: Save Me The Trouble.mp3
# Extracting audio features for: Save Your Tears.mp3
# Extracting audio features for: Say It.mp3
# Extracting audio features for: Say So.mp3
# Extracting audio features for: Say You Won't Let Go.mp3
# Extracting audio features for: Scars To Your Beautiful.mp3
# Extracting audio features for: Scorpio.mp3
# Extracting audio features for: Search & Rescue.mp3
# Extracting audio features for: See You Again.mp3
# Extracting audio features for: Seek & Destroy.mp3
# Extracting audio features for: Segun Quien.mp3
# Extracting audio features for: Selfish.mp3
# Extracting audio features for: Senorita.mp3
# Extracting audio features for: Set Fire To The Rain.mp3
# Extracting audio features for: Shake It Off.mp3
# Extracting audio features for: Shallow.mp3
# Extracting audio features for: Shape Of You.mp3
# Extracting audio features for: She Got The Best Of Me.mp3
# Extracting audio features for: She Knows.mp3
# Extracting audio features for: She's All I Wanna Be.mp3
# Extracting audio features for: She's Mine, Pt. 1.mp3
# Extracting audio features for: Shirt.mp3
# Extracting audio features for: Shivers.mp3
# Extracting audio features for: Shotgun Rider.mp3
# Extracting audio features for: Shut Up And Dance.mp3
# Extracting audio features for: Sicko Mode.mp3
# Extracting audio features for: Side To Side.mp3
# Extracting audio features for: Sidewalks.mp3
# Extracting audio features for: Silence.mp3
# Extracting audio features for: Silent Night.mp3
# Extracting audio features for: Six Feet Under.mp3
# Extracting audio features for: Sixteen.mp3
# Extracting audio features for: Sky Walker.mp3
# Extracting audio features for: Sledgehammer.mp3
# Extracting audio features for: Sleep Without You.mp3
# Extracting audio features for: Sleigh Ride.mp3
# Extracting audio features for: Slide.mp3
# Extracting audio features for: Slow Dancing In The Dark.mp3
# Extracting audio features for: Smoke Break.mp3
# Extracting audio features for: Smokin Out The Window.mp3
# Extracting audio features for: Sneakin'.mp3
# Extracting audio features for: Snooze.mp3
# Extracting audio features for: Soldier.mp3
# Extracting audio features for: Somebody To Love.mp3
# Extracting audio features for: Someday At Christmas.mp3
# Extracting audio features for: Someone You Loved.mp3
# Extracting audio features for: Something In The Orange.mp3
# Extracting audio features for: Something In The Water.mp3
# Extracting audio features for: Somewhere In My Car.mp3
# Extracting audio features for: Son Of A Sinner.mp3
# Extracting audio features for: Song For Another Time.mp3
# Extracting audio features for: Sorry Not Sorry.mp3
# Extracting audio features for: Sorry.mp3
# Extracting audio features for: SOS.mp3
# Extracting audio features for: South Of The Border.mp3
# Extracting audio features for: Special.mp3
# Extracting audio features for: Speechless.mp3
# Extracting audio features for: Spin Bout U.mp3
# Extracting audio features for: Stand By You.mp3
# Extracting audio features for: Standing Next To You.mp3
# Extracting audio features for: Star Of The Show.mp3
# Extracting audio features for: Star Walkin' (League Of Legends Worlds Anthem).mp3
# Extracting audio features for: Starboy.mp3
# Extracting audio features for: Start Wit Me.mp3
# Extracting audio features for: Startender.mp3
# Extracting audio features for: Starting Over.mp3
# Extracting audio features for: Starving.mp3
# Extracting audio features for: Stay A Little Longer.mp3
# Extracting audio features for: Stay With Me.mp3
# Extracting audio features for: Stay.mp3
# Extracting audio features for: Steal My Girl.mp3
# Extracting audio features for: Stick Season.mp3
# Extracting audio features for: Stitches.mp3
# Extracting audio features for: Stolen Dance.mp3
# Extracting audio features for: Strangers.mp3
# Extracting audio features for: Streets.mp3
# Extracting audio features for: Stressed Out.mp3
# Extracting audio features for: Strip It Down.mp3
# Extracting audio features for: Style.mp3
# Extracting audio features for: Suicidal.mp3
# Extracting audio features for: Sun Daze.mp3
# Extracting audio features for: Super Freaky Girl.mp3
# Extracting audio features for: Super Gremlin.mp3
# Extracting audio features for: Superhero (Heroes & Villains).mp3
# Extracting audio features for: Surround Sound.mp3
# Extracting audio features for: Swang.mp3
# Extracting audio features for: Sweet But Psycho.mp3
# Extracting audio features for: Swervin.mp3
# Extracting audio features for: Take Me Home For Christmas.mp3
# Extracting audio features for: Take Me To Church.mp3
# Extracting audio features for: Take My Breath.mp3
# Extracting audio features for: Take What You Want.mp3
# Extracting audio features for: Take You Dancing.mp3
# Extracting audio features for: Taki Taki.mp3
# Extracting audio features for: Talk To Me.mp3
# Extracting audio features for: Talking To The Moon.mp3
# Extracting audio features for: Talladega.mp3
# Extracting audio features for: Tarot.mp3
# Extracting audio features for: Tell Me You Love Me.mp3
# Extracting audio features for: Tennessee Rain.mp3
# Extracting audio features for: Tequila Little Time.mp3
# Extracting audio features for: Tequila Shots.mp3
# Extracting audio features for: Thailand.mp3
# Extracting audio features for: Thank God.mp3
# Extracting audio features for: Thank U, Next.mp3
# Extracting audio features for: That's What I Like.mp3
# Extracting audio features for: Thats What I Want.mp3
# Extracting audio features for: The Bones.mp3
# Extracting audio features for: The Box.mp3
# Extracting audio features for: The Christmas Song (Merry Christmas To You).mp3
# Extracting audio features for: The Christmas Song.mp3
# Extracting audio features for: The Feeling.mp3
# Extracting audio features for: The First Noel.mp3
# Extracting audio features for: The Fix.mp3
# Extracting audio features for: The Greatest.mp3
# Extracting audio features for: The Hanging Tree.mp3
# Extracting audio features for: The Heart Wants What It Wants.mp3
# Extracting audio features for: The Hills.mp3
# Extracting audio features for: The Kind Of Love We Make.mp3
# Extracting audio features for: The Painter.mp3
# Extracting audio features for: The Race.mp3
# Extracting audio features for: The Real Slim Shady.mp3
# Extracting audio features for: The Way Life Goes.mp3
# Extracting audio features for: The Weekend.mp3
# Extracting audio features for: There's Nothing Holdin' Me Back.mp3
# Extracting audio features for: Therefore I Am.mp3
# Extracting audio features for: Thinkin' Bout Me.mp3
# Extracting audio features for: Thinking 'Bout You.mp3
# Extracting audio features for: Thinking Out Loud.mp3
# Extracting audio features for: This Christmas.mp3
# Extracting audio features for: This Feeling.mp3
# Extracting audio features for: This Is It.mp3
# Extracting audio features for: This Town.mp3
# Extracting audio features for: Throat Baby (Go Baby).mp3
# Extracting audio features for: Thunder.mp3
# Extracting audio features for: Til It's Gone.mp3
# Extracting audio features for: Time Of Our Lives.mp3
# Extracting audio features for: Tip Toe.mp3
# Extracting audio features for: Titi Me Pregunto.mp3
# Extracting audio features for: To Be Loved By You.mp3
# Extracting audio features for: Tomorrow 2.mp3
# Extracting audio features for: Too Good At Goodbyes.mp3
# Extracting audio features for: Too Many Nights.mp3
# Extracting audio features for: Too Much Sauce.mp3
# Extracting audio features for: Too Much To Ask.mp3
# Extracting audio features for: Took Her To The O.mp3
# Extracting audio features for: Top Of The World.mp3
# Extracting audio features for: Touchin, Lovin.mp3
# Extracting audio features for: Traitor.mp3
# Extracting audio features for: Trampoline.mp3
# Extracting audio features for: Trap Queen.mp3
# Extracting audio features for: Treat You Better.mp3
# Extracting audio features for: Trip.mp3
# Extracting audio features for: Truck Bed.mp3
# Extracting audio features for: Trumpets.mp3
# Extracting audio features for: Truth Hurts.mp3
# Extracting audio features for: Try Me.mp3
# Extracting audio features for: Try.mp3
# Extracting audio features for: Tuesday.mp3
# Extracting audio features for: Tusa.mp3
# Extracting audio features for: Tyler Herro.mp3
# Extracting audio features for: Un Coco.mp3
# Extracting audio features for: Un Ratito.mp3
# Extracting audio features for: Under The Influence.mp3
# Extracting audio features for: Under The Mistletoe.mp3
# Extracting audio features for: Underneath The Tree.mp3
# Extracting audio features for: Unforgettable.mp3
# Extracting audio features for: Unholy.mp3
# Extracting audio features for: Unsteady.mp3
# Extracting audio features for: Unstoppable.mp3
# Extracting audio features for: Until I Found You.mp3
# Extracting audio features for: Up.mp3
# Extracting audio features for: Uproar.mp3
# Extracting audio features for: Uptown Funk!.mp3
# Extracting audio features for: Used To Be Young.mp3
# Extracting audio features for: Used To Love You.mp3
# Extracting audio features for: Used To This.mp3
# Extracting audio features for: Used.mp3
# Extracting audio features for: Vampire.mp3
# Extracting audio features for: Vegas.mp3
# Extracting audio features for: Velvet.mp3
# Extracting audio features for: Versace On The Floor.mp3
# Extracting audio features for: Vete.mp3
# Extracting audio features for: VIBEZ.mp3
# Extracting audio features for: Victoria's Secret.mp3
# Extracting audio features for: Ville Mentality.mp3
# Extracting audio features for: Viva La Vida.mp3
# Extracting audio features for: Wait In The Truck.mp3
# Extracting audio features for: Wake Up In The Sky.mp3
# Extracting audio features for: Walk On Water.mp3
# Extracting audio features for: Wandered To LA..mp3
# Extracting audio features for: Wanna Be That Song.mp3
# Extracting audio features for: Wanted You.mp3
# Extracting audio features for: Wants And Needs.mp3
# Extracting audio features for: WAP.mp3
# Extracting audio features for: Wasted Love.mp3
# Extracting audio features for: Wasted On You.mp3
# Extracting audio features for: Watch Me.mp3
# Extracting audio features for: Water Under The Bridge.mp3
# Extracting audio features for: Water.mp3
# Extracting audio features for: Watermelon Sugar.mp3
# Extracting audio features for: Waves.mp3
# Extracting audio features for: Way 2 Sexy.mp3
# Extracting audio features for: Way Out.mp3
# Extracting audio features for: We're Good.mp3
# Extracting audio features for: Wet Dreamz.mp3
# Extracting audio features for: What About Us.mp3
# Extracting audio features for: What If I Never Get Over You.mp3
# Extracting audio features for: What Lovers Do.mp3
# Extracting audio features for: What My World Spins Around.mp3
# Extracting audio features for: What You Know Bout Love.mp3
# Extracting audio features for: What's Next.mp3
# Extracting audio features for: When I Was Your Man.mp3
# Extracting audio features for: When The Party's Over.mp3
# Extracting audio features for: When We Were Young.mp3
# Extracting audio features for: When We.mp3
# Extracting audio features for: Where Are U Now.mp3
# Extracting audio features for: Where She Goes.mp3
# Extracting audio features for: Where The Wild Things Are.mp3
# Extracting audio features for: Where Ya At.mp3
# Extracting audio features for: Whiskey And Rain.mp3
# Extracting audio features for: Whiskey On You.mp3
# Extracting audio features for: White Christmas.mp3
# Extracting audio features for: White Horse.mp3
# Extracting audio features for: White Iverson.mp3
# Extracting audio features for: Whoopty.mp3
# Extracting audio features for: Wild Ones.mp3
# Extracting audio features for: Wildest Dreams.mp3
# Extracting audio features for: Willow.mp3
# Extracting audio features for: Winter Wonderland.mp3
# Extracting audio features for: Wish I Didn't Love You.mp3
# Extracting audio features for: Without Me.mp3
# Extracting audio features for: Without You.mp3
# Extracting audio features for: Woah.mp3
# Extracting audio features for: Wolves.mp3
# Extracting audio features for: Woman.mp3
# Extracting audio features for: Wonderful Christmastime.mp3
# Extracting audio features for: World On Fire.mp3
# Extracting audio features for: Wow..mp3
# Extracting audio features for: Written In The Sand.mp3
# Extracting audio features for: WTF (Where They From).mp3
# Extracting audio features for: X.mp3
# Extracting audio features for: Yellow Flicker Beat.mp3
# Extracting audio features for: Yellow Hearts.mp3
# Extracting audio features for: Yellow.mp3
# Extracting audio features for: Yo No Soy Celoso.mp3
# Extracting audio features for: Yonaguni.mp3
# Extracting audio features for: You Broke Me First..mp3
# Extracting audio features for: You Broke My Heart.mp3
# Extracting audio features for: You Broke Up With Me.mp3
# Extracting audio features for: You Proof.mp3
# Extracting audio features for: You Say.mp3
# Extracting audio features for: You Should Be Here.mp3
# Extracting audio features for: You Should Probably Leave.mp3
# Extracting audio features for: You Was Right.mp3
# Extracting audio features for: You're A Mean One, Mr. Grinch.mp3
# Extracting audio features for: You're Losing Me (From The Vault).mp3
# Extracting audio features for: You're Mines Still.mp3
# Extracting audio features for: You're Welcome.mp3
# Extracting audio features for: You.mp3
# Extracting audio features for: Young Dumb & Broke.mp3
# Extracting audio features for: Youngblood.mp3
# Extracting audio features for: Yours.mp3
# Extracting audio features for: ZEZE.mp3
# Audio features saved to: audio_features.csv

# %%
import librosa

# Creating function to extract audio features using Librosa
def extract_audio_features(file_path):
    # Loading audio file
    y, sr = librosa.load(file_path)

    # Extracting audio features
    tempo, beats = librosa.beat.beat_track(y=y, sr=sr)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    chroma_cqt = librosa.feature.chroma_cqt(y=y, sr=sr)
    chroma_cens = librosa.feature.chroma_cens(y=y, sr=sr)
    rmse = librosa.feature.rms(y=y)
    spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    spectral_rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
    zero_crossing_rate = librosa.feature.zero_crossing_rate(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    tonnetz = librosa.feature.tonnetz(y=y, sr=sr)
    
    # Concatenating and returning extracted audio features
    return {
        "file_name": os.path.basename(file_path),
        "tempo": tempo,
        "beats": beats,
        "chroma_stft": chroma_stft.mean(axis=1),
        "chroma_cqt": chroma_cqt.mean(axis=1),
        "chroma_cens": chroma_cens.mean(axis=1),
        "rmse": rmse.mean(),
        "spectral_centroid": spectral_centroid.mean(),
        "spectral_bandwidth": spectral_bandwidth.mean(),
        "spectral_rolloff": spectral_rolloff.mean(),
        "spectral_contrast": spectral_contrast.mean(axis=1),
        "zero_crossing_rate": zero_crossing_rate.mean(),
        "mfcc": mfcc.mean(axis=1),
        "tonnetz": tonnetz.mean(axis=1)
    }

# Creating directory where chorus audio files are stored
audio_folder = "chorus"

# Creating list to store extracted features for all audio files
all_features = []

# Iterating over all chorus audio files in the directory
for file_name in os.listdir(audio_folder):
    if file_name.endswith(".mp3"):
        file_path = os.path.join(audio_folder, file_name)
        print(f"Extracting audio features for: {file_name}")
        features = extract_audio_features(file_path)
        all_features.append(features)

# Converting the collected features into a pandas DataFrame
df = pd.DataFrame(all_features)

# Splitting arrays into separate columns
df = pd.concat([df.drop(['chroma_stft', 'chroma_cqt', 'chroma_cens', 'mfcc'], axis=1), 
                df['chroma_stft'].apply(pd.Series).add_prefix('chroma_stft_'), 
                df['chroma_cqt'].apply(pd.Series).add_prefix('chroma_cqt_'), 
                df['chroma_cens'].apply(pd.Series).add_prefix('chroma_cens_'),
                df['spectral_contrast'].apply(pd.Series).add_prefix('spectral_contrast_'),
                df['mfcc'].apply(pd.Series).add_prefix('mfcc_'), 
                df['tonnetz'].apply(pd.Series).add_prefix('tonnetz_')], axis=1)

# Saving the DataFrame to a CSV file
output_csv = "audio_features_chorus.csv"
df.to_csv(output_csv, index=False)

print(f"Audio features saved to: {output_csv}")
# Out:
# Extracting audio features for: $ave Dat Money.mp3
# Extracting audio features for: 'Til You Can't.mp3
# Extracting audio features for: 'Tis The Damn Season.mp3
# Extracting audio features for: (There's No Place Like) Home For The Holidays (1954).mp3
# Extracting audio features for: (There's No Place Like) Home For The Holidays (1959).mp3
# Extracting audio features for: 1 Night.mp3
# Extracting audio features for: 1-800-273-8255.mp3
# Extracting audio features for: 1.5.mp3
# Extracting audio features for: 10,000 Hours.mp3
# Extracting audio features for: 223's.mp3
# Extracting audio features for: 24K Magic.mp3
# Extracting audio features for: 25 Million.mp3
# Extracting audio features for: 34+35.mp3
# Extracting audio features for: 500lbs.mp3
# Extracting audio features for: 679.mp3
# Extracting audio features for: 7 Summers.mp3
# Extracting audio features for: A Guy With A Girl.mp3
# Extracting audio features for: A Holly Jolly Christmas.mp3
# Extracting audio features for: A Lot.mp3
# Extracting audio features for: abcdefu.mp3
# Extracting audio features for: About Damn Time.mp3
# Extracting audio features for: About The Money.mp3
# Extracting audio features for: Adderall (Corvette Corvette).mp3
# Extracting audio features for: Adore You.mp3
# Extracting audio features for: Adventure Of A Lifetime.mp3
# Extracting audio features for: Afterglow.mp3
# Extracting audio features for: Again.mp3
# Extracting audio features for: Agora Hills.mp3
# Extracting audio features for: Ain't Shit.mp3
# Extracting audio features for: All About That Bass.mp3
# Extracting audio features for: All I Want For Christmas Is You.mp3
# Extracting audio features for: All My Friends.mp3
# Extracting audio features for: All Of Me.mp3
# Extracting audio features for: All On Me.mp3
# Extracting audio features for: All Time Low.mp3
# Extracting audio features for: All Too Well (Taylor's Version).mp3
# Extracting audio features for: All We Know.mp3
# Extracting audio features for: Alone.mp3
# Extracting audio features for: Already Dead.mp3
# Extracting audio features for: Amargura.mp3
# Extracting audio features for: Anaconda.mp3
# Extracting audio features for: Animals.mp3
# Extracting audio features for: Anti-Hero.mp3
# Extracting audio features for: Antidote.mp3
# Extracting audio features for: Anyone.mp3
# Extracting audio features for: Apparently.mp3
# Extracting audio features for: Armed And Dangerous.mp3
# Extracting audio features for: Arms Around You.mp3
# Extracting audio features for: As It Was.mp3
# Extracting audio features for: ASMR.mp3
# Extracting audio features for: Attention.mp3
# Extracting audio features for: Baby It's Cold Outside.mp3
# Extracting audio features for: Baby Sitter.mp3
# Extracting audio features for: Back To Back.mp3
# Extracting audio features for: Back To Sleep.mp3
# Extracting audio features for: Back To The Streets.mp3
# Extracting audio features for: Back Up.mp3
# Extracting audio features for: Backdoor.mp3
# Extracting audio features for: Backin' It Up.mp3
# Extracting audio features for: Backroad Song.mp3
# Extracting audio features for: Bad And Boujee.mp3
# Extracting audio features for: Bad At Love.mp3
# Extracting audio features for: Bad Guy.mp3
# Extracting audio features for: Bad Habit.mp3
# Extracting audio features for: Bad Habits.mp3
# Extracting audio features for: Bad Things.mp3
# Extracting audio features for: BAD!.mp3
# Extracting audio features for: Ballin'.mp3
# Extracting audio features for: Bandit.mp3
# Extracting audio features for: Bang Bang.mp3
# Extracting audio features for: Bang!.mp3
# Extracting audio features for: Bank Account.mp3
# Extracting audio features for: Be Alright.mp3
# Extracting audio features for: Beautiful Crazy.mp3
# Extracting audio features for: Beautiful Drug.mp3
# Extracting audio features for: Beautiful.mp3
# Extracting audio features for: Bebe Dame.mp3
# Extracting audio features for: Bed Of Lies.mp3
# Extracting audio features for: Before You Go.mp3
# Extracting audio features for: Beg For It.mp3
# Extracting audio features for: Believe.mp3
# Extracting audio features for: Believer.mp3
# Extracting audio features for: Bellakeo.mp3
# Extracting audio features for: Best Friend.mp3
# Extracting audio features for: BEST ON EARTH.mp3
# Extracting audio features for: Best Shot.mp3
# Extracting audio features for: Betrayed.mp3
# Extracting audio features for: Better Days.mp3
# Extracting audio features for: Better Man.mp3
# Extracting audio features for: Better Now.mp3
# Extracting audio features for: Better Together.mp3
# Extracting audio features for: Better.mp3
# Extracting audio features for: Bichota.mp3
# Extracting audio features for: Big Energy.mp3
# Extracting audio features for: Big Rings.mp3
# Extracting audio features for: Big, Big Plans.mp3
# Extracting audio features for: Black Beatles.mp3
# Extracting audio features for: Black Widow.mp3
# Extracting audio features for: Blame.mp3
# Extracting audio features for: Blank Space.mp3
# Extracting audio features for: Blase.mp3
# Extracting audio features for: Blind.mp3
# Extracting audio features for: Blinding Lights.mp3
# Extracting audio features for: Bloody Mary.mp3
# Extracting audio features for: Blue Ain't Your Color.mp3
# Extracting audio features for: Blue Christmas.mp3
# Extracting audio features for: Bodak Yellow (Money Moves).mp3
# Extracting audio features for: Body Language.mp3
# Extracting audio features for: Body.mp3
# Extracting audio features for: Bones.mp3
# Extracting audio features for: BOP.mp3
# Extracting audio features for: Both.mp3
# Extracting audio features for: Bounce Back.mp3
# Extracting audio features for: Break Da Law.mp3
# Extracting audio features for: Break My Heart.mp3
# Extracting audio features for: Break My Soul.mp3
# Extracting audio features for: Break The Rules.mp3
# Extracting audio features for: Break Up In A Small Town.mp3
# Extracting audio features for: Breathin.mp3
# Extracting audio features for: Broadway Girls.mp3
# Extracting audio features for: Broccoli.mp3
# Extracting audio features for: Brutal.mp3
# Extracting audio features for: Bubbly.mp3
# Extracting audio features for: Burn It Down.mp3
# Extracting audio features for: Burn.mp3
# Extracting audio features for: Burning House.mp3
# Extracting audio features for: Burning Man.mp3
# Extracting audio features for: Butter.mp3
# Extracting audio features for: Buy Dirt.mp3
# Extracting audio features for: By Your Side.mp3
# Extracting audio features for: Cake By The Ocean.mp3
# Extracting audio features for: Calling My Spirit.mp3
# Extracting audio features for: Calm Down.mp3
# Extracting audio features for: Camelot.mp3
# Extracting audio features for: Can't Catch Me Now.mp3
# Extracting audio features for: Can't Feel My Face.mp3
# Extracting audio features for: Can't Leave Without It.mp3
# Extracting audio features for: Can't Stop The Feeling!.mp3
# Extracting audio features for: Candy Paint.mp3
# Extracting audio features for: Candy.mp3
# Extracting audio features for: Cardigan.mp3
# Extracting audio features for: Caroline.mp3
# Extracting audio features for: Centuries.mp3
# Extracting audio features for: Champagne Night.mp3
# Extracting audio features for: Champagne Problems.mp3
# Extracting audio features for: Chandelier.mp3
# Extracting audio features for: Change.mp3
# Extracting audio features for: Chantaje.mp3
# Extracting audio features for: Cheap Thrills.mp3
# Extracting audio features for: Cheerleader.mp3
# Extracting audio features for: Chemical.mp3
# Extracting audio features for: Chill Bill.mp3
# Extracting audio features for: Chosen.mp3
# Extracting audio features for: Christmas (Baby Please Come Home).mp3
# Extracting audio features for: Christmas Isn't Canceled (Just You).mp3
# Extracting audio features for: Christmas Tree Farm (Old Timey Version).mp3
# Extracting audio features for: Christmastime Is Here.mp3
# Extracting audio features for: Circles.mp3
# Extracting audio features for: Circo Loco.mp3
# Extracting audio features for: Climb Every Mountain.mp3
# Extracting audio features for: Close To Me.mp3
# Extracting audio features for: Close Your Eyes.mp3
# Extracting audio features for: Closer.mp3
# Extracting audio features for: CoCo.mp3
# Extracting audio features for: Codeine Dreaming.mp3
# Extracting audio features for: Cold Heart (PNAU Remix).mp3
# Extracting audio features for: Cold Water.mp3
# Extracting audio features for: Come Get Her.mp3
# Extracting audio features for: Confident.mp3
# Extracting audio features for: Consequences.mp3
# Extracting audio features for: Counting Stars.mp3
# Extracting audio features for: Cozy Little Christmas.mp3
# Extracting audio features for: Creepin'.mp3
# Extracting audio features for: Cruel Summer.mp3
# Extracting audio features for: Cry Baby.mp3
# Extracting audio features for: Cuff It.mp3
# Extracting audio features for: Dakiti.mp3
# Extracting audio features for: Damage.mp3
# Extracting audio features for: Dance Monkey.mp3
# Extracting audio features for: Dance The Night.mp3
# Extracting audio features for: Dangerous.mp3
# Extracting audio features for: Dark Knight Dummo.mp3
# Extracting audio features for: Death.mp3
# Extracting audio features for: Deck The Halls.mp3
# Extracting audio features for: Deja Vu.mp3
# Extracting audio features for: Demons And Angels.mp3
# Extracting audio features for: Despacito.mp3
# Extracting audio features for: Despues de La Playa.mp3
# Extracting audio features for: Dessert.mp3
# Extracting audio features for: Diamonds.mp3
# Extracting audio features for: Dibs.mp3
# Extracting audio features for: Die A Happy Man.mp3
# Extracting audio features for: Die For You.mp3
# Extracting audio features for: Dior.mp3
# Extracting audio features for: Dirt On My Boots.mp3
# Extracting audio features for: Dirty Laundry.mp3
# Extracting audio features for: DJ Play A Christmas Song.mp3
# Extracting audio features for: Do It Like Me.mp3
# Extracting audio features for: Do It To It.mp3
# Extracting audio features for: Do You Mind.mp3
# Extracting audio features for: Don't Blame Me.mp3
# Extracting audio features for: Don't Let Me Down.mp3
# Extracting audio features for: Don't Start Now.mp3
# Extracting audio features for: Don't Tell 'Em.mp3
# Extracting audio features for: Don't Wanna Know.mp3
# Extracting audio features for: Don't.mp3
# Extracting audio features for: Dos Mil 16.mp3
# Extracting audio features for: Down Home.mp3
# Extracting audio features for: Down In The DM.mp3
# Extracting audio features for: Downtown.mp3
# Extracting audio features for: Drag Me Down.mp3
# Extracting audio features for: Drinking Class.mp3
# Extracting audio features for: Drip Too Hard.mp3
# Extracting audio features for: Drivers License.mp3
# Extracting audio features for: Drunk Me.mp3
# Extracting audio features for: Dusk Till Dawn.mp3
# Extracting audio features for: Dynamite.mp3
# Extracting audio features for: Eastside.mp3
# Extracting audio features for: Easy On Me.mp3
# Extracting audio features for: Easy.mp3
# Extracting audio features for: Echame La Culpa.mp3
# Extracting audio features for: Efecto.mp3
# Extracting audio features for: El Amor de Su Vida.mp3
# Extracting audio features for: Ella Quiere Beber.mp3
# Extracting audio features for: End Game.mp3
# Extracting audio features for: Enemies.mp3
# Extracting audio features for: Enemy.mp3
# Extracting audio features for: Envy Me.mp3
# Extracting audio features for: Escapism.mp3
# Extracting audio features for: Even Though I'm Leaving.mp3
# Extracting audio features for: Everybody.mp3
# Extracting audio features for: Everything I Wanted.mp3
# Extracting audio features for: Ex's & Oh's.mp3
# Extracting audio features for: Exchange.mp3
# Extracting audio features for: Exes.mp3
# Extracting audio features for: Eyes Closed.mp3
# Extracting audio features for: Fake Love.mp3
# Extracting audio features for: Falling.mp3
# Extracting audio features for: Family Ties.mp3
# Extracting audio features for: Fancy Like.mp3
# Extracting audio features for: Fast Car.mp3
# Extracting audio features for: Favorite Crime.mp3
# Extracting audio features for: Favorite Time Of Year.mp3
# Extracting audio features for: Feather.mp3
# Extracting audio features for: Feel It Still.mp3
# Extracting audio features for: Feeling Myself.mp3
# Extracting audio features for: Feliz Navidad.mp3
# Extracting audio features for: Fine China.mp3
# Extracting audio features for: Fingers Crossed.mp3
# Extracting audio features for: Fireball.mp3
# Extracting audio features for: First Class.mp3
# Extracting audio features for: First Person Shooter.mp3
# Extracting audio features for: Five More Minutes.mp3
# Extracting audio features for: Flowers.mp3
# Extracting audio features for: Focus.mp3
# Extracting audio features for: Foldin Clothes.mp3
# Extracting audio features for: Follow You.mp3
# Extracting audio features for: For The Night.mp3
# Extracting audio features for: For Tonight.mp3
# Extracting audio features for: For Whom The Bell Tolls.mp3
# Extracting audio features for: Forever After All.mp3
# Extracting audio features for: Forget Me.mp3
# Extracting audio features for: Freedom Was A Highway.mp3
# Extracting audio features for: Fresh Eyes.mp3
# Extracting audio features for: FTCU.mp3
# Extracting audio features for: Futsal Shuffle 2020.mp3
# Extracting audio features for: G.D.F.R..mp3
# Extracting audio features for: Gato de Noche.mp3
# Extracting audio features for: Get Him Back!.mp3
# Extracting audio features for: Get Into It (Yuh).mp3
# Extracting audio features for: Get On Your Knees.mp3
# Extracting audio features for: Ghost In The Machine.mp3
# Extracting audio features for: Ghost.mp3
# Extracting audio features for: Girl In A Country Song.mp3
# Extracting audio features for: Girl Like You.mp3
# Extracting audio features for: Girls Like You.mp3
# Extracting audio features for: Girls Want Girls.mp3
# Extracting audio features for: Glimpse Of Us.mp3
# Extracting audio features for: Gnat.mp3
# Extracting audio features for: Go Crazy.mp3
# Extracting audio features for: God Made Girls.mp3
# Extracting audio features for: God Only Knows.mp3
# Extracting audio features for: Going Bad.mp3
# Extracting audio features for: Going, Going, Gone.mp3
# Extracting audio features for: Golden Hour.mp3
# Extracting audio features for: Golden.mp3
# Extracting audio features for: Gone Girl.mp3
# Extracting audio features for: Gonna Know We Were Here.mp3
# Extracting audio features for: Gonna.mp3
# Extracting audio features for: Good 4 U.mp3
# Extracting audio features for: Good As Hell.mp3
# Extracting audio features for: Good Days.mp3
# Extracting audio features for: Good For You.mp3
# Extracting audio features for: Good Girl.mp3
# Extracting audio features for: Good Good.mp3
# Extracting audio features for: Good Old Days.mp3
# Extracting audio features for: Good Time.mp3
# Extracting audio features for: Good To Be Alive (Hallelujah).mp3
# Extracting audio features for: Goosebumps.mp3
# Extracting audio features for: Graveyard.mp3
# Extracting audio features for: Great Gatsby.mp3
# Extracting audio features for: Greatest Love Story.mp3
# Extracting audio features for: Greedy.mp3
# Extracting audio features for: Gucci Gang.mp3
# Extracting audio features for: Gummo.mp3
# Extracting audio features for: Gun Smoke.mp3
# Extracting audio features for: Habits (Stay High).mp3
# Extracting audio features for: Hallelujah.mp3
# Extracting audio features for: HandClap.mp3
# Extracting audio features for: Hands To Myself.mp3
# Extracting audio features for: Happier Than Ever.mp3
# Extracting audio features for: Happier.mp3
# Extracting audio features for: Happy Xmas (War Is Over).mp3
# Extracting audio features for: Harley Quinn.mp3
# Extracting audio features for: Hate Me.mp3
# Extracting audio features for: Havana.mp3
# Extracting audio features for: Have Mercy.mp3
# Extracting audio features for: Have Yourself A Merry Little Christmas.mp3
# Extracting audio features for: Hawai.mp3
# Extracting audio features for: Heart Like A Truck.mp3
# Extracting audio features for: Heart On Fire.mp3
# Extracting audio features for: Heart On Ice.mp3
# Extracting audio features for: Heartache Medication.mp3
# Extracting audio features for: Heartbreak Anniversary.mp3
# Extracting audio features for: Heartless.mp3
# Extracting audio features for: Heat Waves.mp3
# Extracting audio features for: Heat.mp3
# Extracting audio features for: Heathens.mp3
# Extracting audio features for: Hello.mp3
# Extracting audio features for: Here Comes Santa Claus (Right Down Santa Claus Lane).mp3
# Extracting audio features for: Here With Me.mp3
# Extracting audio features for: Here.mp3
# Extracting audio features for: Heroes (We Could Be).mp3
# Extracting audio features for: Hey Driver.mp3
# Extracting audio features for: Hibachi.mp3
# Extracting audio features for: Hide Away.mp3
# Extracting audio features for: High Hopes.mp3
# Extracting audio features for: Highest In The Room.mp3
# Extracting audio features for: Him & I.mp3
# Extracting audio features for: Hit Different.mp3
# Extracting audio features for: Hit The Quan.mp3
# Extracting audio features for: Hold Me Closer.mp3
# Extracting audio features for: Hold My Hand.mp3
# Extracting audio features for: Hold On.mp3
# Extracting audio features for: Hold You Down.mp3
# Extracting audio features for: Hole In The Bottle.mp3
# Extracting audio features for: Holiday.mp3
# Extracting audio features for: Hollow.mp3
# Extracting audio features for: Holy.mp3
# Extracting audio features for: Home Alone Tonight.mp3
# Extracting audio features for: Home.mp3
# Extracting audio features for: Homegrown Honey.mp3
# Extracting audio features for: Homesick.mp3
# Extracting audio features for: Hot Boy.mp3
# Extracting audio features for: Hot Girl Bummer.mp3
# Extracting audio features for: Hot.mp3
# Extracting audio features for: Hotel California.mp3
# Extracting audio features for: Hotline Bling.mp3
# Extracting audio features for: Houdini.mp3
# Extracting audio features for: How Far I'll Go.mp3
# Extracting audio features for: How I'll Always Be.mp3
# Extracting audio features for: How Long.mp3
# Extracting audio features for: I Ain't Worried.mp3
# Extracting audio features for: I Bet My Life.mp3
# Extracting audio features for: I Could Use A Love Song.mp3
# Extracting audio features for: I Don't Mind.mp3
# Extracting audio features for: I Don't Wanna Live Forever (Fifty Shades Darker).mp3
# Extracting audio features for: I Fall Apart.mp3
# Extracting audio features for: I Feel It Coming.mp3
# Extracting audio features for: I Get The Bag.mp3
# Extracting audio features for: I Got The Boy.mp3
# Extracting audio features for: I Hate U I Love U.mp3
# Extracting audio features for: I Hate U.mp3
# Extracting audio features for: I Hope.mp3
# Extracting audio features for: I Know What You Did Last Summer.mp3
# Extracting audio features for: I Like It.mp3
# Extracting audio features for: I Lived.mp3
# Extracting audio features for: I Love This Life.mp3
# Extracting audio features for: I Pray.mp3
# Extracting audio features for: I Remember Everything.mp3
# Extracting audio features for: I Saw Mommy Kissing Santa Claus.mp3
# Extracting audio features for: I See You.mp3
# Extracting audio features for: I'll Be Home For Christmas.mp3
# Extracting audio features for: I'll Name The Dogs.mp3
# Extracting audio features for: I'll Show You.mp3
# Extracting audio features for: I'm Good (Blue).mp3
# Extracting audio features for: I'm Not The Only One.mp3
# Extracting audio features for: Ice Tray.mp3
# Extracting audio features for: IDGAF.mp3
# Extracting audio features for: Imagine.mp3
# Extracting audio features for: Immortal.mp3
# Extracting audio features for: In The Name Of Love.mp3
# Extracting audio features for: In The Night.mp3
# Extracting audio features for: In Your Arms.mp3
# Extracting audio features for: Industry Baby.mp3
# Extracting audio features for: Into The Unknown.mp3
# Extracting audio features for: Irresistible.mp3
# Extracting audio features for: It's Beginning To Look A Lot Like Christmas.mp3
# Extracting audio features for: It's The Most Wonderful Time Of The Year.mp3
# Extracting audio features for: Jealous.mp3
# Extracting audio features for: Jealousy, Jealousy.mp3
# Extracting audio features for: Jimmy Cooks.mp3
# Extracting audio features for: Jingle Bell Rock.mp3
# Extracting audio features for: Jingle Bells.mp3
# C:\Users\Basan\anaconda3\Lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=717
#   warnings.warn(
# C:\Users\Basan\anaconda3\Lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=359
#   warnings.warn(
# Extracting audio features for: Juice.mp3
# Extracting audio features for: Juicy.mp3
# Extracting audio features for: Juju On That Beat (TZ Anthem).mp3
# Extracting audio features for: Jumpman.mp3
# Extracting audio features for: Just Gettin' Started.mp3
# Extracting audio features for: Just Hold On.mp3
# Extracting audio features for: Just Wanna Rock.mp3
# Extracting audio features for: Kid On Christmas.mp3
# Extracting audio features for: Kill Bill.mp3
# Extracting audio features for: Kinfolks.mp3
# Extracting audio features for: Kings & Queens.mp3
# Extracting audio features for: Knife Talk.mp3
# Extracting audio features for: Knowing You.mp3
# Extracting audio features for: Kooda.mp3
# Extracting audio features for: L.A.LOVE (la la).mp3
# Extracting audio features for: La Diabla.mp3
# Extracting audio features for: La Jumpa.mp3
# Extracting audio features for: La Victima.mp3
# Extracting audio features for: Lace It.mp3
# Extracting audio features for: Last Christmas.mp3
# Extracting audio features for: Last Night.mp3
# Extracting audio features for: Last Shot.mp3
# Extracting audio features for: Late Night Talking.mp3
# Extracting audio features for: Laugh Now Cry Later.mp3
# Extracting audio features for: Lavender Haze.mp3
# Extracting audio features for: Lay It All On Me.mp3
# Extracting audio features for: Lean On.mp3
# Extracting audio features for: Leave Em Alone.mp3
# Extracting audio features for: Leave Me Alone.mp3
# Extracting audio features for: Leave The Door Open.mp3
# Extracting audio features for: Legends.mp3
# Extracting audio features for: Lemon.mp3
# Extracting audio features for: Lemonade.mp3
# Extracting audio features for: Let It Snow, Let It Snow, Let It Snow!.mp3
# Extracting audio features for: Let Me Go.mp3
# Extracting audio features for: Let Me Know (I Wonder Why Freestyle).mp3
# Extracting audio features for: Let Me Love You.mp3
# Extracting audio features for: Let You Down.mp3
# Extracting audio features for: Levitating.mp3
# Extracting audio features for: Life Goes On.mp3
# Extracting audio features for: Life Is Good.mp3
# Extracting audio features for: Lifestyle.mp3
# Extracting audio features for: Lift Me Up.mp3
# Extracting audio features for: Light It Up.mp3
# Extracting audio features for: Light Switch.mp3
# Extracting audio features for: Lights Down Low.mp3
# Extracting audio features for: Like A Cowboy.mp3
# Extracting audio features for: Like I Loved You.mp3
# Extracting audio features for: Like I'm Gonna Lose You.mp3
# Extracting audio features for: Like It's Christmas.mp3
# Extracting audio features for: Lil Boo Thang.mp3
# Extracting audio features for: Linus And Lucy (Peanuts Theme).mp3
# Extracting audio features for: Lips Are Movin.mp3
# Extracting audio features for: Little Saint Nick.mp3
# Extracting audio features for: Locked Away.mp3
# Extracting audio features for: Lonely Eyes.mp3
# Extracting audio features for: Lonely Tonight.mp3
# Extracting audio features for: Lonely.mp3
# Extracting audio features for: Look Back At It.mp3
# Extracting audio features for: Look What You Made Me Do.mp3
# Extracting audio features for: Lose Control.mp3
# Extracting audio features for: Lose You To Love Me.mp3
# Extracting audio features for: Lose Yourself.mp3
# Extracting audio features for: Losing Sleep.mp3
# Extracting audio features for: Lost In Japan.mp3
# Extracting audio features for: Lost Stars.mp3
# Extracting audio features for: Lost Without U.mp3
# Extracting audio features for: Love Again.mp3
# Extracting audio features for: Love Language.mp3
# Extracting audio features for: Love Lies.mp3
# Extracting audio features for: Love Me Harder.mp3
# Extracting audio features for: Love Me Now.mp3
# Extracting audio features for: Love Nwantiti (Ah Ah Ah).mp3
# Extracting audio features for: Love On The Brain.mp3
# Extracting audio features for: Love You Like I Used To.mp3
# Extracting audio features for: Love Yourself.mp3
# Extracting audio features for: Love..mp3
# Extracting audio features for: Lovely.mp3
# Extracting audio features for: Lover.mp3
# Extracting audio features for: Lovin On Me.mp3
# Extracting audio features for: Low.mp3
# Extracting audio features for: Lucid Dreams.mp3
# Extracting audio features for: Made You Look.mp3
# Extracting audio features for: Make Me (Cry).mp3
# Extracting audio features for: Make Me Wanna.mp3
# Extracting audio features for: Man Made A Bar.mp3
# Extracting audio features for: Marry Me.mp3
# Extracting audio features for: Mary Did You Know.mp3
# Extracting audio features for: Masterpiece.mp3
# Extracting audio features for: May We All.mp3
# Extracting audio features for: Mayores.mp3
# Extracting audio features for: Me, Myself & I.mp3
# Extracting audio features for: Mean To Me.mp3
# Extracting audio features for: Meant To Be.mp3
# Extracting audio features for: Meet Me At Our Spot.mp3
# Extracting audio features for: Mele Kalikimaka (Merry Christmas).mp3
# Extracting audio features for: Memories.mp3
# Extracting audio features for: Mercy.mp3
# Extracting audio features for: Merry Christmas.mp3
# Extracting audio features for: Message In A Bottle (Taylor's Version) (From The Vault).mp3
# Extracting audio features for: Mi Gente.mp3
# Extracting audio features for: MIA.mp3
# Extracting audio features for: MIC Drop.mp3
# Extracting audio features for: Midnight Sky.mp3
# Extracting audio features for: Million Reasons.mp3
# Extracting audio features for: Mind On You.mp3
# Extracting audio features for: Mistletoe.mp3
# Extracting audio features for: Mo Bamba.mp3
# Extracting audio features for: Mockingbird.mp3
# Extracting audio features for: Monaco.mp3
# Extracting audio features for: Money.mp3
# Extracting audio features for: Monster.mp3
# Extracting audio features for: Montero (Call Me By Your Name).mp3
# Extracting audio features for: Mood.mp3
# Extracting audio features for: Moonwalking In Calabasas.mp3
# Extracting audio features for: Moscow Mule.mp3
# Extracting audio features for: MotorSport.mp3
# Extracting audio features for: Moved To Miami.mp3
# Extracting audio features for: Mr. Right Now.mp3
# Extracting audio features for: My Baby's Got A Smile On Her Face.mp3
# Extracting audio features for: My Dawg.mp3
# Extracting audio features for: My Ex's Best Friend.mp3
# Extracting audio features for: My Head And My Heart.mp3
# Extracting audio features for: My House.mp3
# Extracting audio features for: My Love Mine All Mine.mp3
# Extracting audio features for: My Oh My.mp3
# Extracting audio features for: My Universe.mp3
# Extracting audio features for: Natural.mp3
# Extracting audio features for: Need To Know.mp3
# Extracting audio features for: Needle.mp3
# Extracting audio features for: Neighbors.mp3
# Extracting audio features for: Never Be The Same.mp3
# Extracting audio features for: Never Lose Me.mp3
# Extracting audio features for: Neverita.mp3
# Extracting audio features for: New Americana.mp3
# Extracting audio features for: New Rules.mp3
# Extracting audio features for: Nice To Meet Ya.mp3
# Extracting audio features for: Night Changes.mp3
# Extracting audio features for: No Body, No Crime.mp3
# Extracting audio features for: No Guidance.mp3
# Extracting audio features for: No Heart.mp3
# Extracting audio features for: No Idea.mp3
# Extracting audio features for: No Limit.mp3
# Extracting audio features for: No Love.mp3
# Extracting audio features for: No Role Modelz.mp3
# Extracting audio features for: No Se Va.mp3
# Extracting audio features for: No Smoke.mp3
# Extracting audio features for: No Stylist.mp3
# Extracting audio features for: No Type.mp3
# Extracting audio features for: Nobody Gets Me.mp3
# Extracting audio features for: Nonsense.mp3
# Extracting audio features for: Nothin' Like You.mp3
# Extracting audio features for: Nothing Breaks Like A Heart.mp3
# Extracting audio features for: Often.mp3
# Extracting audio features for: Oh My God.mp3
# Extracting audio features for: Old Town Road.mp3
# Extracting audio features for: On Chill.mp3
# Extracting audio features for: On Me.mp3
# Extracting audio features for: On My Mama.mp3
# Extracting audio features for: On My Mind.mp3
# Extracting audio features for: One Call Away.mp3
# Extracting audio features for: One Man Band.mp3
# Extracting audio features for: One Mississippi.mp3
# Extracting audio features for: One Right Now.mp3
# Extracting audio features for: One Thing At A Time.mp3
# Extracting audio features for: Only.mp3
# Extracting audio features for: OOOUUU.mp3
# Extracting audio features for: OTW.mp3
# Extracting audio features for: Out For The Night.mp3
# Extracting audio features for: Paint The Town Red.mp3
# Extracting audio features for: Panini.mp3
# Extracting audio features for: Party Monster.mp3
# Extracting audio features for: Party.mp3
# Extracting audio features for: Perfect Storm.mp3
# Extracting audio features for: Perfect.mp3
# Extracting audio features for: Permission To Dance.mp3
# Extracting audio features for: Pick It Up.mp3
# Extracting audio features for: Pick Me Up.mp3
# Extracting audio features for: Pick Out A Christmas Tree.mp3
# Extracting audio features for: Pills And Automobiles.mp3
# Extracting audio features for: Plain Jane.mp3
# Extracting audio features for: Play No Games.mp3
# Extracting audio features for: Play That Song.mp3
# Extracting audio features for: Playing Games.mp3
# Extracting audio features for: Please Come Home For Christmas.mp3
# Extracting audio features for: Positions.mp3
# Extracting audio features for: Prayer In C.mp3
# Extracting audio features for: Pretty Little Poison.mp3
# Extracting audio features for: Prisoner.mp3
# Extracting audio features for: Provenza.mp3
# Extracting audio features for: Purpose.mp3
# Extracting audio features for: Put Your Records On.mp3
# Extracting audio features for: Qlona.mp3
# Extracting audio features for: Que Onda.mp3
# Extracting audio features for: Que Vuelvas.mp3
# Extracting audio features for: Ran$om.mp3
# Extracting audio features for: Rather Be.mp3
# Extracting audio features for: Red Opps.mp3
# Extracting audio features for: Redbone.mp3
# Extracting audio features for: Remember You Young.mp3
# Extracting audio features for: Reminder.mp3
# Extracting audio features for: Ric Flair Drip.mp3
# Extracting audio features for: Rich Baby Daddy.mp3
# Extracting audio features for: Ridin' Roads.mp3
# Extracting audio features for: Right Hand.mp3
# Extracting audio features for: Riptide.mp3
# Extracting audio features for: RITMO (Bad Boys For Life).mp3
# Extracting audio features for: River.mp3
# Extracting audio features for: Rock And A Hard Place.mp3
# Extracting audio features for: Rockabye.mp3
# Extracting audio features for: Rockin' Around The Christmas Tree.mp3
# Extracting audio features for: Rockstar.mp3
# Extracting audio features for: Roll In Peace.mp3
# Extracting audio features for: Romantic Homicide.mp3
# Extracting audio features for: Roses.mp3
# Extracting audio features for: Round Here Buzz.mp3
# Extracting audio features for: Roxanne.mp3
# Extracting audio features for: Rubbin Off The Paint.mp3
# Extracting audio features for: Rude.mp3
# Extracting audio features for: Rudolph The Red-Nosed Reindeer.mp3
# Extracting audio features for: Run Rudolph Run.mp3
# Extracting audio features for: Run.mp3
# Extracting audio features for: Sacrifice.mp3
# Extracting audio features for: Same Boat.mp3
# Extracting audio features for: Same Old Love.mp3
# Extracting audio features for: Sand In My Boots.mp3
# Extracting audio features for: Santa Baby.mp3
# Extracting audio features for: Santa Claus Is Comin' To Town.mp3
# Extracting audio features for: Santa Tell Me.mp3
# Extracting audio features for: Santa, Can't You Hear Me.mp3
# Extracting audio features for: Save Me The Trouble.mp3
# Extracting audio features for: Save Your Tears.mp3
# Extracting audio features for: Say It.mp3
# Extracting audio features for: Say So.mp3
# Extracting audio features for: Say You Won't Let Go.mp3
# Extracting audio features for: Scars To Your Beautiful.mp3
# Extracting audio features for: Scorpio.mp3
# Extracting audio features for: Search & Rescue.mp3
# Extracting audio features for: See You Again.mp3
# Extracting audio features for: Seek & Destroy.mp3
# Extracting audio features for: Segun Quien.mp3
# Extracting audio features for: Selfish.mp3
# Extracting audio features for: Senorita.mp3
# Extracting audio features for: Set Fire To The Rain.mp3
# Extracting audio features for: Shake It Off.mp3
# Extracting audio features for: Shallow.mp3
# Extracting audio features for: Shape Of You.mp3
# Extracting audio features for: She Got The Best Of Me.mp3
# Extracting audio features for: She Knows.mp3
# Extracting audio features for: She's All I Wanna Be.mp3
# Extracting audio features for: She's Mine, Pt. 1.mp3
# Extracting audio features for: Shirt.mp3
# Extracting audio features for: Shivers.mp3
# Extracting audio features for: Shotgun Rider.mp3
# Extracting audio features for: Shut Up And Dance.mp3
# Extracting audio features for: Sicko Mode.mp3
# Extracting audio features for: Side To Side.mp3
# Extracting audio features for: Sidewalks.mp3
# Extracting audio features for: Silence.mp3
# Extracting audio features for: Silent Night.mp3
# Extracting audio features for: Six Feet Under.mp3
# Extracting audio features for: Sixteen.mp3
# Extracting audio features for: Sky Walker.mp3
# Extracting audio features for: Sledgehammer.mp3
# Extracting audio features for: Sleep Without You.mp3
# Extracting audio features for: Sleigh Ride.mp3
# Extracting audio features for: Slide.mp3
# Extracting audio features for: Slow Dancing In The Dark.mp3
# Extracting audio features for: Smoke Break.mp3
# Extracting audio features for: Smokin Out The Window.mp3
# Extracting audio features for: Sneakin'.mp3
# Extracting audio features for: Snooze.mp3
# Extracting audio features for: Soldier.mp3
# Extracting audio features for: Somebody To Love.mp3
# Extracting audio features for: Someday At Christmas.mp3
# Extracting audio features for: Someone You Loved.mp3
# Extracting audio features for: Something In The Orange.mp3
# Extracting audio features for: Something In The Water.mp3
# Extracting audio features for: Somewhere In My Car.mp3
# Extracting audio features for: Son Of A Sinner.mp3
# Extracting audio features for: Song For Another Time.mp3
# Extracting audio features for: Sorry Not Sorry.mp3
# Extracting audio features for: Sorry.mp3
# Extracting audio features for: SOS.mp3
# Extracting audio features for: South Of The Border.mp3
# Extracting audio features for: Special.mp3
# Extracting audio features for: Speechless.mp3
# Extracting audio features for: Spin Bout U.mp3
# Extracting audio features for: Stand By You.mp3
# Extracting audio features for: Standing Next To You.mp3
# Extracting audio features for: Star Of The Show.mp3
# Extracting audio features for: Star Walkin' (League Of Legends Worlds Anthem).mp3
# Extracting audio features for: Starboy.mp3
# Extracting audio features for: Start Wit Me.mp3
# Extracting audio features for: Startender.mp3
# Extracting audio features for: Starting Over.mp3
# Extracting audio features for: Starving.mp3
# Extracting audio features for: Stay A Little Longer.mp3
# Extracting audio features for: Stay With Me.mp3
# Extracting audio features for: Stay.mp3
# Extracting audio features for: Steal My Girl.mp3
# Extracting audio features for: Stick Season.mp3
# Extracting audio features for: Stitches.mp3
# Extracting audio features for: Stolen Dance.mp3
# Extracting audio features for: Strangers.mp3
# Extracting audio features for: Streets.mp3
# Extracting audio features for: Stressed Out.mp3
# Extracting audio features for: Strip It Down.mp3
# Extracting audio features for: Style.mp3
# Extracting audio features for: Suicidal.mp3
# Extracting audio features for: Sun Daze.mp3
# Extracting audio features for: Super Freaky Girl.mp3
# Extracting audio features for: Super Gremlin.mp3
# Extracting audio features for: Superhero (Heroes & Villains).mp3
# Extracting audio features for: Surround Sound.mp3
# Extracting audio features for: Swang.mp3
# Extracting audio features for: Sweet But Psycho.mp3
# Extracting audio features for: Swervin.mp3
# Extracting audio features for: Take Me Home For Christmas.mp3
# Extracting audio features for: Take Me To Church.mp3
# Extracting audio features for: Take My Breath.mp3
# Extracting audio features for: Take What You Want.mp3
# Extracting audio features for: Take You Dancing.mp3
# Extracting audio features for: Taki Taki.mp3
# Extracting audio features for: Talk To Me.mp3
# Extracting audio features for: Talking To The Moon.mp3
# Extracting audio features for: Talladega.mp3
# Extracting audio features for: Tarot.mp3
# Extracting audio features for: Tell Me You Love Me.mp3
# Extracting audio features for: Tennessee Rain.mp3
# Extracting audio features for: Tequila Little Time.mp3
# Extracting audio features for: Tequila Shots.mp3
# Extracting audio features for: Thailand.mp3
# Extracting audio features for: Thank God.mp3
# Extracting audio features for: Thank U, Next.mp3
# Extracting audio features for: That's What I Like.mp3
# Extracting audio features for: Thats What I Want.mp3
# Extracting audio features for: The Bones.mp3
# Extracting audio features for: The Box.mp3
# Extracting audio features for: The Christmas Song (Merry Christmas To You).mp3
# Extracting audio features for: The Christmas Song.mp3
# Extracting audio features for: The Feeling.mp3
# Extracting audio features for: The First Noel.mp3
# Extracting audio features for: The Fix.mp3
# Extracting audio features for: The Greatest.mp3
# Extracting audio features for: The Hanging Tree.mp3
# Extracting audio features for: The Heart Wants What It Wants.mp3
# Extracting audio features for: The Hills.mp3
# Extracting audio features for: The Kind Of Love We Make.mp3
# Extracting audio features for: The Painter.mp3
# Extracting audio features for: The Race.mp3
# Extracting audio features for: The Real Slim Shady.mp3
# Extracting audio features for: The Way Life Goes.mp3
# Extracting audio features for: The Weekend.mp3
# Extracting audio features for: There's Nothing Holdin' Me Back.mp3
# Extracting audio features for: Therefore I Am.mp3
# Extracting audio features for: Thinkin' Bout Me.mp3
# Extracting audio features for: Thinking 'Bout You.mp3
# Extracting audio features for: Thinking Out Loud.mp3
# Extracting audio features for: This Christmas.mp3
# Extracting audio features for: This Feeling.mp3
# Extracting audio features for: This Is It.mp3
# Extracting audio features for: This Town.mp3
# Extracting audio features for: Throat Baby (Go Baby).mp3
# Extracting audio features for: Thunder.mp3
# Extracting audio features for: Til It's Gone.mp3
# Extracting audio features for: Time Of Our Lives.mp3
# Extracting audio features for: Tip Toe.mp3
# Extracting audio features for: Titi Me Pregunto.mp3
# Extracting audio features for: To Be Loved By You.mp3
# Extracting audio features for: Tomorrow 2.mp3
# Extracting audio features for: Too Good At Goodbyes.mp3
# Extracting audio features for: Too Many Nights.mp3
# Extracting audio features for: Too Much Sauce.mp3
# Extracting audio features for: Too Much To Ask.mp3
# Extracting audio features for: Took Her To The O.mp3
# Extracting audio features for: Top Of The World.mp3
# Extracting audio features for: Touchin, Lovin.mp3
# Extracting audio features for: Traitor.mp3
# Extracting audio features for: Trampoline.mp3
# Extracting audio features for: Trap Queen.mp3
# Extracting audio features for: Treat You Better.mp3
# Extracting audio features for: Trip.mp3
# Extracting audio features for: Truck Bed.mp3
# Extracting audio features for: Trumpets.mp3
# Extracting audio features for: Truth Hurts.mp3
# Extracting audio features for: Try Me.mp3
# Extracting audio features for: Try.mp3
# Extracting audio features for: Tuesday.mp3
# Extracting audio features for: Tusa.mp3
# Extracting audio features for: Tyler Herro.mp3
# Extracting audio features for: Un Coco.mp3
# Extracting audio features for: Un Ratito.mp3
# Extracting audio features for: Under The Influence.mp3
# Extracting audio features for: Under The Mistletoe.mp3
# Extracting audio features for: Underneath The Tree.mp3
# Extracting audio features for: Unforgettable.mp3
# Extracting audio features for: Unholy.mp3
# Extracting audio features for: Unsteady.mp3
# Extracting audio features for: Unstoppable.mp3
# Extracting audio features for: Until I Found You.mp3
# Extracting audio features for: Up.mp3
# Extracting audio features for: Uproar.mp3
# Extracting audio features for: Uptown Funk!.mp3
# Extracting audio features for: Used To Be Young.mp3
# Extracting audio features for: Used To Love You.mp3
# Extracting audio features for: Used To This.mp3
# Extracting audio features for: Used.mp3
# Extracting audio features for: Vampire.mp3
# Extracting audio features for: Vegas.mp3
# Extracting audio features for: Velvet.mp3
# Extracting audio features for: Versace On The Floor.mp3
# Extracting audio features for: Vete.mp3
# Extracting audio features for: VIBEZ.mp3
# Extracting audio features for: Victoria's Secret.mp3
# Extracting audio features for: Ville Mentality.mp3
# Extracting audio features for: Viva La Vida.mp3
# Extracting audio features for: Wait In The Truck.mp3
# Extracting audio features for: Wake Up In The Sky.mp3
# Extracting audio features for: Walk On Water.mp3
# Extracting audio features for: Wandered To LA..mp3
# Extracting audio features for: Wanna Be That Song.mp3
# Extracting audio features for: Wanted You.mp3
# Extracting audio features for: Wants And Needs.mp3
# Extracting audio features for: WAP.mp3
# Extracting audio features for: Wasted Love.mp3
# Extracting audio features for: Wasted On You.mp3
# Extracting audio features for: Watch Me.mp3
# Extracting audio features for: Water Under The Bridge.mp3
# Extracting audio features for: Water.mp3
# Extracting audio features for: Watermelon Sugar.mp3
# Extracting audio features for: Waves.mp3
# Extracting audio features for: Way 2 Sexy.mp3
# Extracting audio features for: Way Out.mp3
# Extracting audio features for: We're Good.mp3
# Extracting audio features for: Wet Dreamz.mp3
# Extracting audio features for: What About Us.mp3
# Extracting audio features for: What If I Never Get Over You.mp3
# Extracting audio features for: What Lovers Do.mp3
# Extracting audio features for: What My World Spins Around.mp3
# Extracting audio features for: What You Know Bout Love.mp3
# Extracting audio features for: What's Next.mp3
# Extracting audio features for: When I Was Your Man.mp3
# Extracting audio features for: When The Party's Over.mp3
# Extracting audio features for: When We Were Young.mp3
# Extracting audio features for: When We.mp3
# Extracting audio features for: Where Are U Now.mp3
# Extracting audio features for: Where She Goes.mp3
# Extracting audio features for: Where The Wild Things Are.mp3
# Extracting audio features for: Where Ya At.mp3
# Extracting audio features for: Whiskey And Rain.mp3
# Extracting audio features for: Whiskey On You.mp3
# Extracting audio features for: White Christmas.mp3
# Extracting audio features for: White Horse.mp3
# Extracting audio features for: White Iverson.mp3
# Extracting audio features for: Whoopty.mp3
# Extracting audio features for: Wild Ones.mp3
# Extracting audio features for: Wildest Dreams.mp3
# Extracting audio features for: Willow.mp3
# Extracting audio features for: Winter Wonderland.mp3
# Extracting audio features for: Wish I Didn't Love You.mp3
# Extracting audio features for: Without Me.mp3
# Extracting audio features for: Without You.mp3
# Extracting audio features for: Woah.mp3
# Extracting audio features for: Wolves.mp3
# Extracting audio features for: Woman.mp3
# Extracting audio features for: Wonderful Christmastime.mp3
# Extracting audio features for: World On Fire.mp3
# Extracting audio features for: Wow..mp3
# Extracting audio features for: Written In The Sand.mp3
# Extracting audio features for: WTF (Where They From).mp3
# Extracting audio features for: X.mp3
# Extracting audio features for: Yellow Flicker Beat.mp3
# Extracting audio features for: Yellow Hearts.mp3
# Extracting audio features for: Yellow.mp3
# Extracting audio features for: Yo No Soy Celoso.mp3
# Extracting audio features for: Yonaguni.mp3
# Extracting audio features for: You Broke Me First..mp3
# Extracting audio features for: You Broke My Heart.mp3
# Extracting audio features for: You Broke Up With Me.mp3
# Extracting audio features for: You Proof.mp3
# Extracting audio features for: You Say.mp3
# Extracting audio features for: You Should Be Here.mp3
# Extracting audio features for: You Should Probably Leave.mp3
# Extracting audio features for: You Was Right.mp3
# Extracting audio features for: You're A Mean One, Mr. Grinch.mp3
# Extracting audio features for: You're Losing Me (From The Vault).mp3
# Extracting audio features for: You're Mines Still.mp3
# Extracting audio features for: You're Welcome.mp3
# Extracting audio features for: You.mp3
# Extracting audio features for: Young Dumb & Broke.mp3
# Extracting audio features for: Youngblood.mp3
# Extracting audio features for: Yours.mp3
# Extracting audio features for: ZEZE.mp3
# Audio features saved to: audio_features_chorus.csv
