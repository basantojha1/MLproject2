# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Preforming logistic regression and naive bayes on pca dataframe

# %%
# Loading CSV file
pca_df = pd.read_csv('pca.csv')

# %%
# Checking information
pca_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915 entries, 0 to 914
# Data columns (total 35 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  915 non-null    int64
#  1   PC1         915 non-null    float64
#  2   PC2         915 non-null    float64
#  3   PC3         915 non-null    float64
#  4   PC4         915 non-null    float64
#  5   PC5         915 non-null    float64
#  6   PC6         915 non-null    float64
#  7   PC7         915 non-null    float64
#  8   PC8         915 non-null    float64
#  9   PC9         915 non-null    float64
#  10  PC10        915 non-null    float64
#  11  PC11        915 non-null    float64
#  12  PC12        915 non-null    float64
#  13  PC13        915 non-null    float64
#  14  PC14        915 non-null    float64
#  15  PC15        915 non-null    float64
#  16  PC16        915 non-null    float64
#  17  PC17        915 non-null    float64
# ...

# %%
# Dropping unnamed column
pca_df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
pca_df.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -6.492711  6.874188 -1.968564 -1.975650 -0.575041 -5.597309 -4.470611
# 1 -7.433454  4.056370  0.101741  0.524605 -1.284552  0.791289 -2.067485
# 2 -9.522612  4.870539 -0.437663  0.015167  1.713550 -3.005877  0.929472
# 3 -8.105297 -0.613300  1.290936  0.702758  2.507130  1.181359  0.987580
# 4 -2.330014  0.180027 -2.029767  0.753153 -1.064218 -1.516332  1.384673
#
#         PC8       PC9      PC10  ...      PC25      PC26      PC27      PC28  \
# 0  3.515907  0.245031  2.978113  ... -1.316242 -1.112884 -0.072426  0.417510
# 1  1.253907 -2.234390 -2.056215  ... -0.640821  0.489938 -0.568624  0.324642
# 2 -4.029814 -1.833326  0.472772  ... -0.427927 -0.504746  0.915967  0.746980
# 3 -2.548739 -1.422121 -0.052155  ... -0.442217 -0.123394  0.112966 -1.251188
# 4  1.506373 -1.347584 -1.380337  ... -0.561004  0.796018 -0.762684  1.251386
#
#        PC29      PC30      PC31      PC32      PC33  Label
# ...

# %%
pca_df.describe().T
# Out:
#        count          mean       std       min       25%       50%       75%  \
# PC1    915.0  0.000000e+00  4.158106 -9.666004 -2.722627 -0.414093  2.900448
# PC2    915.0  1.553099e-17  2.894681 -8.502819 -1.960534 -0.248703  1.753384
# PC3    915.0 -3.106198e-17  2.318791 -6.326784 -1.637969  0.155530  1.662595
# PC4    915.0 -3.882747e-18  2.170212 -6.522497 -1.497894 -0.053554  1.426273
# PC5    915.0  2.329648e-17  2.069201 -5.115789 -1.469441 -0.024339  1.379682
# PC6    915.0  3.494472e-17  1.900604 -5.602456 -1.297900  0.070173  1.132575
# PC7    915.0  2.912060e-17  1.787240 -8.200302 -1.006096 -0.060836  1.078734
# PC8    915.0 -1.553099e-17  1.727733 -6.038920 -1.097402  0.028679  1.072081
# PC9    915.0 -3.106198e-17  1.622601 -5.149095 -1.059468 -0.015340  1.012901
# PC10   915.0  3.203266e-17  1.543913 -6.242542 -1.031684 -0.020538  0.995473
# PC11   915.0 -2.912060e-17  1.520777 -4.040034 -1.057887 -0.098077  0.925298
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
# Step 1: Splitting the data into features (X) and target variable (y)
X = pca_df.drop('Label', axis=1)
y = pca_df['Label']

# Step 2: Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.41, random_state=42)

# Step 3: Standardizing features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 4: Fit Logistic Regression model
log_reg_model = LogisticRegression()
log_reg_model.fit(X_train_scaled, y_train)

# Step 5: Evaluate model performance
y_pred = log_reg_model.predict(X_test_scaled)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        44
#            1       0.88      1.00      0.94       332
#
#     accuracy                           0.88       376
#    macro avg       0.44      0.50      0.47       376
# weighted avg       0.78      0.88      0.83       376

# %%
from sklearn.metrics import accuracy_score

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

print("Model Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Model Accuracy: 88.03%

# %%
from sklearn.naive_bayes import GaussianNB

# Step 2: Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.41, random_state=42)

# Step 3: Standardizing features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 4: Fit Gaussian Naive Bayes model
nb_model = GaussianNB()
nb_model.fit(X_train_scaled, y_train)

# Step 5: Evaluate model performance
y_pred_nb = nb_model.predict(X_test_scaled)
print(classification_report(y_test, y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.38      0.07      0.12        44
#            1       0.89      0.98      0.93       332
#
#     accuracy                           0.88       376
#    macro avg       0.63      0.53      0.52       376
# weighted avg       0.83      0.88      0.84       376

# %%
# Calculating accuracy
accuracy_nb = accuracy_score(y_test, y_pred_nb)

print("Naive Bayes Model Accuracy: {:.2f}%".format(accuracy_nb * 100))
# Out:
# Naive Bayes Model Accuracy: 87.77%

# %%
# While using the pca dataframe that contains the columns with 95% variance:
# Model accuracy for logestic regression came out to be 88.03%.
# Model accuracy for Naive Bayes came out to be 87.77%

# %%
# Preforming logistic regression and naive bayes on final dataset

# %%
# Loading CSV file
final_df = pd.read_csv('final_data.csv')

# %%
# Checking information
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915 entries, 0 to 914
# Data columns (total 88 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              915 non-null    int64
#  1   Song                    915 non-null    object
#  2   Artist                  915 non-null    object
#  3   Label                   915 non-null    int64
#  4   YouTube_URL             915 non-null    object
#  5   tempo                   915 non-null    float64
#  6   beats                   915 non-null    object
#  7   rmse                    915 non-null    float64
#  8   spectral_centroid       915 non-null    float64
#  9   spectral_bandwidth      915 non-null    float64
#  10  spectral_rolloff        915 non-null    float64
#  11  spectral_contrast       915 non-null    object
#  12  zero_crossing_rate      915 non-null    float64
#  13  chroma_stft_0           915 non-null    float64
# ...

# %%
# Dropping unnamed column
final_df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Selecting specific columns
selected_columns = ['tempo', 'rmse', 'spectral_centroid', 'spectral_bandwidth', 
                    'spectral_rolloff', 'zero_crossing_rate', 'tonnetz_mean', 
                    'mfcc_mean', 'spectral_contrast_mean', 'chroma_cens_mean', 
                    'chroma_cqt_mean', 'chroma_stft_mean', 'Label']

# Create a new DataFrame with only the selected columns
df = final_df.loc[:, selected_columns]

# %%
df.head()
# Out:
#         tempo      rmse  spectral_centroid  spectral_bandwidth  \
# 0  143.554688  0.255377        2469.284500         2551.212317
# 1  172.265625  0.264122        2395.214782         2619.288219
# 2   83.354335  0.376883        2013.544292         2440.739148
# 3  143.554688  0.297056        1896.583680         2452.158667
# 4  135.999178  0.262961        2389.685530         2346.994035
#
#    spectral_rolloff  zero_crossing_rate  tonnetz_mean  mfcc_mean  \
# 0       5280.168729            0.061881      0.028604   5.856240
# 1       5265.804933            0.056898      0.017409   7.351922
# 2       4593.616771            0.043014      0.026574   8.405519
# 3       4405.838246            0.035403      0.027215   7.781207
# 4       4792.798899            0.102749     -0.037936   2.160049
#
#    spectral_contrast_mean  chroma_cens_mean  chroma_cqt_mean  \
# 0               22.161122          0.190910         0.275123
# 1               22.292219          0.232774         0.347113
# ...

# %%
df.describe().T
# Out:
#                         count         mean          std          min  \
# tempo                   915.0   122.824019    28.751459    48.754422
# rmse                    915.0     0.190480     0.091630     0.005688
# spectral_centroid       915.0  2115.780246   457.161526   735.760354
# spectral_bandwidth      915.0  2332.961635   343.353688  1050.980075
# spectral_rolloff        915.0  4486.242744  1051.445004  1067.379895
# zero_crossing_rate      915.0     0.084294     0.028109     0.013752
# tonnetz_mean            915.0     0.004193     0.033539    -0.105284
# mfcc_mean               915.0     0.226426     5.921810   -23.027361
# spectral_contrast_mean  915.0    23.929937     1.498057    18.590917
# chroma_cens_mean        915.0     0.239472     0.023717     0.154614
# chroma_cqt_mean         915.0     0.421315     0.096274     0.177367
# chroma_stft_mean        915.0     0.384562     0.082024     0.202268
# Label                   915.0     0.901639     0.297965     0.000000
#
# ...

# %%
# I have already imported the required libraries

# Step 1: Splitting the data into features (X) and target variable (y)
X = df.drop('Label', axis=1)
y = df['Label']

# Step 2: Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.41, random_state=42)

# Step 3: Standardizing features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 4: Fitting Logistic Regression model
log_reg_model = LogisticRegression()
log_reg_model.fit(X_train_scaled, y_train)

# Step 5: Evaluating model performance
y_pred = log_reg_model.predict(X_test_scaled)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        44
#            1       0.88      1.00      0.94       332
#
#     accuracy                           0.88       376
#    macro avg       0.44      0.50      0.47       376
# weighted avg       0.78      0.88      0.83       376
# C:\Users\Basan\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Basan\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# Calculating accuracy
accuracy = accuracy_score(y_test, y_pred)

print("Model Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Model Accuracy: 88.30%

# %%
# I have already imported the required libraries

# Step 2: Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Step 3: Standardizing features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 4: Fit Gaussian Naive Bayes model
nb_model = GaussianNB()
nb_model.fit(X_train_scaled, y_train)

# Step 5: Evaluate model performance
y_pred_nb = nb_model.predict(X_test_scaled)
print(classification_report(y_test, y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        43
#            1       0.88      1.00      0.94       323
#
#     accuracy                           0.88       366
#    macro avg       0.44      0.50      0.47       366
# weighted avg       0.78      0.88      0.83       366
# C:\Users\Basan\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Basan\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# Calculating accuracy
accuracy_nb = accuracy_score(y_test, y_pred_nb)

print("Naive Bayes Model Accuracy: {:.2f}%".format(accuracy_nb * 100))
# Out:
# Naive Bayes Model Accuracy: 88.25%

# %%
# While using certain columns from final_data dataset which contains the cleaned data:
# Model accuracy for logestic regression came out to be 88.30%.
# Model accuracy for Naive Bayes came out to be 88.25%%
